# %%
import os

CHECKPOINT_DIR_PATH = "G:\\segmentation_master\\training_environment\\ade_indoor\\Checkpoints\\Checkpoint_mn2"

with open(os.path.join(CHECKPOINT_DIR_PATH, "checkpoint")) as file:
    for i, line in enumerate(file):
        if i == 0:
            continue
        model_name = (line.split(' ')[1])[1:-2]
        model_path = os.path.join(CHECKPOINT_DIR_PATH, model_name)
        print(model_path)
# Out:
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-0
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-618
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-1247
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-1826
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-2406
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-3024
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-3648
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-4245
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-4813
# G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint_mn2\model.ckpt-5393
# ...

# %%
import pickle

with open(os.path.join(CHECKPOINT_DIR_PATH, "metrics - Copy.pickle"), 'rb') as handle:
    metrics_dict = pickle.load(handle)
    print(len(metrics_dict))
    print(metrics_dict)
# Out:
# 188
# ...
