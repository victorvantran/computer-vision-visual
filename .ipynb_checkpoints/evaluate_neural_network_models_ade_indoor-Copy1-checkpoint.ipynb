# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import io
import shutil
import re 
import time

import scipy.interpolate
from sklearn.model_selection import train_test_split

import PIL
from PIL import Image

import logging, sys
logging.basicConfig(stream=sys.stderr, level=logging.INFO) # INFO # WARNING # ERROR

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.INFO)


RANDOM_SEED = 8675309
ZFILL=8

TARGET_WIDTH = 257
TARGET_HEIGHT = 257

# %% [markdown]
# ## Evaluate as you train

# %%
# Proper MobilenetV2 Evaluation
'''
# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_v2" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mn2_proper_v1 \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mn2_proper_v1 \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
'''

# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations\Evaluation_mn2"

# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_v2" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mn2 \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mn2 \
  --dataset_dir=training_environment/ade_indoor/TFRecord
# Out:
# G:\segmentation_master

# %%
# Proper MobilenetV3 Evaluation


# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations\Evaluation_mn3_small"

# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_v3_large_seg" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mn3_large \
  --dataset_dir=training_environment/ade_indoor/TFRecord
# Out:
# G:\segmentation_master
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/1.76m params)
#   MobilenetV3 (--/1.38m params)
#     MobilenetV3/Conv (--/464 params)
#       MobilenetV3/Conv/BatchNorm (--/32 params)
#         MobilenetV3/Conv/BatchNorm/beta (16, 16/16 params)
#         MobilenetV3/Conv/BatchNorm/gamma (16, 16/16 params)
#       MobilenetV3/Conv/weights (3x3x3x16, 432/432 params)
#     MobilenetV3/Conv_1 (--/39.36k params)
#       MobilenetV3/Conv_1/BatchNorm (--/960 params)
#         MobilenetV3/Conv_1/BatchNorm/beta (480, 480/480 params)
#         MobilenetV3/Conv_1/BatchNorm/gamma (480, 480/480 params)
#       MobilenetV3/Conv_1/weights (1x1x80x480, 38.40k/38.40k params)
#     MobilenetV3/expanded_conv (--/464 params)
#       MobilenetV3/expanded_conv/depthwise (--/176 params)
#         MobilenetV3/expanded_conv/depthwise/BatchNorm (--/32 params)
#           MobilenetV3/expanded_conv/depthwise/BatchNorm/beta (16, 16/16 params)
#           MobilenetV3/expanded_conv/depthwise/BatchNorm/gamma (16, 16/16 params)
#         MobilenetV3/expanded_conv/depthwise/depthwise_weights (3x3x16x1, 144/144 params)
#       MobilenetV3/expanded_conv/project (--/288 params)
#         MobilenetV3/expanded_conv/project/BatchNorm (--/32 params)
#           MobilenetV3/expanded_conv/project/BatchNorm/beta (16, 16/16 params)
#           MobilenetV3/expanded_conv/project/BatchNorm/gamma (16, 16/16 params)
#         MobilenetV3/expanded_conv/project/weights (1x1x16x16, 256/256 params)
#     MobilenetV3/expanded_conv_1 (--/3.44k params)
#       MobilenetV3/expanded_conv_1/depthwise (--/704 params)
#         MobilenetV3/expanded_conv_1/depthwise/BatchNorm (--/128 params)
#           MobilenetV3/expanded_conv_1/depthwise/BatchNorm/beta (64, 64/64 params)
#           MobilenetV3/expanded_conv_1/depthwise/BatchNorm/gamma (64, 64/64 params)
#         MobilenetV3/expanded_conv_1/depthwise/depthwise_weights (3x3x64x1, 576/576 params)
#       MobilenetV3/expanded_conv_1/expand (--/1.15k params)
#         MobilenetV3/expanded_conv_1/expand/BatchNorm (--/128 params)
#           MobilenetV3/expanded_conv_1/expand/BatchNorm/beta (64, 64/64 params)
#           MobilenetV3/expanded_conv_1/expand/BatchNorm/gamma (64, 64/64 params)
#         MobilenetV3/expanded_conv_1/expand/weights (1x1x16x64, 1.02k/1.02k params)
#       MobilenetV3/expanded_conv_1/project (--/1.58k params)
#         MobilenetV3/expanded_conv_1/project/BatchNorm (--/48 params)
#           MobilenetV3/expanded_conv_1/project/BatchNorm/beta (24, 24/24 params)
#           MobilenetV3/expanded_conv_1/project/BatchNorm/gamma (24, 24/24 params)
#         MobilenetV3/expanded_conv_1/project/weights (1x1x64x24, 1.54k/1.54k params)
#     MobilenetV3/expanded_conv_10 (--/214.42k params)
#       MobilenetV3/expanded_conv_10/depthwise (--/5.28k params)
#         MobilenetV3/expanded_conv_10/depthwise/BatchNorm (--/960 params)
#           MobilenetV3/expanded_conv_10/depthwise/BatchNorm/beta (480, 480/480 params)
#           MobilenetV3/expanded_conv_10/depthwise/BatchNorm/gamma (480, 480/480 params)
#         MobilenetV3/expanded_conv_10/depthwise/depthwise_weights (3x3x480x1, 4.32k/4.32k params)
#       MobilenetV3/expanded_conv_10/expand (--/39.36k params)
#         MobilenetV3/expanded_conv_10/expand/BatchNorm (--/960 params)
#           MobilenetV3/expanded_conv_10/expand/BatchNorm/beta (480, 480/480 params)
#           MobilenetV3/expanded_conv_10/expand/BatchNorm/gamma (480, 480/480 params)
#         MobilenetV3/expanded_conv_10/expand/weights (1x1x80x480, 38.40k/38.40k params)
#       MobilenetV3/expanded_conv_10/project (--/53.98k params)
#         MobilenetV3/expanded_conv_10/project/BatchNorm (--/224 params)
#           MobilenetV3/expanded_conv_10/project/BatchNorm/beta (112, 112/112 params)
# 2022-11-29 05:11:18.861681: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/eval.py:254: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1129 05:11:22.947888  9404 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1129 05:11:22.947888  9404 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From deeplab/eval.py:108: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1129 05:11:22.947888  9404 module_wrapper.py:139] From deeplab/eval.py:108: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From deeplab/eval.py:109: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1129 05:11:22.947888  9404 module_wrapper.py:139] From deeplab/eval.py:109: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Evaluating on val set
# I1129 05:11:22.947888  9404 eval.py:109] Evaluating on val set
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1129 05:11:22.948887  9404 module_wrapper.py:139] From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1129 05:11:23.258835  9404 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1129 05:11:23.260834  9404 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# 2022-11-29 05:11:23.674721: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2022-11-29 05:11:23.692555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-11-29 05:11:23.692588: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-11-29 05:11:23.694387: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-11-29 05:11:23.696143: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-11-29 05:11:23.696638: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-11-29 05:11:23.698627: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-11-29 05:11:23.700314: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-11-29 05:11:23.704644: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-11-29 05:11:23.704696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W1129 05:11:24.181541  9404 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W1129 05:11:27.574459  9404 deprecation.py:323] From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Performing single-scale test.
# I1129 05:11:27.605449  9404 eval.py:127] Performing single-scale test.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1129 05:11:27.606449  9404 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
#           MobilenetV3/expanded_conv_10/project/BatchNorm/gamma (112, 112/112 params)
#         MobilenetV3/expanded_conv_10/project/weights (1x1x480x112, 53.76k/53.76k params)
#       MobilenetV3/expanded_conv_10/squeeze_excite (--/115.80k params)
#         MobilenetV3/expanded_conv_10/squeeze_excite/Conv (--/57.72k params)
#           MobilenetV3/expanded_conv_10/squeeze_excite/Conv/biases (120, 120/120 params)
#           MobilenetV3/expanded_conv_10/squeeze_excite/Conv/weights (1x1x480x120, 57.60k/57.60k params)
#         MobilenetV3/expanded_conv_10/squeeze_excite/Conv_1 (--/58.08k params)
#           MobilenetV3/expanded_conv_10/squeeze_excite/Conv_1/biases (480, 480/480 params)
#           MobilenetV3/expanded_conv_10/squeeze_excite/Conv_1/weights (1x1x120x480, 57.60k/57.60k params)
#     MobilenetV3/expanded_conv_11 (--/386.12k params)
#       MobilenetV3/expanded_conv_11/depthwise (--/7.39k params)
#         MobilenetV3/expanded_conv_11/depthwise/BatchNorm (--/1.34k params)
#           MobilenetV3/expanded_conv_11/depthwise/BatchNorm/beta (672, 672/672 params)
#           MobilenetV3/expanded_conv_11/depthwise/BatchNorm/gamma (672, 672/672 params)
#         MobilenetV3/expanded_conv_11/depthwise/depthwise_weights (3x3x672x1, 6.05k/6.05k params)
#       MobilenetV3/expanded_conv_11/expand (--/76.61k params)
#         MobilenetV3/expanded_conv_11/expand/BatchNorm (--/1.34k params)
#           MobilenetV3/expanded_conv_11/expand/BatchNorm/beta (672, 672/672 params)
#           MobilenetV3/expanded_conv_11/expand/BatchNorm/gamma (672, 672/672 params)
#         MobilenetV3/expanded_conv_11/expand/weights (1x1x112x672, 75.26k/75.26k params)
#       MobilenetV3/expanded_conv_11/project (--/75.49k params)
#         MobilenetV3/expanded_conv_11/project/BatchNorm (--/224 params)
#           MobilenetV3/expanded_conv_11/project/BatchNorm/beta (112, 112/112 params)
#           MobilenetV3/expanded_conv_11/project/BatchNorm/gamma (112, 112/112 params)
#         MobilenetV3/expanded_conv_11/project/weights (1x1x672x112, 75.26k/75.26k params)
#       MobilenetV3/expanded_conv_11/squeeze_excite (--/226.63k params)
#         MobilenetV3/expanded_conv_11/squeeze_excite/Conv (--/113.06k params)
#           MobilenetV3/expanded_conv_11/squeeze_excite/Conv/biases (168, 168/168 params)
#           MobilenetV3/expanded_conv_11/squeeze_excite/Conv/weights (1x1x672x168, 112.90k/112.90k params)
#         MobilenetV3/expanded_conv_11/squeeze_excite/Conv_1 (--/113.57k params)
#           MobilenetV3/expanded_conv_11/squeeze_excite/Conv_1/biases (672, 672/672 params)
#           MobilenetV3/expanded_conv_11/squeeze_excite/Conv_1/weights (1x1x168x672, 112.90k/112.90k params)
#     MobilenetV3/expanded_conv_12 (--/133.98k params)
#       MobilenetV3/expanded_conv_12/depthwise (--/9.07k params)
#         MobilenetV3/expanded_conv_12/depthwise/BatchNorm (--/672 params)
#           MobilenetV3/expanded_conv_12/depthwise/BatchNorm/beta (336, 336/336 params)
#           MobilenetV3/expanded_conv_12/depthwise/BatchNorm/gamma (336, 336/336 params)
#         MobilenetV3/expanded_conv_12/depthwise/depthwise_weights (5x5x336x1, 8.40k/8.40k params)
#       MobilenetV3/expanded_conv_12/expand (--/38.30k params)
#         MobilenetV3/expanded_conv_12/expand/BatchNorm (--/672 params)
#           MobilenetV3/expanded_conv_12/expand/BatchNorm/beta (336, 336/336 params)
#           MobilenetV3/expanded_conv_12/expand/BatchNorm/gamma (336, 336/336 params)
#         MobilenetV3/expanded_conv_12/expand/weights (1x1x112x336, 37.63k/37.63k params)
#       MobilenetV3/expanded_conv_12/project (--/27.04k params)
#         MobilenetV3/expanded_conv_12/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_12/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_12/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_12/project/weights (1x1x336x80, 26.88k/26.88k params)
#       MobilenetV3/expanded_conv_12/squeeze_excite (--/59.56k params)
#         MobilenetV3/expanded_conv_12/squeeze_excite/Conv (--/29.66k params)
#           MobilenetV3/expanded_conv_12/squeeze_excite/Conv/biases (88, 88/88 params)
#           MobilenetV3/expanded_conv_12/squeeze_excite/Conv/weights (1x1x336x88, 29.57k/29.57k params)
#         MobilenetV3/expanded_conv_12/squeeze_excite/Conv_1 (--/29.90k params)
#           MobilenetV3/expanded_conv_12/squeeze_excite/Conv_1/biases (336, 336/336 params)
#           MobilenetV3/expanded_conv_12/squeeze_excite/Conv_1/weights (1x1x88x336, 29.57k/29.57k params)
#     MobilenetV3/expanded_conv_13 (--/206.68k params)
#       MobilenetV3/expanded_conv_13/depthwise (--/12.96k params)
#         MobilenetV3/expanded_conv_13/depthwise/BatchNorm (--/960 params)
#           MobilenetV3/expanded_conv_13/depthwise/BatchNorm/beta (480, 480/480 params)
#           MobilenetV3/expanded_conv_13/depthwise/BatchNorm/gamma (480, 480/480 params)
#         MobilenetV3/expanded_conv_13/depthwise/depthwise_weights (5x5x480x1, 12.00k/12.00k params)
#       MobilenetV3/expanded_conv_13/expand (--/39.36k params)
#         MobilenetV3/expanded_conv_13/expand/BatchNorm (--/960 params)
#           MobilenetV3/expanded_conv_13/expand/BatchNorm/beta (480, 480/480 params)
#           MobilenetV3/expanded_conv_13/expand/BatchNorm/gamma (480, 480/480 params)
#         MobilenetV3/expanded_conv_13/expand/weights (1x1x80x480, 38.40k/38.40k params)
#       MobilenetV3/expanded_conv_13/project (--/38.56k params)
#         MobilenetV3/expanded_conv_13/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_13/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_13/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_13/project/weights (1x1x480x80, 38.40k/38.40k params)
#       MobilenetV3/expanded_conv_13/squeeze_excite (--/115.80k params)
#         MobilenetV3/expanded_conv_13/squeeze_excite/Conv (--/57.72k params)
#           MobilenetV3/expanded_conv_13/squeeze_excite/Conv/biases (120, 120/120 params)
#           MobilenetV3/expanded_conv_13/squeeze_excite/Conv/weights (1x1x480x120, 57.60k/57.60k params)
#         MobilenetV3/expanded_conv_13/squeeze_excite/Conv_1 (--/58.08k params)
#           MobilenetV3/expanded_conv_13/squeeze_excite/Conv_1/biases (480, 480/480 params)
#           MobilenetV3/expanded_conv_13/squeeze_excite/Conv_1/weights (1x1x120x480, 57.60k/57.60k params)
#     MobilenetV3/expanded_conv_14 (--/206.68k params)
#       MobilenetV3/expanded_conv_14/depthwise (--/12.96k params)
#         MobilenetV3/expanded_conv_14/depthwise/BatchNorm (--/960 params)
#           MobilenetV3/expanded_conv_14/depthwise/BatchNorm/beta (480, 480/480 params)
#           MobilenetV3/expanded_conv_14/depthwise/BatchNorm/gamma (480, 480/480 params)
#         MobilenetV3/expanded_conv_14/depthwise/depthwise_weights (5x5x480x1, 12.00k/12.00k params)
#       MobilenetV3/expanded_conv_14/expand (--/39.36k params)
#         MobilenetV3/expanded_conv_14/expand/BatchNorm (--/960 params)
#           MobilenetV3/expanded_conv_14/expand/BatchNorm/beta (480, 480/480 params)
#           MobilenetV3/expanded_conv_14/expand/BatchNorm/gamma (480, 480/480 params)
#         MobilenetV3/expanded_conv_14/expand/weights (1x1x80x480, 38.40k/38.40k params)
#       MobilenetV3/expanded_conv_14/project (--/38.56k params)
#         MobilenetV3/expanded_conv_14/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_14/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_14/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_14/project/weights (1x1x480x80, 38.40k/38.40k params)
#       MobilenetV3/expanded_conv_14/squeeze_excite (--/115.80k params)
#         MobilenetV3/expanded_conv_14/squeeze_excite/Conv (--/57.72k params)
#           MobilenetV3/expanded_conv_14/squeeze_excite/Conv/biases (120, 120/120 params)
#           MobilenetV3/expanded_conv_14/squeeze_excite/Conv/weights (1x1x480x120, 57.60k/57.60k params)
#         MobilenetV3/expanded_conv_14/squeeze_excite/Conv_1 (--/58.08k params)
#           MobilenetV3/expanded_conv_14/squeeze_excite/Conv_1/biases (480, 480/480 params)
#           MobilenetV3/expanded_conv_14/squeeze_excite/Conv_1/weights (1x1x120x480, 57.60k/57.60k params)
#     MobilenetV3/expanded_conv_2 (--/4.44k params)
#       MobilenetV3/expanded_conv_2/depthwise (--/792 params)
#         MobilenetV3/expanded_conv_2/depthwise/BatchNorm (--/144 params)
#           MobilenetV3/expanded_conv_2/depthwise/BatchNorm/beta (72, 72/72 params)
#           MobilenetV3/expanded_conv_2/depthwise/BatchNorm/gamma (72, 72/72 params)
#         MobilenetV3/expanded_conv_2/depthwise/depthwise_weights (3x3x72x1, 648/648 params)
#       MobilenetV3/expanded_conv_2/expand (--/1.87k params)
#         MobilenetV3/expanded_conv_2/expand/BatchNorm (--/144 params)
#           MobilenetV3/expanded_conv_2/expand/BatchNorm/beta (72, 72/72 params)
#           MobilenetV3/expanded_conv_2/expand/BatchNorm/gamma (72, 72/72 params)
#         MobilenetV3/expanded_conv_2/expand/weights (1x1x24x72, 1.73k/1.73k params)
#       MobilenetV3/expanded_conv_2/project (--/1.78k params)
#         MobilenetV3/expanded_conv_2/project/BatchNorm (--/48 params)
#           MobilenetV3/expanded_conv_2/project/BatchNorm/beta (24, 24/24 params)
#           MobilenetV3/expanded_conv_2/project/BatchNorm/gamma (24, 24/24 params)
#         MobilenetV3/expanded_conv_2/project/weights (1x1x72x24, 1.73k/1.73k params)
#     MobilenetV3/expanded_conv_3 (--/10.33k params)
#       MobilenetV3/expanded_conv_3/depthwise (--/1.94k params)
#         MobilenetV3/expanded_conv_3/depthwise/BatchNorm (--/144 params)
#           MobilenetV3/expanded_conv_3/depthwise/BatchNorm/beta (72, 72/72 params)
#           MobilenetV3/expanded_conv_3/depthwise/BatchNorm/gamma (72, 72/72 params)
#         MobilenetV3/expanded_conv_3/depthwise/depthwise_weights (5x5x72x1, 1.80k/1.80k params)
#       MobilenetV3/expanded_conv_3/expand (--/1.87k params)
#         MobilenetV3/expanded_conv_3/expand/BatchNorm (--/144 params)
#           MobilenetV3/expanded_conv_3/expand/BatchNorm/beta (72, 72/72 params)
#           MobilenetV3/expanded_conv_3/expand/BatchNorm/gamma (72, 72/72 params)
#         MobilenetV3/expanded_conv_3/expand/weights (1x1x24x72, 1.73k/1.73k params)
#       MobilenetV3/expanded_conv_3/project (--/2.96k params)
#         MobilenetV3/expanded_conv_3/project/BatchNorm (--/80 params)
#           MobilenetV3/expanded_conv_3/project/BatchNorm/beta (40, 40/40 params)
#           MobilenetV3/expanded_conv_3/project/BatchNorm/gamma (40, 40/40 params)
#         MobilenetV3/expanded_conv_3/project/weights (1x1x72x40, 2.88k/2.88k params)
#       MobilenetV3/expanded_conv_3/squeeze_excite (--/3.55k params)
#         MobilenetV3/expanded_conv_3/squeeze_excite/Conv (--/1.75k params)
#           MobilenetV3/expanded_conv_3/squeeze_excite/Conv/biases (24, 24/24 params)
#           MobilenetV3/expanded_conv_3/squeeze_excite/Conv/weights (1x1x72x24, 1.73k/1.73k params)
#         MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1 (--/1.80k params)
#           MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/biases (72, 72/72 params)
#           MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/weights (1x1x24x72, 1.73k/1.73k params)
#     MobilenetV3/expanded_conv_4 (--/20.99k params)
#       MobilenetV3/expanded_conv_4/depthwise (--/3.24k params)
#         MobilenetV3/expanded_conv_4/depthwise/BatchNorm (--/240 params)
#           MobilenetV3/expanded_conv_4/depthwise/BatchNorm/beta (120, 120/120 params)
#           MobilenetV3/expanded_conv_4/depthwise/BatchNorm/gamma (120, 120/120 params)
#         MobilenetV3/expanded_conv_4/depthwise/depthwise_weights (5x5x120x1, 3.00k/3.00k params)
#       MobilenetV3/expanded_conv_4/expand (--/5.04k params)
#         MobilenetV3/expanded_conv_4/expand/BatchNorm (--/240 params)
#           MobilenetV3/expanded_conv_4/expand/BatchNorm/beta (120, 120/120 params)
#           MobilenetV3/expanded_conv_4/expand/BatchNorm/gamma (120, 120/120 params)
#         MobilenetV3/expanded_conv_4/expand/weights (1x1x40x120, 4.80k/4.80k params)
#       MobilenetV3/expanded_conv_4/project (--/4.88k params)
#         MobilenetV3/expanded_conv_4/project/BatchNorm (--/80 params)
#           MobilenetV3/expanded_conv_4/project/BatchNorm/beta (40, 40/40 params)
#           MobilenetV3/expanded_conv_4/project/BatchNorm/gamma (40, 40/40 params)
#         MobilenetV3/expanded_conv_4/project/weights (1x1x120x40, 4.80k/4.80k params)
#       MobilenetV3/expanded_conv_4/squeeze_excite (--/7.83k params)
#         MobilenetV3/expanded_conv_4/squeeze_excite/Conv (--/3.87k params)
#           MobilenetV3/expanded_conv_4/squeeze_excite/Conv/biases (32, 32/32 params)
#           MobilenetV3/expanded_conv_4/squeeze_excite/Conv/weights (1x1x120x32, 3.84k/3.84k params)
#         MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1 (--/3.96k params)
#           MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/biases (120, 120/120 params)
#           MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/weights (1x1x32x120, 3.84k/3.84k params)
#     MobilenetV3/expanded_conv_5 (--/20.99k params)
#       MobilenetV3/expanded_conv_5/depthwise (--/3.24k params)
#         MobilenetV3/expanded_conv_5/depthwise/BatchNorm (--/240 params)
#           MobilenetV3/expanded_conv_5/depthwise/BatchNorm/beta (120, 120/120 params)
#           MobilenetV3/expanded_conv_5/depthwise/BatchNorm/gamma (120, 120/120 params)
#         MobilenetV3/expanded_conv_5/depthwise/depthwise_weights (5x5x120x1, 3.00k/3.00k params)
#       MobilenetV3/expanded_conv_5/expand (--/5.04k params)
#         MobilenetV3/expanded_conv_5/expand/BatchNorm (--/240 params)
#           MobilenetV3/expanded_conv_5/expand/BatchNorm/beta (120, 120/120 params)
#           MobilenetV3/expanded_conv_5/expand/BatchNorm/gamma (120, 120/120 params)
#         MobilenetV3/expanded_conv_5/expand/weights (1x1x40x120, 4.80k/4.80k params)
#       MobilenetV3/expanded_conv_5/project (--/4.88k params)
#         MobilenetV3/expanded_conv_5/project/BatchNorm (--/80 params)
#           MobilenetV3/expanded_conv_5/project/BatchNorm/beta (40, 40/40 params)
#           MobilenetV3/expanded_conv_5/project/BatchNorm/gamma (40, 40/40 params)
#         MobilenetV3/expanded_conv_5/project/weights (1x1x120x40, 4.80k/4.80k params)
#       MobilenetV3/expanded_conv_5/squeeze_excite (--/7.83k params)
#         MobilenetV3/expanded_conv_5/squeeze_excite/Conv (--/3.87k params)
#           MobilenetV3/expanded_conv_5/squeeze_excite/Conv/biases (32, 32/32 params)
#           MobilenetV3/expanded_conv_5/squeeze_excite/Conv/weights (1x1x120x32, 3.84k/3.84k params)
#         MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1 (--/3.96k params)
#           MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/biases (120, 120/120 params)
#           MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/weights (1x1x32x120, 3.84k/3.84k params)
#     MobilenetV3/expanded_conv_6 (--/32.08k params)
#       MobilenetV3/expanded_conv_6/depthwise (--/2.64k params)
#         MobilenetV3/expanded_conv_6/depthwise/BatchNorm (--/480 params)
#           MobilenetV3/expanded_conv_6/depthwise/BatchNorm/beta (240, 240/240 params)
#           MobilenetV3/expanded_conv_6/depthwise/BatchNorm/gamma (240, 240/240 params)
#         MobilenetV3/expanded_conv_6/depthwise/depthwise_weights (3x3x240x1, 2.16k/2.16k params)
#       MobilenetV3/expanded_conv_6/expand (--/10.08k params)
#         MobilenetV3/expanded_conv_6/expand/BatchNorm (--/480 params)
#           MobilenetV3/expanded_conv_6/expand/BatchNorm/beta (240, 240/240 params)
#           MobilenetV3/expanded_conv_6/expand/BatchNorm/gamma (240, 240/240 params)
#         MobilenetV3/expanded_conv_6/expand/weights (1x1x40x240, 9.60k/9.60k params)
#       MobilenetV3/expanded_conv_6/project (--/19.36k params)
#         MobilenetV3/expanded_conv_6/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_6/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_6/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_6/project/weights (1x1x240x80, 19.20k/19.20k params)
#     MobilenetV3/expanded_conv_7 (--/34.76k params)
#       MobilenetV3/expanded_conv_7/depthwise (--/2.20k params)
#         MobilenetV3/expanded_conv_7/depthwise/BatchNorm (--/400 params)
#           MobilenetV3/expanded_conv_7/depthwise/BatchNorm/beta (200, 200/200 params)
#           MobilenetV3/expanded_conv_7/depthwise/BatchNorm/gamma (200, 200/200 params)
#         MobilenetV3/expanded_conv_7/depthwise/depthwise_weights (3x3x200x1, 1.80k/1.80k params)
#       MobilenetV3/expanded_conv_7/expand (--/16.40k params)
#         MobilenetV3/expanded_conv_7/expand/BatchNorm (--/400 params)
#           MobilenetV3/expanded_conv_7/expand/BatchNorm/beta (200, 200/200 params)
#           MobilenetV3/expanded_conv_7/expand/BatchNorm/gamma (200, 200/200 params)
#         MobilenetV3/expanded_conv_7/expand/weights (1x1x80x200, 16.00k/16.00k params)
#       MobilenetV3/expanded_conv_7/project (--/16.16k params)
#         MobilenetV3/expanded_conv_7/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_7/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_7/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_7/project/weights (1x1x200x80, 16.00k/16.00k params)
#     MobilenetV3/expanded_conv_8 (--/31.99k params)
#       MobilenetV3/expanded_conv_8/depthwise (--/2.02k params)
#         MobilenetV3/expanded_conv_8/depthwise/BatchNorm (--/368 params)
#           MobilenetV3/expanded_conv_8/depthwise/BatchNorm/beta (184, 184/184 params)
#           MobilenetV3/expanded_conv_8/depthwise/BatchNorm/gamma (184, 184/184 params)
#         MobilenetV3/expanded_conv_8/depthwise/depthwise_weights (3x3x184x1, 1.66k/1.66k params)
#       MobilenetV3/expanded_conv_8/expand (--/15.09k params)
#         MobilenetV3/expanded_conv_8/expand/BatchNorm (--/368 params)
#           MobilenetV3/expanded_conv_8/expand/BatchNorm/beta (184, 184/184 params)
#           MobilenetV3/expanded_conv_8/expand/BatchNorm/gamma (184, 184/184 params)
#         MobilenetV3/expanded_conv_8/expand/weights (1x1x80x184, 14.72k/14.72k params)
#       MobilenetV3/expanded_conv_8/project (--/14.88k params)
#         MobilenetV3/expanded_conv_8/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_8/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_8/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_8/project/weights (1x1x184x80, 14.72k/14.72k params)
#     MobilenetV3/expanded_conv_9 (--/31.99k params)
#       MobilenetV3/expanded_conv_9/depthwise (--/2.02k params)
#         MobilenetV3/expanded_conv_9/depthwise/BatchNorm (--/368 params)
#           MobilenetV3/expanded_conv_9/depthwise/BatchNorm/beta (184, 184/184 params)
#           MobilenetV3/expanded_conv_9/depthwise/BatchNorm/gamma (184, 184/184 params)
#         MobilenetV3/expanded_conv_9/depthwise/depthwise_weights (3x3x184x1, 1.66k/1.66k params)
#       MobilenetV3/expanded_conv_9/expand (--/15.09k params)
#         MobilenetV3/expanded_conv_9/expand/BatchNorm (--/368 params)
#           MobilenetV3/expanded_conv_9/expand/BatchNorm/beta (184, 184/184 params)
#           MobilenetV3/expanded_conv_9/expand/BatchNorm/gamma (184, 184/184 params)
#         MobilenetV3/expanded_conv_9/expand/weights (1x1x80x184, 14.72k/14.72k params)
#       MobilenetV3/expanded_conv_9/project (--/14.88k params)
#         MobilenetV3/expanded_conv_9/project/BatchNorm (--/160 params)
#           MobilenetV3/expanded_conv_9/project/BatchNorm/beta (80, 80/80 params)
#           MobilenetV3/expanded_conv_9/project/BatchNorm/gamma (80, 80/80 params)
#         MobilenetV3/expanded_conv_9/project/weights (1x1x184x80, 14.72k/14.72k params)
#   aspp0 (--/123.39k params)
#     aspp0/BatchNorm (--/512 params)
#       aspp0/BatchNorm/beta (256, 256/256 params)
#       aspp0/BatchNorm/gamma (256, 256/256 params)
#     aspp0/weights (1x1x480x256, 122.88k/122.88k params)
#   concat_projection (--/131.58k params)
#     concat_projection/BatchNorm (--/512 params)
#       concat_projection/BatchNorm/beta (256, 256/256 params)
#       concat_projection/BatchNorm/gamma (256, 256/256 params)
#     concat_projection/weights (1x1x512x256, 131.07k/131.07k params)
#   image_pooling (--/123.39k params)
#     image_pooling/BatchNorm (--/512 params)
#       image_pooling/BatchNorm/beta (256, 256/256 params)
#       image_pooling/BatchNorm/gamma (256, 256/256 params)
#     image_pooling/weights (1x1x480x256, 122.88k/122.88k params)
#   logits (--/514 params)
#     logits/semantic (--/514 params)
#       logits/semantic/biases (2, 2/2 params)
#       logits/semantic/weights (1x1x256x2, 512/512 params)
#
# ======================End of Report==========================
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/2.89b flops)
#   concat_projection/Conv2D (285.47m/285.47m flops)
#   aspp0/Conv2D (267.63m/267.63m flops)
#   MobilenetV3/expanded_conv_11/project/Conv2D (163.92m/163.92m flops)
#   MobilenetV3/expanded_conv_11/expand/Conv2D (163.92m/163.92m flops)
#   MobilenetV3/expanded_conv_1/expand/Conv2D (135.27m/135.27m flops)
#   MobilenetV3/expanded_conv_10/project/Conv2D (117.09m/117.09m flops)
#   MobilenetV3/expanded_conv_14/expand/Conv2D (83.64m/83.64m flops)
#   MobilenetV3/expanded_conv_13/project/Conv2D (83.64m/83.64m flops)
#   MobilenetV3/expanded_conv_13/expand/Conv2D (83.64m/83.64m flops)
#   MobilenetV3/Conv_1/Conv2D (83.64m/83.64m flops)
#   MobilenetV3/expanded_conv_14/project/Conv2D (83.64m/83.64m flops)
#   MobilenetV3/expanded_conv_10/expand/Conv2D (83.64m/83.64m flops)
#   MobilenetV3/expanded_conv_12/expand/Conv2D (81.96m/81.96m flops)
#   MobilenetV3/expanded_conv_6/expand/Conv2D (81.12m/81.12m flops)
#   MobilenetV3/expanded_conv_12/project/Conv2D (58.54m/58.54m flops)
#   MobilenetV3/expanded_conv_3/expand/Conv2D (57.51m/57.51m flops)
#   MobilenetV3/expanded_conv_2/project/Conv2D (57.51m/57.51m flops)
#   MobilenetV3/expanded_conv_2/expand/Conv2D (57.51m/57.51m flops)
#   MobilenetV3/Conv/Conv2D (57.07m/57.07m flops)
#   MobilenetV3/expanded_conv_1/project/Conv2D (51.12m/51.12m flops)
#   MobilenetV3/expanded_conv_6/project/Conv2D (41.82m/41.82m flops)
#   MobilenetV3/expanded_conv_5/expand/Conv2D (40.56m/40.56m flops)
#   MobilenetV3/expanded_conv_5/project/Conv2D (40.56m/40.56m flops)
#   MobilenetV3/expanded_conv_4/project/Conv2D (40.56m/40.56m flops)
#   MobilenetV3/expanded_conv_4/expand/Conv2D (40.56m/40.56m flops)
#   MobilenetV3/expanded_conv_7/expand/Conv2D (34.85m/34.85m flops)
#   MobilenetV3/expanded_conv_7/project/Conv2D (34.85m/34.85m flops)
#   MobilenetV3/expanded_conv/project/Conv2D (33.82m/33.82m flops)
#   MobilenetV3/expanded_conv_9/expand/Conv2D (32.06m/32.06m flops)
# W1129 05:11:27.606449  9404 deprecation.py:323] From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1129 05:11:27.611447  9404 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W1129 05:11:29.974982  9404 module_wrapper.py:139] From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1129 05:11:30.130934  9404 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From deeplab/eval.py:150: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1129 05:11:30.158925  9404 deprecation.py:323] From deeplab/eval.py:150: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# W1129 05:11:30.159925  9404 module_wrapper.py:139] From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W1129 05:11:30.225904  9404 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# W1129 05:11:30.229903  9404 module_wrapper.py:139] From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# W1129 05:11:30.277886  9404 module_wrapper.py:139] From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# W1129 05:11:30.306878  9404 module_wrapper.py:139] From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# W1129 05:11:30.395849  9404 module_wrapper.py:139] From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# W1129 05:11:30.407846  9404 module_wrapper.py:139] From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# W1129 05:11:30.420841  9404 module_wrapper.py:139] From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# W1129 05:11:30.433837  9404 module_wrapper.py:139] From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:218: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1129 05:11:30.595785  9404 module_wrapper.py:139] From deeplab/eval.py:218: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From deeplab/eval.py:219: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# W1129 05:11:30.596784  9404 deprecation.py:323] From deeplab/eval.py:219: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# WARNING:tensorflow:From deeplab/eval.py:222: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W1129 05:11:30.668763  9404 module_wrapper.py:139] From deeplab/eval.py:222: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From deeplab/eval.py:235: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1129 05:11:30.669762  9404 module_wrapper.py:139] From deeplab/eval.py:235: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From deeplab/eval.py:236: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W1129 05:11:30.669762  9404 deprecation.py:323] From deeplab/eval.py:236: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W1129 05:11:30.675760  9404 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 20 ops no flops stats due to incomplete shapes.
# 20 ops no flops stats due to incomplete shapes.
# INFO:tensorflow:Waiting for new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large
# I1129 05:11:37.649662  9404 evaluation.py:189] Waiting for new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large
# INFO:tensorflow:Found new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large\model.ckpt-0
# I1129 05:11:37.653647  9404 evaluation.py:198] Found new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large\model.ckpt-0
# INFO:tensorflow:Graph was finalized.
# I1129 05:11:38.511369  9404 monitored_session.py:240] Graph was finalized.
# 2022-11-29 05:11:38.512079: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2022-11-29 05:11:38.514485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-11-29 05:11:38.514510: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-11-29 05:11:38.514517: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-11-29 05:11:38.514523: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-11-29 05:11:38.514529: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-11-29 05:11:38.514534: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-11-29 05:11:38.514540: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-11-29 05:11:38.514545: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-11-29 05:11:38.514562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-11-29 05:11:39.978180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-29 05:11:39.978196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-11-29 05:11:39.978211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-11-29 05:11:39.978325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6665 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large\model.ckpt-0
# I1129 05:11:39.982138  9404 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mn3_large\model.ckpt-0
# 2022-11-29 05:11:40.449551: W tensorflow/core/framework/op_kernel.cc:1651] OP_REQUIRES failed at save_restore_v2_ops.cc:184 : Not found: Key concat_projection/BatchNorm/beta not found in checkpoint
# Traceback (most recent call last):
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\client\session.py", line 1365, in _do_call
#     return fn(*args)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\client\session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\client\session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.NotFoundError: Key concat_projection/BatchNorm/beta not found in checkpoint
# 	 [[{{node save/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
#   MobilenetV3/expanded_conv_10/depthwise/depthwise_weights/Initializer/truncated_normal (4.32k/8.64k flops)
#     MobilenetV3/expanded_conv_10/depthwise/depthwise_weights/Initializer/truncated_normal/mul (4.32k/4.32k flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/weights/Initializer/truncated_normal (3.84k/7.68k flops)
#     MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/weights/Initializer/truncated_normal/mul (3.84k/3.84k flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv/Conv2D (7.68k/7.68k flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/Conv2D (7.68k/7.68k flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/weights/Initializer/truncated_normal (3.84k/7.68k flops)
#     MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/weights/Initializer/truncated_normal/mul (3.84k/3.84k flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv/weights/Initializer/truncated_normal (3.84k/7.68k flops)
#     MobilenetV3/expanded_conv_5/squeeze_excite/Conv/weights/Initializer/truncated_normal/mul (3.84k/3.84k flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv/Conv2D (7.68k/7.68k flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv/weights/Initializer/truncated_normal (3.84k/7.68k flops)
#     MobilenetV3/expanded_conv_4/squeeze_excite/Conv/weights/Initializer/truncated_normal/mul (3.84k/3.84k flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/Conv2D (7.68k/7.68k flops)
#   MobilenetV3/expanded_conv_4/depthwise/depthwise_weights/Initializer/truncated_normal (3.00k/6.00k flops)
#     MobilenetV3/expanded_conv_4/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.00k/3.00k flops)
#   MobilenetV3/expanded_conv_5/depthwise/depthwise_weights/Initializer/truncated_normal (3.00k/6.00k flops)
#     MobilenetV3/expanded_conv_5/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.00k/3.00k flops)
#   MobilenetV3/expanded_conv_3/project/weights/Initializer/truncated_normal (2.88k/5.76k flops)
#     MobilenetV3/expanded_conv_3/project/weights/Initializer/truncated_normal/mul (2.88k/2.88k flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/kernel/Regularizer/l2_regularizer (1/5.18k flops)
#     MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/kernel/Regularizer/l2_regularizer/L2Loss (5.18k/5.18k flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv/kernel/Regularizer/l2_regularizer (1/5.18k flops)
#     MobilenetV3/expanded_conv_3/squeeze_excite/Conv/kernel/Regularizer/l2_regularizer/L2Loss (5.18k/5.18k flops)
#   MobilenetV3/expanded_conv_3/expand/kernel/Regularizer/l2_regularizer (1/5.18k flops)
#     MobilenetV3/expanded_conv_3/expand/kernel/Regularizer/l2_regularizer/L2Loss (5.18k/5.18k flops)
#   MobilenetV3/expanded_conv_2/expand/kernel/Regularizer/l2_regularizer (1/5.18k flops)
#     MobilenetV3/expanded_conv_2/expand/kernel/Regularizer/l2_regularizer/L2Loss (5.18k/5.18k flops)
#   MobilenetV3/expanded_conv_2/project/kernel/Regularizer/l2_regularizer (1/5.18k flops)
#     MobilenetV3/expanded_conv_2/project/kernel/Regularizer/l2_regularizer/L2Loss (5.18k/5.18k flops)
#   MobilenetV3/expanded_conv_1/project/kernel/Regularizer/l2_regularizer (1/4.61k flops)
#     MobilenetV3/expanded_conv_1/project/kernel/Regularizer/l2_regularizer/L2Loss (4.61k/4.61k flops)
#   MobilenetV3/expanded_conv_6/depthwise/depthwise_weights/Initializer/truncated_normal (2.16k/4.32k flops)
#     MobilenetV3/expanded_conv_6/depthwise/depthwise_weights/Initializer/truncated_normal/mul (2.16k/2.16k flops)
#   MobilenetV3/expanded_conv_3/depthwise/depthwise_weights/Initializer/truncated_normal (1.80k/3.60k flops)
#     MobilenetV3/expanded_conv_3/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.80k/1.80k flops)
#   MobilenetV3/expanded_conv_7/depthwise/depthwise_weights/Initializer/truncated_normal (1.80k/3.60k flops)
#     MobilenetV3/expanded_conv_7/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.80k/1.80k flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV3/expanded_conv_3/expand/weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV3/expanded_conv_3/expand/weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV3/expanded_conv_2/expand/weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV3/expanded_conv_2/expand/weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV3/expanded_conv_2/project/weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV3/expanded_conv_2/project/weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv/Conv2D (3.46k/3.46k flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv/weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV3/expanded_conv_3/squeeze_excite/Conv/weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/Conv2D (3.46k/3.46k flops)
#   MobilenetV3/expanded_conv_8/depthwise/depthwise_weights/Initializer/truncated_normal (1.66k/3.31k flops)
#     MobilenetV3/expanded_conv_8/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.66k/1.66k flops)
#   MobilenetV3/expanded_conv_9/depthwise/depthwise_weights/Initializer/truncated_normal (1.66k/3.31k flops)
#     MobilenetV3/expanded_conv_9/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.66k/1.66k flops)
#   MobilenetV3/expanded_conv_1/expand/kernel/Regularizer/l2_regularizer (1/3.07k flops)
#     MobilenetV3/expanded_conv_1/expand/kernel/Regularizer/l2_regularizer/L2Loss (3.07k/3.07k flops)
#   MobilenetV3/expanded_conv_1/project/weights/Initializer/truncated_normal (1.54k/3.07k flops)
#     MobilenetV3/expanded_conv_1/project/weights/Initializer/truncated_normal/mul (1.54k/1.54k flops)
#   logits/semantic/BiasAdd (2.18k/2.18k flops)
#   MobilenetV3/expanded_conv_1/expand/weights/Initializer/truncated_normal (1.02k/2.05k flops)
#     MobilenetV3/expanded_conv_1/expand/weights/Initializer/truncated_normal/mul (1.02k/1.02k flops)
#   logits/semantic/kernel/Regularizer/l2_regularizer (1/1.54k flops)
#     logits/semantic/kernel/Regularizer/l2_regularizer/L2Loss (1.53k/1.53k flops)
#   MobilenetV3/expanded_conv_2/depthwise/depthwise_weights/Initializer/truncated_normal (648/1.30k flops)
#     MobilenetV3/expanded_conv_2/depthwise/depthwise_weights/Initializer/truncated_normal/mul (648/648 flops)
#   MobilenetV3/Conv/kernel/Regularizer/l2_regularizer (1/1.30k flops)
#     MobilenetV3/Conv/kernel/Regularizer/l2_regularizer/L2Loss (1.29k/1.29k flops)
#   MobilenetV3/expanded_conv_1/depthwise/depthwise_weights/Initializer/truncated_normal (576/1.15k flops)
#     MobilenetV3/expanded_conv_1/depthwise/depthwise_weights/Initializer/truncated_normal/mul (576/576 flops)
#   logits/semantic/weights/Initializer/truncated_normal (512/1.02k flops)
#     logits/semantic/weights/Initializer/truncated_normal/mul (512/512 flops)
#   MobilenetV3/Conv/weights/Initializer/truncated_normal (432/864 flops)
#     MobilenetV3/Conv/weights/Initializer/truncated_normal/mul (432/432 flops)
#   MobilenetV3/expanded_conv/project/kernel/Regularizer/l2_regularizer (1/768 flops)
#     MobilenetV3/expanded_conv/project/kernel/Regularizer/l2_regularizer/L2Loss (767/767 flops)
#   MobilenetV3/expanded_conv_11/squeeze_excite/Conv_1/mul (672/672 flops)
#   MobilenetV3/expanded_conv_11/squeeze_excite/Conv_1/BiasAdd (672/672 flops)
#   MobilenetV3/expanded_conv/project/weights/Initializer/truncated_normal (256/512 flops)
#     MobilenetV3/expanded_conv/project/weights/Initializer/truncated_normal/mul (256/256 flops)
#   MobilenetV3/expanded_conv_14/squeeze_excite/Conv_1/mul (480/480 flops)
#   MobilenetV3/expanded_conv_13/squeeze_excite/Conv_1/BiasAdd (480/480 flops)
#   MobilenetV3/expanded_conv_13/squeeze_excite/Conv_1/mul (480/480 flops)
#   MobilenetV3/expanded_conv_10/squeeze_excite/Conv_1/BiasAdd (480/480 flops)
#   MobilenetV3/expanded_conv_10/squeeze_excite/Conv_1/mul (480/480 flops)
#   MobilenetV3/expanded_conv_14/squeeze_excite/Conv_1/BiasAdd (480/480 flops)
#   MobilenetV3/expanded_conv_12/squeeze_excite/Conv_1/BiasAdd (336/336 flops)
#   MobilenetV3/expanded_conv_12/squeeze_excite/Conv_1/mul (336/336 flops)
#   MobilenetV3/expanded_conv/depthwise/depthwise_weights/Initializer/truncated_normal (144/288 flops)
#     MobilenetV3/expanded_conv/depthwise/depthwise_weights/Initializer/truncated_normal/mul (144/144 flops)
#   MobilenetV3/expanded_conv_11/squeeze_excite/Conv/BiasAdd (168/168 flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/BiasAdd (120/120 flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/BiasAdd (120/120 flops)
#   MobilenetV3/expanded_conv_14/squeeze_excite/Conv/BiasAdd (120/120 flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv_1/mul (120/120 flops)
#   MobilenetV3/expanded_conv_13/squeeze_excite/Conv/BiasAdd (120/120 flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv_1/mul (120/120 flops)
#   MobilenetV3/expanded_conv_10/squeeze_excite/Conv/BiasAdd (120/120 flops)
#   MobilenetV3/expanded_conv_12/squeeze_excite/Conv/BiasAdd (88/88 flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/BiasAdd (72/72 flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv_1/mul (72/72 flops)
#   MobilenetV3/expanded_conv_5/squeeze_excite/Conv/BiasAdd (32/32 flops)
#   MobilenetV3/expanded_conv_4/squeeze_excite/Conv/BiasAdd (32/32 flops)
#   MobilenetV3/expanded_conv_3/squeeze_excite/Conv/BiasAdd (24/24 flops)
#   mean_iou/AssignAdd (4/4 flops)
#   mean_iou/sub (2/2 flops)
#   mean_iou/NotEqual (2/2 flops)
#   mean_iou/Greater (2/2 flops)
#   mean_iou/Sum_1 (2/2 flops)
#   mean_iou/Sum (2/2 flops)
#   mean_iou/div (2/2 flops)
#   false_negatives_1/AssignAdd (1/1 flops)
#   false_negatives/AssignAdd (1/1 flops)
#   mean_iou/Greater_1 (1/1 flops)
#   Greater (1/1 flops)
#   recall/div_1 (1/1 flops)
#   recall/true_positives/AssignAdd (1/1 flops)
#   recall/div (1/1 flops)
#   recall/Greater_1 (1/1 flops)
#   recall/Greater (1/1 flops)
#   recall/false_negatives/AssignAdd (1/1 flops)
#   true_negatives/AssignAdd (1/1 flops)
#   accuracy/AssignAdd (1/1 flops)
#   accuracy/AssignAdd_1 (1/1 flops)
#   accuracy/Maximum (1/1 flops)
#   true_negatives_1/AssignAdd (1/1 flops)
#   Greater_1 (1/1 flops)
#   accuracy/Maximum_1 (1/1 flops)
#   precision/false_positives/AssignAdd (1/1 flops)
#   true_negatives_2/AssignAdd (1/1 flops)
#   precision/div_1 (1/1 flops)
#   precision/div (1/1 flops)
#   precision/Greater_1 (1/1 flops)
#   true_positives/AssignAdd (1/1 flops)
#   precision/Greater (1/1 flops)
#   false_positives_2/AssignAdd (1/1 flops)
#   mean_iou/truediv (1/1 flops)
#   true_positives_1/AssignAdd (1/1 flops)
#   precision/true_positives/AssignAdd (1/1 flops)
#   mean_iou/mean_iou (1/1 flops)
#   mean_iou/Sum_2 (1/1 flops)
#   true_positives_2/AssignAdd (1/1 flops)
#   false_positives_1/AssignAdd (1/1 flops)
#   false_positives/AssignAdd (1/1 flops)
#   false_negatives_2/AssignAdd (1/1 flops)
#   truediv (1/1 flops)
#   truediv_1 (1/1 flops)
#
# ======================End of Report==========================
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAZZZZ
# Key concat_projection/BatchNorm/beta not found in checkpoint
# 	 [[node save/RestoreV2 (defined at G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\framework\ops.py:1748) ]]
#
# Original stack trace for 'save/RestoreV2':
#   File "deeplab/eval.py", line 254, in <module>
#     tf.app.run()
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\platform\app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\absl\app.py", line 312, in run
#     _run_main(main, args)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\absl\app.py", line 258, in _run_main
#     sys.exit(main(argv))
#   File "deeplab/eval.py", line 247, in main
#     eval_interval_secs=FLAGS.eval_interval_secs)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\training\python\training\evaluation.py", line 448, in evaluate_repeatedly
#     session_creator=session_creator, hooks=hooks) as session:
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 1014, in __init__
#     stop_grace_period_secs=stop_grace_period_secs)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 725, in __init__
#     self._sess = _RecoverableSession(self._coordinated_creator)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 1207, in __init__
#     _WrappedSession.__init__(self, self._create_session())
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 1212, in _create_session
#     return self._sess_creator.create_session()
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 878, in create_session
#     self.tf_sess = self._session_creator.create_session()
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 638, in create_session
#     self._scaffold.finalize()
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\monitored_session.py", line 229, in finalize
#     self._saver = training_saver._get_saver_or_default()  # pylint: disable=protected-access
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 599, in _get_saver_or_default
#     saver = Saver(sharded=True, allow_empty=True)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 828, in __init__
#     self.build()
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 840, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 878, in _build
#     build_restore=build_restore)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 502, in _build_internal
#     restore_sequentially, reshape)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 381, in _AddShardedRestoreOps
#     name="restore_shard"))
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\training\saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\framework\op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
# Proper MobilenetEdgeTPU Evaluation
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations/Evaluation_mnetpu"
# tensorboard --logdir="G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint"

# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_edgetpu" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mnetpu \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
# Out:
# G:\segmentation_master

# %%
# Proper Resnet Evaluation
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations\Evaluation_resnet"

# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="resnet_v1_50_beta" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --atrous_rates=6 \
  --atrous_rates=12 \
  --atrous_rates=18 \
  --output_stride=16 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_resnet \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_resnet \
  --dataset_dir=training_environment/ade_indoor/TFRecord
# Out:
# G:\segmentation_master

# %% [markdown]
# ## Evaluating through many checkpoints and pickling

# %%
# Proper MobilenetEdgeTPU Evaluation
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations/Evaluation_mnetpu_test"

# %cd G:\segmentation_master
# tensorboard --logdir="G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint"

# !python deeplab/custom_eval.py \
  --logtostderr \
  --eval_split="train" \
  --model_variant="mobilenet_edgetpu" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_misc \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
# Out:
# G:\segmentation_master
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/3.60m params)
#   MobilenetEdgeTPU (--/2.81m params)
#     MobilenetEdgeTPU/Conv (--/928 params)
#       MobilenetEdgeTPU/Conv/BatchNorm (--/64 params)
#         MobilenetEdgeTPU/Conv/BatchNorm/beta (32, 32/32 params)
#         MobilenetEdgeTPU/Conv/BatchNorm/gamma (32, 32/32 params)
#       MobilenetEdgeTPU/Conv/weights (3x3x3x32, 864/864 params)
#     MobilenetEdgeTPU/Conv_1 (--/248.32k params)
#       MobilenetEdgeTPU/Conv_1/BatchNorm (--/2.56k params)
# 2022-12-06 17:08:09.848617: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:258: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:93: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1206 17:08:16.972924  8524 module_wrapper.py:139] From deeplab/custom_eval.py:93: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:93: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1206 17:08:16.972924  8524 module_wrapper.py:139] From deeplab/custom_eval.py:93: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:110: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1206 17:08:16.972924  8524 module_wrapper.py:139] From deeplab/custom_eval.py:110: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:111: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1206 17:08:16.972924  8524 module_wrapper.py:139] From deeplab/custom_eval.py:111: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Evaluating on train set
# I1206 17:08:16.972924  8524 custom_eval.py:111] Evaluating on train set
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1206 17:08:16.972924  8524 module_wrapper.py:139] From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1206 17:08:17.172907  8524 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1206 17:08:17.172907  8524 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# 2022-12-06 17:08:17.497231: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2022-12-06 17:08:17.512619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 17:08:17.512641: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 17:08:17.731170: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 17:08:17.970653: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 17:08:17.998583: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 17:08:18.235424: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 17:08:18.469156: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 17:08:18.687282: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 17:08:18.687358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W1206 17:08:19.058746  8524 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W1206 17:08:21.519495  8524 deprecation.py:323] From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Performing single-scale test.
# I1206 17:08:21.549493  8524 custom_eval.py:129] Performing single-scale test.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1206 17:08:21.549493  8524 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#         MobilenetEdgeTPU/Conv_1/BatchNorm/beta (1280, 1.28k/1.28k params)
#         MobilenetEdgeTPU/Conv_1/BatchNorm/gamma (1280, 1.28k/1.28k params)
#       MobilenetEdgeTPU/Conv_1/weights (1x1x192x1280, 245.76k/245.76k params)
#     MobilenetEdgeTPU/expanded_conv (--/544 params)
#       MobilenetEdgeTPU/expanded_conv/project (--/544 params)
#         MobilenetEdgeTPU/expanded_conv/project/BatchNorm (--/32 params)
#           MobilenetEdgeTPU/expanded_conv/project/BatchNorm/beta (16, 16/16 params)
#           MobilenetEdgeTPU/expanded_conv/project/BatchNorm/gamma (16, 16/16 params)
#         MobilenetEdgeTPU/expanded_conv/project/weights (1x1x32x16, 512/512 params)
#     MobilenetEdgeTPU/expanded_conv_1 (--/22.85k params)
#       MobilenetEdgeTPU/expanded_conv_1/expand (--/18.69k params)
#         MobilenetEdgeTPU/expanded_conv_1/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_1/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_1/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_1/expand/weights (3x3x16x128, 18.43k/18.43k params)
#       MobilenetEdgeTPU/expanded_conv_1/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_1/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_1/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_1/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_1/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_10 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_10/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_10/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_10/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_10/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_10/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_10/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_10/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_10/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_10/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_10/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_10/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_10/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_10/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_10/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_10/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_11 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_11/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_11/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_11/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_11/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_11/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_11/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_11/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_11/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_11/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_11/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_11/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_11/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_11/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_11/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_11/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_12 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_12/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_12/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_12/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_12/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_12/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_12/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_12/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_12/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_12/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_12/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_12/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_12/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_12/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_12/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_12/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_13 (--/157.63k params)
#       MobilenetEdgeTPU/expanded_conv_13/depthwise (--/8.45k params)
#         MobilenetEdgeTPU/expanded_conv_13/depthwise/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_13/depthwise/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_13/depthwise/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_13/depthwise/depthwise_weights (3x3x768x1, 6.91k/6.91k params)
#       MobilenetEdgeTPU/expanded_conv_13/expand (--/75.26k params)
#         MobilenetEdgeTPU/expanded_conv_13/expand/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_13/expand/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_13/expand/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_13/expand/weights (1x1x96x768, 73.73k/73.73k params)
#       MobilenetEdgeTPU/expanded_conv_13/project (--/73.92k params)
#         MobilenetEdgeTPU/expanded_conv_13/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_13/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_13/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_13/project/weights (1x1x768x96, 73.73k/73.73k params)
#     MobilenetEdgeTPU/expanded_conv_14 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_14/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_14/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_14/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_14/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_14/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_14/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_14/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_14/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_14/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_14/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_14/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_14/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_14/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_14/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_14/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_15 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_15/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_15/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_15/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_15/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_15/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_15/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_15/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_15/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_15/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_15/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_15/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_15/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_15/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_15/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_15/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_16 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_16/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_16/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_16/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_16/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_16/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_16/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_16/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_16/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_16/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_16/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_16/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_16/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_16/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_16/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_16/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_17 (--/219.20k params)
#       MobilenetEdgeTPU/expanded_conv_17/depthwise (--/20.74k params)
#         MobilenetEdgeTPU/expanded_conv_17/depthwise/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_17/depthwise/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_17/depthwise/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_17/depthwise/depthwise_weights (5x5x768x1, 19.20k/19.20k params)
#       MobilenetEdgeTPU/expanded_conv_17/expand (--/75.26k params)
#         MobilenetEdgeTPU/expanded_conv_17/expand/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_17/expand/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_17/expand/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_17/expand/weights (1x1x96x768, 73.73k/73.73k params)
#       MobilenetEdgeTPU/expanded_conv_17/project (--/123.20k params)
#         MobilenetEdgeTPU/expanded_conv_17/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_17/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_17/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_17/project/weights (1x1x768x160, 122.88k/122.88k params)
#     MobilenetEdgeTPU/expanded_conv_18 (--/223.68k params)
#       MobilenetEdgeTPU/expanded_conv_18/depthwise (--/17.28k params)
#         MobilenetEdgeTPU/expanded_conv_18/depthwise/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_18/depthwise/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_18/depthwise/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_18/depthwise/depthwise_weights (5x5x640x1, 16.00k/16.00k params)
#       MobilenetEdgeTPU/expanded_conv_18/expand (--/103.68k params)
#         MobilenetEdgeTPU/expanded_conv_18/expand/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_18/expand/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_18/expand/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_18/expand/weights (1x1x160x640, 102.40k/102.40k params)
#       MobilenetEdgeTPU/expanded_conv_18/project (--/102.72k params)
#         MobilenetEdgeTPU/expanded_conv_18/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_18/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_18/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_18/project/weights (1x1x640x160, 102.40k/102.40k params)
#     MobilenetEdgeTPU/expanded_conv_19 (--/223.68k params)
#       MobilenetEdgeTPU/expanded_conv_19/depthwise (--/17.28k params)
#         MobilenetEdgeTPU/expanded_conv_19/depthwise/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_19/depthwise/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_19/depthwise/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_19/depthwise/depthwise_weights (5x5x640x1, 16.00k/16.00k params)
#       MobilenetEdgeTPU/expanded_conv_19/expand (--/103.68k params)
#         MobilenetEdgeTPU/expanded_conv_19/expand/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_19/expand/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_19/expand/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_19/expand/weights (1x1x160x640, 102.40k/102.40k params)
#       MobilenetEdgeTPU/expanded_conv_19/project (--/102.72k params)
#         MobilenetEdgeTPU/expanded_conv_19/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_19/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_19/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_19/project/weights (1x1x640x160, 102.40k/102.40k params)
#     MobilenetEdgeTPU/expanded_conv_2 (--/41.28k params)
#       MobilenetEdgeTPU/expanded_conv_2/expand (--/37.12k params)
#         MobilenetEdgeTPU/expanded_conv_2/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_2/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_2/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_2/expand/weights (3x3x32x128, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_2/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_2/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_2/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_2/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_2/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_20 (--/223.68k params)
#       MobilenetEdgeTPU/expanded_conv_20/depthwise (--/17.28k params)
#         MobilenetEdgeTPU/expanded_conv_20/depthwise/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_20/depthwise/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_20/depthwise/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_20/depthwise/depthwise_weights (5x5x640x1, 16.00k/16.00k params)
#       MobilenetEdgeTPU/expanded_conv_20/expand (--/103.68k params)
#         MobilenetEdgeTPU/expanded_conv_20/expand/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_20/expand/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_20/expand/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_20/expand/weights (1x1x160x640, 102.40k/102.40k params)
#       MobilenetEdgeTPU/expanded_conv_20/project (--/102.72k params)
#         MobilenetEdgeTPU/expanded_conv_20/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_20/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_20/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_20/project/weights (1x1x640x160, 102.40k/102.40k params)
#     MobilenetEdgeTPU/expanded_conv_21 (--/467.58k params)
#       MobilenetEdgeTPU/expanded_conv_21/depthwise (--/14.08k params)
#         MobilenetEdgeTPU/expanded_conv_21/depthwise/BatchNorm (--/2.56k params)
#           MobilenetEdgeTPU/expanded_conv_21/depthwise/BatchNorm/beta (1280, 1.28k/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_21/depthwise/BatchNorm/gamma (1280, 1.28k/1.28k params)
#         MobilenetEdgeTPU/expanded_conv_21/depthwise/depthwise_weights (3x3x1280x1, 11.52k/11.52k params)
#       MobilenetEdgeTPU/expanded_conv_21/expand (--/207.36k params)
#         MobilenetEdgeTPU/expanded_conv_21/expand/BatchNorm (--/2.56k params)
#           MobilenetEdgeTPU/expanded_conv_21/expand/BatchNorm/beta (1280, 1.28k/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_21/expand/BatchNorm/gamma (1280, 1.28k/1.28k params)
#         MobilenetEdgeTPU/expanded_conv_21/expand/weights (1x1x160x1280, 204.80k/204.80k params)
#       MobilenetEdgeTPU/expanded_conv_21/project (--/246.14k params)
#         MobilenetEdgeTPU/expanded_conv_21/project/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_21/project/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_21/project/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_21/project/weights (1x1x1280x192, 245.76k/245.76k params)
#     MobilenetEdgeTPU/expanded_conv_3 (--/41.28k params)
#       MobilenetEdgeTPU/expanded_conv_3/expand (--/37.12k params)
#         MobilenetEdgeTPU/expanded_conv_3/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_3/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_3/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_3/expand/weights (3x3x32x128, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_3/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_3/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_3/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_3/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_3/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_4 (--/41.28k params)
#       MobilenetEdgeTPU/expanded_conv_4/expand (--/37.12k params)
#         MobilenetEdgeTPU/expanded_conv_4/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_4/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_4/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_4/expand/weights (3x3x32x128, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_4/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_4/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_4/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_4/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_4/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_5 (--/86.62k params)
#       MobilenetEdgeTPU/expanded_conv_5/expand (--/74.24k params)
#         MobilenetEdgeTPU/expanded_conv_5/expand/BatchNorm (--/512 params)
#           MobilenetEdgeTPU/expanded_conv_5/expand/BatchNorm/beta (256, 256/256 params)
#           MobilenetEdgeTPU/expanded_conv_5/expand/BatchNorm/gamma (256, 256/256 params)
#         MobilenetEdgeTPU/expanded_conv_5/expand/weights (3x3x32x256, 73.73k/73.73k params)
#       MobilenetEdgeTPU/expanded_conv_5/project (--/12.38k params)
#         MobilenetEdgeTPU/expanded_conv_5/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_5/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_5/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_5/project/weights (1x1x256x48, 12.29k/12.29k params)
#     MobilenetEdgeTPU/expanded_conv_6 (--/92.64k params)
#       MobilenetEdgeTPU/expanded_conv_6/expand (--/83.33k params)
#         MobilenetEdgeTPU/expanded_conv_6/expand/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_6/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_6/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_6/expand/weights (3x3x48x192, 82.94k/82.94k params)
#       MobilenetEdgeTPU/expanded_conv_6/project (--/9.31k params)
#         MobilenetEdgeTPU/expanded_conv_6/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_6/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_6/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_6/project/weights (1x1x192x48, 9.22k/9.22k params)
#     MobilenetEdgeTPU/expanded_conv_7 (--/92.64k params)
#       MobilenetEdgeTPU/expanded_conv_7/expand (--/83.33k params)
#         MobilenetEdgeTPU/expanded_conv_7/expand/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_7/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_7/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_7/expand/weights (3x3x48x192, 82.94k/82.94k params)
#       MobilenetEdgeTPU/expanded_conv_7/project (--/9.31k params)
#         MobilenetEdgeTPU/expanded_conv_7/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_7/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_7/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_7/project/weights (1x1x192x48, 9.22k/9.22k params)
#     MobilenetEdgeTPU/expanded_conv_8 (--/92.64k params)
#       MobilenetEdgeTPU/expanded_conv_8/expand (--/83.33k params)
#         MobilenetEdgeTPU/expanded_conv_8/expand/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_8/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_8/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_8/expand/weights (3x3x48x192, 82.94k/82.94k params)
#       MobilenetEdgeTPU/expanded_conv_8/project (--/9.31k params)
#         MobilenetEdgeTPU/expanded_conv_8/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_8/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_8/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_8/project/weights (1x1x192x48, 9.22k/9.22k params)
#     MobilenetEdgeTPU/expanded_conv_9 (--/60.48k params)
#       MobilenetEdgeTPU/expanded_conv_9/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_9/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_9/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_9/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_9/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_9/expand (--/19.20k params)
#         MobilenetEdgeTPU/expanded_conv_9/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_9/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_9/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_9/expand/weights (1x1x48x384, 18.43k/18.43k params)
#       MobilenetEdgeTPU/expanded_conv_9/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_9/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_9/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_9/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_9/project/weights (1x1x384x96, 36.86k/36.86k params)
#   aspp0 (--/328.19k params)
#     aspp0/BatchNorm (--/512 params)
#       aspp0/BatchNorm/beta (256, 256/256 params)
#       aspp0/BatchNorm/gamma (256, 256/256 params)
#     aspp0/weights (1x1x1280x256, 327.68k/327.68k params)
#   concat_projection (--/131.58k params)
#     concat_projection/BatchNorm (--/512 params)
#       concat_projection/BatchNorm/beta (256, 256/256 params)
#       concat_projection/BatchNorm/gamma (256, 256/256 params)
#     concat_projection/weights (1x1x512x256, 131.07k/131.07k params)
#   image_pooling (--/328.19k params)
#     image_pooling/BatchNorm (--/512 params)
#       image_pooling/BatchNorm/beta (256, 256/256 params)
#       image_pooling/BatchNorm/gamma (256, 256/256 params)
#     image_pooling/weights (1x1x1280x256, 327.68k/327.68k params)
#   logits (--/514 params)
#     logits/semantic (--/514 params)
#       logits/semantic/biases (2, 2/2 params)
#       logits/semantic/weights (1x1x256x2, 512/512 params)
#
# ======================End of Report==========================
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/14.17b flops)
#   MobilenetEdgeTPU/expanded_conv_4/expand/Conv2D (1.23b/1.23b flops)
#   MobilenetEdgeTPU/expanded_conv_2/expand/Conv2D (1.23b/1.23b flops)
#   MobilenetEdgeTPU/expanded_conv_3/expand/Conv2D (1.23b/1.23b flops)
#   aspp0/Conv2D (713.69m/713.69m flops)
#   MobilenetEdgeTPU/expanded_conv_8/expand/Conv2D (700.88m/700.88m flops)
#   MobilenetEdgeTPU/expanded_conv_6/expand/Conv2D (700.88m/700.88m flops)
#   MobilenetEdgeTPU/expanded_conv_7/expand/Conv2D (700.88m/700.88m flops)
#   MobilenetEdgeTPU/expanded_conv_5/expand/Conv2D (623.00m/623.00m flops)
#   MobilenetEdgeTPU/expanded_conv_1/expand/Conv2D (613.45m/613.45m flops)
#   MobilenetEdgeTPU/expanded_conv_21/project/Conv2D (535.27m/535.27m flops)
#   MobilenetEdgeTPU/Conv_1/Conv2D (535.27m/535.27m flops)
#   MobilenetEdgeTPU/expanded_conv_21/expand/Conv2D (446.05m/446.05m flops)
#   concat_projection/Conv2D (285.47m/285.47m flops)
#   MobilenetEdgeTPU/expanded_conv_17/project/Conv2D (267.63m/267.63m flops)
#   MobilenetEdgeTPU/expanded_conv_20/expand/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_18/expand/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_19/project/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_19/expand/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_20/project/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_18/project/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_13/expand/Conv2D (160.58m/160.58m flops)
#   MobilenetEdgeTPU/expanded_conv_13/project/Conv2D (160.58m/160.58m flops)
#   MobilenetEdgeTPU/expanded_conv_17/expand/Conv2D (160.58m/160.58m flops)
#   MobilenetEdgeTPU/expanded_conv_9/expand/Conv2D (155.75m/155.75m flops)
#   MobilenetEdgeTPU/expanded_conv_4/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/expanded_conv_2/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/expanded_conv_3/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/expanded_conv_1/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/Conv/Conv2D (114.13m/114.13m flops)
#   MobilenetEdgeTPU/expanded_conv_5/project/Conv2D (103.83m/103.83m flops)
#   MobilenetEdgeTPU/expanded_conv_15/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_10/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_11/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_11/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_12/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_12/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_10/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_15/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_9/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_16/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_14/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_14/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_16/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_6/project/Conv2D (77.88m/77.88m flops)
#   MobilenetEdgeTPU/expanded_conv_8/project/Conv2D (77.88m/77.88m flops)
#   MobilenetEdgeTPU/expanded_conv_7/project/Conv2D (77.88m/77.88m flops)
#   MobilenetEdgeTPU/expanded_conv/project/Conv2D (67.63m/67.63m flops)
#   MobilenetEdgeTPU/expanded_conv_17/depthwise/depthwise (41.82m/41.82m flops)
#   MobilenetEdgeTPU/expanded_conv_18/depthwise/depthwise (36.99m/36.99m flops)
#   MobilenetEdgeTPU/expanded_conv_19/depthwise/depthwise (36.99m/36.99m flops)
#   MobilenetEdgeTPU/expanded_conv_20/depthwise/depthwise (36.99m/36.99m flops)
#   MobilenetEdgeTPU/expanded_conv_21/depthwise/depthwise (26.63m/26.63m flops)
#   MobilenetEdgeTPU/expanded_conv_13/depthwise/depthwise (15.05m/15.05m flops)
#   MobilenetEdgeTPU/expanded_conv_14/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_12/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_10/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_9/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_15/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_16/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_11/depthwise/depthwise (7.53m/7.53m flops)
#   Softmax (2.63m/2.63m flops)
#   AvgPool2D/AvgPool (1.39m/1.39m flops)
#   logits/semantic/Conv2D (1.12m/1.12m flops)
#   aspp0/kernel/Regularizer/l2_regularizer (1/983.04k flops)
#     aspp0/kernel/Regularizer/l2_regularizer/L2Loss (983.04k/983.04k flops)
#   image_pooling/kernel/Regularizer/l2_regularizer (1/983.04k flops)
#     image_pooling/kernel/Regularizer/l2_regularizer/L2Loss (983.04k/983.04k flops)
#   mul (789.51k/789.51k flops)
#   sub (789.51k/789.51k flops)
#   MobilenetEdgeTPU/expanded_conv_21/project/kernel/Regularizer/l2_regularizer (1/737.28k flops)
#     MobilenetEdgeTPU/expanded_conv_21/project/kernel/Regularizer/l2_regularizer/L2Loss (737.28k/737.28k flops)
#   MobilenetEdgeTPU/Conv_1/kernel/Regularizer/l2_regularizer (1/737.28k flops)
#     MobilenetEdgeTPU/Conv_1/kernel/Regularizer/l2_regularizer/L2Loss (737.28k/737.28k flops)
#   aspp0/weights/Initializer/random_uniform (327.68k/655.36k flops)
#     aspp0/weights/Initializer/random_uniform/mul (327.68k/327.68k flops)
#     aspp0/weights/Initializer/random_uniform/sub (1/1 flops)
#   image_pooling/weights/Initializer/random_uniform (327.68k/655.36k flops)
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1206 17:08:21.549493  8524 deprecation.py:323] From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1206 17:08:21.549493  8524 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W1206 17:08:23.247721  8524 module_wrapper.py:139] From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1206 17:08:23.307718  8524 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:152: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1206 17:08:23.337716  8524 deprecation.py:323] From deeplab/custom_eval.py:152: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From deeplab/custom_eval.py:163: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# W1206 17:08:23.337716  8524 module_wrapper.py:139] From deeplab/custom_eval.py:163: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W1206 17:08:23.397712  8524 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From deeplab/custom_eval.py:167: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# W1206 17:08:23.397712  8524 module_wrapper.py:139] From deeplab/custom_eval.py:167: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:170: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# W1206 17:08:23.447709  8524 module_wrapper.py:139] From deeplab/custom_eval.py:170: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:173: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# W1206 17:08:23.477707  8524 module_wrapper.py:139] From deeplab/custom_eval.py:173: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:176: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# W1206 17:08:23.507705  8524 module_wrapper.py:139] From deeplab/custom_eval.py:176: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:179: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# W1206 17:08:23.517704  8524 module_wrapper.py:139] From deeplab/custom_eval.py:179: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:182: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# W1206 17:08:23.527704  8524 module_wrapper.py:139] From deeplab/custom_eval.py:182: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:185: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# W1206 17:08:23.537704  8524 module_wrapper.py:139] From deeplab/custom_eval.py:185: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:220: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1206 17:08:23.687694  8524 module_wrapper.py:139] From deeplab/custom_eval.py:220: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:221: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# W1206 17:08:23.687694  8524 deprecation.py:323] From deeplab/custom_eval.py:221: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# WARNING:tensorflow:From deeplab/custom_eval.py:224: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W1206 17:08:23.707693  8524 module_wrapper.py:139] From deeplab/custom_eval.py:224: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:237: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...
# INFO:tensorflow:Running local_init_op.
# I1207 13:39:58.770205  8524 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 13:39:58.840187  8524 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-21:39:59
# I1207 13:39:59.040187  8524 custom_evaluation.py:343] Starting evaluation at 2022-12-07-21:39:59
# false_negatives[24824568]
# false_positives[54604892]
# true_negatives[182043040]
# true_positives[1.62885466e+09]
# pixel_accuracy[0.957967818]
# precision[0.967563868]
# recall[0.984988272]
# eval/miou_1.0_class_0[0.696222484]
# eval/miou_1.0_class_1[0.95350337]
# eval/miou_1.0_overall[0.824863136]
# INFO:tensorflow:Graph was finalized.
# I1207 13:43:13.949631  8524 monitored_session.py:240] Graph was finalized.
# 2022-12-07 13:43:13.950381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 13:43:13.950404: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 13:43:13.950413: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 13:43:13.950422: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 13:43:13.950428: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 13:43:13.950435: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 13:43:13.950441: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 13:43:13.950448: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 13:43:13.950471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-07 13:43:13.950533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-07 13:43:13.950540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-07 13:43:13.950544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-07 13:43:13.950604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-197988
# I1207 13:43:13.949631  8524 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-197988
# INFO:tensorflow:Running local_init_op.
# I1207 13:43:14.579605  8524 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 13:43:14.649592  8524 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-21:43:14
# I1207 13:43:14.869586  8524 custom_evaluation.py:343] Starting evaluation at 2022-12-07-21:43:14
# false_positives[56807164]
# false_negatives[23140592]
# true_negatives[179841088]
# true_positives[1.63053824e+09]
# pixel_accuracy[0.957692206]
# precision[0.966333389]
# recall[0.986006618]
# eval/miou_1.0_class_1[0.953260183]
# eval/miou_1.0_class_0[0.692258716]
# eval/miou_1.0_overall[0.822759211]
# INFO:tensorflow:Graph was finalized.
# I1207 13:46:26.677908  8524 monitored_session.py:240] Graph was finalized.
# 2022-12-07 13:46:26.684662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 13:46:26.684682: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 13:46:26.684690: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 13:46:26.684696: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 13:46:26.684702: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 13:46:26.684708: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 13:46:26.684713: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 13:46:26.684719: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 13:46:26.684737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-07 13:46:26.684789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-07 13:46:26.684794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-07 13:46:26.684797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-07 13:46:26.684850: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-198511
# I1207 13:46:26.687885  8524 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-198511
# INFO:tensorflow:Running local_init_op.
# I1207 13:46:27.257865  8524 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 13:46:27.327847  8524 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-21:46:27
# I1207 13:46:27.537849  8524 custom_evaluation.py:343] Starting evaluation at 2022-12-07-21:46:27
# true_positives[1.62931968e+09]
# false_positives[55258836]
# true_negatives[181389120]
# false_negatives[24358480]
# pixel_accuracy[0.957867384]
# recall[0.985270083]
# precision[0.96719718]
# eval/miou_1.0_class_0[0.694960356]
# eval/miou_1.0_class_1[0.953411162]
# eval/miou_1.0_overall[0.824185729]
# INFO:tensorflow:Graph was finalized.
# I1207 13:49:41.255830  8524 monitored_session.py:240] Graph was finalized.
# 2022-12-07 13:49:41.259174: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 13:49:41.259202: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 13:49:41.259210: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 13:49:41.259217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 13:49:41.259222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 13:49:41.259227: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 13:49:41.259233: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 13:49:41.259238: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 13:49:41.259258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-07 13:49:41.259321: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-07 13:49:41.259326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-07 13:49:41.259339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-07 13:49:41.259388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-199042
# I1207 13:49:41.255830  8524 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-199042
# INFO:tensorflow:Running local_init_op.
# I1207 13:49:41.875770  8524 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 13:49:41.945773  8524 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-21:49:42
# I1207 13:49:42.155769  8524 custom_evaluation.py:343] Starting evaluation at 2022-12-07-21:49:42
# false_positives[56692244]
# true_negatives[179955952]
# false_negatives[23150810]
# true_positives[1.63052749e+09]
# pixel_accuracy[0.957749367]
# recall[0.986000419]
# eval/miou_1.0_class_0[0.692673743]precision[0.966399]
#
# eval/miou_1.0_class_1[0.953318238]
# eval/miou_1.0_overall[0.82299614]
# INFO:tensorflow:Graph was finalized.
# I1207 13:52:54.284086  8524 monitored_session.py:240] Graph was finalized.
# 2022-12-07 13:52:54.286684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 13:52:54.286713: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 13:52:54.286721: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 13:52:54.286727: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 13:52:54.286733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 13:52:54.286739: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 13:52:54.286745: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 13:52:54.286750: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 13:52:54.286780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-07 13:52:54.286852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-07 13:52:54.286857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-07 13:52:54.286870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-07 13:52:54.286917: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-199572
# I1207 13:52:54.284086  8524 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-199572
# INFO:tensorflow:Running local_init_op.
# I1207 13:52:54.864050  8524 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 13:52:54.934049  8524 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-21:52:55
# I1207 13:52:55.154018  8524 custom_evaluation.py:343] Starting evaluation at 2022-12-07-21:52:55
# false_positives[55758168]true_positives[1.62979494e+09]
#
# true_negatives[180889664]
# false_negatives[23882352]
# pixel_accuracy[0.957855642]
# recall[0.985558033]
# precision[0.966919959]
# eval/miou_1.0_class_0[0.694313645]
# eval/miou_1.0_class_1[0.953411162]
# eval/miou_1.0_overall[0.823862553]
# INFO:tensorflow:Graph was finalized.
# I1207 13:56:10.571908  8524 monitored_session.py:240] Graph was finalized.
# 2022-12-07 13:56:10.578611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 13:56:10.578630: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 13:56:10.578637: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 13:56:10.578643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 13:56:10.578649: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 13:56:10.578654: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 13:56:10.578660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 13:56:10.578665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 13:56:10.578685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-07 13:56:10.578737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-07 13:56:10.578742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-07 13:56:10.578746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-07 13:56:10.578784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-200000
# I1207 13:56:10.581888  8524 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu/model.ckpt-200000
# INFO:tensorflow:Running local_init_op.
# I1207 13:56:11.171865  8524 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 13:56:11.241864  8524 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-21:56:11
# I1207 13:56:11.461834  8524 custom_evaluation.py:343] Starting evaluation at 2022-12-07-21:56:11
# true_positives[1.63035955e+09]false_negatives[23314468]
#
# false_positives[56467896]
# true_negatives[180180048]
# pixel_accuracy[0.957782745]
# recall[0.985901415]
# precision[0.966524243]
# eval/miou_1.0_class_0[0.693100393]
# eval/miou_1.0_class_1[0.953347564]
# eval/miou_1.0_overall[0.823224247]
# INFO:tensorflow:Ending evaluations:2022-12-07-21:59:24
# I1207 13:59:24.829845  8524 custom_evaluation.py:359] Ending evaluations:2022-12-07-21:59:24

# %%
# Proper MobilenetV2 Evaluation
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations/Evaluation_mnetpu_test"

# %cd G:\segmentation_master

# !python deeplab/custom_eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_v2" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mn2 \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mn2 \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
# Out:
# G:\segmentation_master

# %%
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations\Evaluation_misc"

# %cd G:\segmentation_master

# !python deeplab/custom_eval.py \
  --logtostderr \
  --eval_split="train" \
  --model_variant="resnet_v1_50_beta" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --atrous_rates=6 \
  --atrous_rates=12 \
  --atrous_rates=18 \
  --output_stride=16 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0 \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_restnet \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
# Out:
# G:\segmentation_master
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# 2022-12-06 02:28:40.467915: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:258: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:93: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1206 02:28:43.643867  2036 module_wrapper.py:139] From deeplab/custom_eval.py:93: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:93: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1206 02:28:43.643867  2036 module_wrapper.py:139] From deeplab/custom_eval.py:93: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:110: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1206 02:28:43.643867  2036 module_wrapper.py:139] From deeplab/custom_eval.py:110: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:111: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1206 02:28:43.643867  2036 module_wrapper.py:139] From deeplab/custom_eval.py:111: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Evaluating on train set
# I1206 02:28:43.643867  2036 custom_eval.py:111] Evaluating on train set
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1206 02:28:43.653877  2036 module_wrapper.py:139] From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1206 02:28:43.863855  2036 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1206 02:28:43.863855  2036 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# 2022-12-06 02:28:44.210299: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2022-12-06 02:28:44.225704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 02:28:44.225735: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 02:28:44.227887: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 02:28:44.230024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 02:28:44.230870: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 02:28:44.233655: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 02:28:44.235706: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 02:28:44.242275: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 02:28:44.242347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W1206 02:28:44.585756  2036 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W1206 02:28:47.063375  2036 deprecation.py:323] From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Performing single-scale test.
# I1206 02:28:47.093369  2036 custom_eval.py:129] Performing single-scale test.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1206 02:28:47.093369  2036 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1206 02:28:47.093369  2036 deprecation.py:323] From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/26.65m params)
#   aspp0 (--/524.80k params)
#     aspp0/BatchNorm (--/512 params)
#       aspp0/BatchNorm/beta (256, 256/256 params)
#       aspp0/BatchNorm/gamma (256, 256/256 params)
#     aspp0/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp1_depthwise (--/22.53k params)
#     aspp1_depthwise/BatchNorm (--/4.10k params)
#       aspp1_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp1_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp1_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp1_pointwise (--/524.80k params)
#     aspp1_pointwise/BatchNorm (--/512 params)
#       aspp1_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp1_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp1_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp2_depthwise (--/22.53k params)
#     aspp2_depthwise/BatchNorm (--/4.10k params)
#       aspp2_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp2_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp2_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp2_pointwise (--/524.80k params)
#     aspp2_pointwise/BatchNorm (--/512 params)
#       aspp2_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp2_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp2_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp3_depthwise (--/22.53k params)
#     aspp3_depthwise/BatchNorm (--/4.10k params)
#       aspp3_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp3_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp3_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp3_pointwise (--/524.80k params)
#     aspp3_pointwise/BatchNorm (--/512 params)
#       aspp3_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp3_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp3_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   concat_projection (--/328.19k params)
#     concat_projection/BatchNorm (--/512 params)
#       concat_projection/BatchNorm/beta (256, 256/256 params)
#       concat_projection/BatchNorm/gamma (256, 256/256 params)
#     concat_projection/weights (1x1x1280x256, 327.68k/327.68k params)
#   image_pooling (--/524.80k params)
#     image_pooling/BatchNorm (--/512 params)
#       image_pooling/BatchNorm/beta (256, 256/256 params)
#       image_pooling/BatchNorm/gamma (256, 256/256 params)
#     image_pooling/weights (1x1x2048x256, 524.29k/524.29k params)
#   logits (--/514 params)
#     logits/semantic (--/514 params)
#       logits/semantic/biases (2, 2/2 params)
#       logits/semantic/weights (1x1x256x2, 512/512 params)
#   resnet_v1_50 (--/23.63m params)
#     resnet_v1_50/block1 (--/236.29k params)
#       resnet_v1_50/block1/unit_1 (--/95.49k params)
#         resnet_v1_50/block1/unit_1/bottleneck_v1 (--/95.49k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/conv1 (--/8.32k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights (1x1x128x64, 8.19k/8.19k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/conv2 (--/36.99k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/weights (3x3x64x64, 36.86k/36.86k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/conv3 (--/16.90k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/weights (1x1x64x256, 16.38k/16.38k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut (--/33.28k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/weights (1x1x128x256, 32.77k/32.77k params)
#       resnet_v1_50/block1/unit_2 (--/70.40k params)
#         resnet_v1_50/block1/unit_2/bottleneck_v1 (--/70.40k params)
#           resnet_v1_50/block1/unit_2/bottleneck_v1/conv1 (--/16.51k params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/weights (1x1x256x64, 16.38k/16.38k params)
#           resnet_v1_50/block1/unit_2/bottleneck_v1/conv2 (--/36.99k params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/weights (3x3x64x64, 36.86k/36.86k params)
#           resnet_v1_50/block1/unit_2/bottleneck_v1/conv3 (--/16.90k params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/weights (1x1x64x256, 16.38k/16.38k params)
#       resnet_v1_50/block1/unit_3 (--/70.40k params)
#         resnet_v1_50/block1/unit_3/bottleneck_v1 (--/70.40k params)
#           resnet_v1_50/block1/unit_3/bottleneck_v1/conv1 (--/16.51k params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/weights (1x1x256x64, 16.38k/16.38k params)
#           resnet_v1_50/block1/unit_3/bottleneck_v1/conv2 (--/36.99k params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/weights (3x3x64x64, 36.86k/36.86k params)
#           resnet_v1_50/block1/unit_3/bottleneck_v1/conv3 (--/16.90k params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/weights (1x1x64x256, 16.38k/16.38k params)
#     resnet_v1_50/block2 (--/1.22m params)
#       resnet_v1_50/block2/unit_1 (--/379.39k params)
#         resnet_v1_50/block2/unit_1/bottleneck_v1 (--/379.39k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/conv1 (--/33.02k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/weights (1x1x256x128, 32.77k/32.77k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut (--/132.10k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/weights (1x1x256x512, 131.07k/131.07k params)
#       resnet_v1_50/block2/unit_2 (--/280.06k params)
#         resnet_v1_50/block2/unit_2/bottleneck_v1 (--/280.06k params)
#           resnet_v1_50/block2/unit_2/bottleneck_v1/conv1 (--/65.79k params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/weights (1x1x512x128, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_2/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_2/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#       resnet_v1_50/block2/unit_3 (--/280.06k params)
#         resnet_v1_50/block2/unit_3/bottleneck_v1 (--/280.06k params)
#           resnet_v1_50/block2/unit_3/bottleneck_v1/conv1 (--/65.79k params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/weights (1x1x512x128, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_3/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_3/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#       resnet_v1_50/block2/unit_4 (--/280.06k params)
#         resnet_v1_50/block2/unit_4/bottleneck_v1 (--/280.06k params)
#           resnet_v1_50/block2/unit_4/bottleneck_v1/conv1 (--/65.79k params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/weights (1x1x512x128, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_4/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_4/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#     resnet_v1_50/block3 (--/7.10m params)
#       resnet_v1_50/block3/unit_1 (--/1.51m params)
#         resnet_v1_50/block3/unit_1/bottleneck_v1 (--/1.51m params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/conv1 (--/131.58k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/weights (1x1x512x256, 131.07k/131.07k params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut (--/526.34k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/weights (1x1x512x1024, 524.29k/524.29k params)
#       resnet_v1_50/block3/unit_2 (--/1.12m params)
#         resnet_v1_50/block3/unit_2/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_2/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_2/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_2/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_3 (--/1.12m params)
#         resnet_v1_50/block3/unit_3/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_3/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_3/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_3/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_4 (--/1.12m params)
#         resnet_v1_50/block3/unit_4/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_4/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_4/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_4/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_5 (--/1.12m params)
#         resnet_v1_50/block3/unit_5/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_5/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_5/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_5/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_6 (--/1.12m params)
#         resnet_v1_50/block3/unit_6/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_6/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_6/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_6/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#     resnet_v1_50/block4 (--/14.96m params)
#       resnet_v1_50/block4/unit_1 (--/6.04m params)
#         resnet_v1_50/block4/unit_1/bottleneck_v1 (--/6.04m params)
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\resnet_v1_beta.py:244: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1206 02:28:47.093369  2036 module_wrapper.py:139] From G:\segmentation_master\deeplab\core\resnet_v1_beta.py:244: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\conv2d_ws.py:293: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1206 02:28:47.103369  2036 deprecation.py:323] From G:\segmentation_master\deeplab\core\conv2d_ws.py:293: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W1206 02:28:49.050424  2036 module_wrapper.py:139] From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:152: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1206 02:28:49.356423  2036 deprecation.py:323] From deeplab/custom_eval.py:152: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From deeplab/custom_eval.py:163: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# W1206 02:28:49.356423  2036 module_wrapper.py:139] From deeplab/custom_eval.py:163: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W1206 02:28:49.416416  2036 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From deeplab/custom_eval.py:167: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# W1206 02:28:49.426415  2036 module_wrapper.py:139] From deeplab/custom_eval.py:167: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:170: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# W1206 02:28:49.476412  2036 module_wrapper.py:139] From deeplab/custom_eval.py:170: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:173: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# W1206 02:28:49.506410  2036 module_wrapper.py:139] From deeplab/custom_eval.py:173: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:176: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# W1206 02:28:49.536408  2036 module_wrapper.py:139] From deeplab/custom_eval.py:176: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:179: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# W1206 02:28:49.546408  2036 module_wrapper.py:139] From deeplab/custom_eval.py:179: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:182: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# W1206 02:28:49.556407  2036 module_wrapper.py:139] From deeplab/custom_eval.py:182: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:185: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# W1206 02:28:49.566406  2036 module_wrapper.py:139] From deeplab/custom_eval.py:185: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:220: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1206 02:28:49.828542  2036 module_wrapper.py:139] From deeplab/custom_eval.py:220: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:221: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# W1206 02:28:49.828542  2036 deprecation.py:323] From deeplab/custom_eval.py:221: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# WARNING:tensorflow:From deeplab/custom_eval.py:224: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W1206 02:28:49.848561  2036 module_wrapper.py:139] From deeplab/custom_eval.py:224: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:237: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1206 02:28:49.848561  2036 module_wrapper.py:139] From deeplab/custom_eval.py:237: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From deeplab/custom_eval.py:238: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W1206 02:28:49.848561  2036 deprecation.py:323] From deeplab/custom_eval.py:238: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W1206 02:28:49.858556  2036 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 20 ops no flops stats due to incomplete shapes.
# 20 ops no flops stats due to incomplete shapes.
# INFO:tensorflow:Starting evaluations:2022-12-06-10:28:55
# I1206 02:28:55.081497  2036 custom_evaluation.py:331] Starting evaluations:2022-12-06-10:28:55
# INFO:tensorflow:Graph was finalized.
# I1206 02:28:55.747360  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 02:28:55.748200: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2022-12-06 02:28:55.750481: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 02:28:55.750506: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 02:28:55.750512: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 02:28:55.750517: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 02:28:55.750523: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 02:28:55.750528: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 02:28:55.750533: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 02:28:55.750538: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 02:28:55.750564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 02:28:56.171309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 02:28:56.171325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 02:28:56.171339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 02:28:56.171452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-60464
# I1206 02:28:56.168139  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-60464
# INFO:tensorflow:Running local_init_op.
# I1206 02:28:57.278072  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 02:28:57.368069  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-06-10:29:03
# I1206 02:29:03.355033  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-06-10:29:03
# 2022-12-06 02:29:03.903542: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 02:29:04.489703: W tensorflow/stream_executor/cuda/redzone_allocator.cc:312] Internal: Invoking ptxas not supported on Windows
# Relying on driver to perform ptx compilation. This message will be only logged once.
# 2022-12-06 02:29:04.514296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# true_negatives[129116072]false_positives[107532072]
#
# false_negatives[1.43366131e+09]
# true_positives[220016896]
# pixel_accuracy[0.184691519]
# precision[0.671706915]
# recall[0.133046985]
# eval/miou_1.0_class_1[0.124923699]
# eval/miou_1.0_class_0[0.0773006901]
# eval/miou_1.0_overall[0.101112247]
# INFO:tensorflow:Graph was finalized.
# I1206 02:36:01.031950  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 02:36:01.037394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 02:36:01.037425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 02:36:01.037433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 02:36:01.037439: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 02:36:01.037445: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 02:36:01.037451: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 02:36:01.037457: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 02:36:01.037463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 02:36:01.037490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 02:36:01.037564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 02:36:01.037569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 02:36:01.037582: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 02:36:01.037625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-60937
# I1206 02:36:01.031950  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-60937
# INFO:tensorflow:Running local_init_op.
# I1206 02:36:02.067382  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 02:36:02.147397  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-06-10:36:02
# I1206 02:36:02.377372  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-06-10:36:02
# true_negatives[129487352]
# false_positives[107160960]
# false_negatives[1.43424653e+09]
# true_positives[219428944]
# pixel_accuracy[0.184577271]
# recall[0.132691652]
# precision[0.671879172]
# eval/miou_1.0_class_0[0.0774958134]
# eval/miou_1.0_class_1[0.12461631]
# ...
# INFO:tensorflow:Done running local_init_op.
# I1206 15:59:51.586653  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-06-23:59:51
# I1206 15:59:51.816636  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-06-23:59:51
# false_negatives[1.43839386e+09]
# true_negatives[130242008]
# true_positives[215280064]
# false_positives[106406256]
# pixel_accuracy[0.182781741]
# precision[0.669223547]
# recall[0.130182892]
# eval/miou_1.0_class_1[0.122312643]
# eval/miou_1.0_class_0[0.0777544677]
# eval/miou_1.0_overall[0.100033313]
# INFO:tensorflow:Graph was finalized.
# I1206 16:06:50.528920  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 16:06:50.536179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 16:06:50.536210: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 16:06:50.536217: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 16:06:50.536224: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 16:06:50.536230: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 16:06:50.536235: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 16:06:50.536241: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 16:06:50.536246: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 16:06:50.536266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 16:06:50.536348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 16:06:50.536352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 16:06:50.536365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 16:06:50.536425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-116200
# I1206 16:06:50.538898  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-116200
# INFO:tensorflow:Running local_init_op.
# I1206 16:06:51.168860  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 16:06:51.238857  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-00:06:51
# I1206 16:06:51.458857  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-07-00:06:51
# true_positives[215272704]
# true_negatives[130192112]
# false_positives[106456088]
# false_negatives[1.43840141e+09]
# pixel_accuracy[0.182751954]
# precision[0.669112325]
# recall[0.130178437]
# eval/miou_1.0_class_1[0.122304991]
# eval/miou_1.0_class_0[0.0777243301]
# eval/miou_1.0_overall[0.100014746]
# INFO:tensorflow:Graph was finalized.
# I1206 16:13:51.552123  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 16:13:51.558512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 16:13:51.558542: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 16:13:51.558549: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 16:13:51.558556: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 16:13:51.558561: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 16:13:51.558567: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 16:13:51.558572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 16:13:51.558578: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 16:13:51.558606: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 16:13:51.558678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 16:13:51.558683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 16:13:51.558696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 16:13:51.558743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-116676
# I1206 16:13:51.562114  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-116676
# INFO:tensorflow:Running local_init_op.
# I1206 16:13:52.192080  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 16:13:52.272056  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-00:13:52
# I1206 16:13:52.482059  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-07-00:13:52
# false_negatives[1.4384407e+09]
# true_positives[215234560]
# true_negatives[130215440]
# false_positives[106432840]
# pixel_accuracy[0.182743683]
# recall[0.13015528]
# precision[0.669121504]
# eval/miou_1.0_class_1[0.122284852]
# eval/miou_1.0_class_0[0.0777364299]
# eval/miou_1.0_overall[0.100010544]
# INFO:tensorflow:Graph was finalized.
# I1206 16:20:56.138466  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 16:20:56.143716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 16:20:56.143745: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 16:20:56.143752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 16:20:56.143759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 16:20:56.143764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 16:20:56.143770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 16:20:56.143775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 16:20:56.143781: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 16:20:56.143809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 16:20:56.143879: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 16:20:56.143884: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 16:20:56.143898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 16:20:56.143944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-117154
# I1206 16:20:56.138466  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-117154
# INFO:tensorflow:Running local_init_op.
# I1206 16:20:56.768425  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 16:20:56.838421  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-00:20:57
# I1206 16:20:57.058404  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-07-00:20:57
# false_negatives[1.4386007e+09]
# true_negatives[130276752]
# true_positives[215076256]
# false_positives[106371184]
# pixel_accuracy[0.182692364]
# precision[0.669086874]recall[0.130059421]
#
# eval/miou_1.0_class_0[0.0777656212]
# eval/miou_1.0_class_1[0.122199073]
# eval/miou_1.0_overall[0.0999822915]
# INFO:tensorflow:Graph was finalized.
# I1206 16:27:59.203841  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 16:27:59.209346: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 16:27:59.209367: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 16:27:59.209375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 16:27:59.209382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 16:27:59.209388: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 16:27:59.209394: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 16:27:59.209401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 16:27:59.209406: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 16:27:59.209426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 16:27:59.209482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 16:27:59.209487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 16:27:59.209491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 16:27:59.209534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-117631
# I1206 16:27:59.203841  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-117631
# INFO:tensorflow:Running local_init_op.
# I1206 16:27:59.833786  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 16:27:59.913790  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-00:28:00
# I1206 16:28:00.133780  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-07-00:28:00
# false_negatives[1.43865587e+09]
# true_positives[215018656]
# true_negatives[130293512]
# false_positives[106354216]
# pixel_accuracy[0.182671353]
# recall[0.130024776]
# precision[0.669062912]
# eval/miou_1.0_class_1[0.122167699]
# eval/miou_1.0_class_0[0.0777730793]
# eval/miou_1.0_overall[0.0999703407]
# INFO:tensorflow:Graph was finalized.
# I1206 16:34:58.457541  2036 monitored_session.py:240] Graph was finalized.
# 2022-12-06 16:34:58.458832: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-06 16:34:58.458864: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-06 16:34:58.458871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-06 16:34:58.458878: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-06 16:34:58.458883: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-06 16:34:58.458889: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-06 16:34:58.458895: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-06 16:34:58.458900: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-06 16:34:58.458922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-06 16:34:58.459004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-06 16:34:58.459009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-06 16:34:58.459022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-06 16:34:58.459071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-118108
# I1206 16:34:58.457541  2036 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0/model.ckpt-118108
# INFO:tensorflow:Running local_init_op.
# I1206 16:34:59.077518  2036 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1206 16:34:59.157499  2036 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-07-00:34:59
# I1206 16:34:59.377499  2036 custom_evaluation.py:343] Starting evaluation at 2022-12-07-00:34:59
# true_positives[215073632]
# true_negatives[130273664]
# false_negatives[1.43860173e+09]
# false_positives[106374448]
# pixel_accuracy[0.182688877]
# recall[0.130057946]
# precision[0.669077396]
# eval/miou_1.0_class_1[0.122197472]
# eval/miou_1.0_class_0[0.0777637213]
# eval/miou_1.0_overall[0.0999804065]
# INFO:tensorflow:Ending evaluations:2022-12-07-00:41:59
# I1206 16:41:59.000513  2036 custom_evaluation.py:359] Ending evaluations:2022-12-07-00:41:59

# %% [markdown]
# ## Final Evaluation on the Best Checkpoint

# %% [markdown]
# ### ResNetV1

# %%
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations\Evaluation_misc"

# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="resnet_v1_50_beta" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --atrous_rates=6 \
  --atrous_rates=12 \
  --atrous_rates=18 \
  --output_stride=16 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0 \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_misc \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
# Out:
# G:\segmentation_master
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/26.65m params)
#   aspp0 (--/524.80k params)
#     aspp0/BatchNorm (--/512 params)
#       aspp0/BatchNorm/beta (256, 256/256 params)
#       aspp0/BatchNorm/gamma (256, 256/256 params)
#     aspp0/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp1_depthwise (--/22.53k params)
#     aspp1_depthwise/BatchNorm (--/4.10k params)
#       aspp1_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp1_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp1_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp1_pointwise (--/524.80k params)
#     aspp1_pointwise/BatchNorm (--/512 params)
#       aspp1_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp1_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp1_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp2_depthwise (--/22.53k params)
#     aspp2_depthwise/BatchNorm (--/4.10k params)
#       aspp2_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp2_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp2_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp2_pointwise (--/524.80k params)
#     aspp2_pointwise/BatchNorm (--/512 params)
#       aspp2_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp2_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp2_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp3_depthwise (--/22.53k params)
#     aspp3_depthwise/BatchNorm (--/4.10k params)
#       aspp3_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp3_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp3_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp3_pointwise (--/524.80k params)
#     aspp3_pointwise/BatchNorm (--/512 params)
#       aspp3_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp3_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp3_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   concat_projection (--/328.19k params)
#     concat_projection/BatchNorm (--/512 params)
#       concat_projection/BatchNorm/beta (256, 256/256 params)
#       concat_projection/BatchNorm/gamma (256, 256/256 params)
#     concat_projection/weights (1x1x1280x256, 327.68k/327.68k params)
#   image_pooling (--/524.80k params)
#     image_pooling/BatchNorm (--/512 params)
#       image_pooling/BatchNorm/beta (256, 256/256 params)
#       image_pooling/BatchNorm/gamma (256, 256/256 params)
#     image_pooling/weights (1x1x2048x256, 524.29k/524.29k params)
#   logits (--/514 params)
#     logits/semantic (--/514 params)
#       logits/semantic/biases (2, 2/2 params)
#       logits/semantic/weights (1x1x256x2, 512/512 params)
#   resnet_v1_50 (--/23.63m params)
#     resnet_v1_50/block1 (--/236.29k params)
#       resnet_v1_50/block1/unit_1 (--/95.49k params)
#         resnet_v1_50/block1/unit_1/bottleneck_v1 (--/95.49k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/conv1 (--/8.32k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights (1x1x128x64, 8.19k/8.19k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/conv2 (--/36.99k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/weights (3x3x64x64, 36.86k/36.86k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/conv3 (--/16.90k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/weights (1x1x64x256, 16.38k/16.38k params)
#           resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut (--/33.28k params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/weights (1x1x128x256, 32.77k/32.77k params)
#       resnet_v1_50/block1/unit_2 (--/70.40k params)
#         resnet_v1_50/block1/unit_2/bottleneck_v1 (--/70.40k params)
#           resnet_v1_50/block1/unit_2/bottleneck_v1/conv1 (--/16.51k params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/weights (1x1x256x64, 16.38k/16.38k params)
#           resnet_v1_50/block1/unit_2/bottleneck_v1/conv2 (--/36.99k params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/weights (3x3x64x64, 36.86k/36.86k params)
#           resnet_v1_50/block1/unit_2/bottleneck_v1/conv3 (--/16.90k params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/weights (1x1x64x256, 16.38k/16.38k params)
#       resnet_v1_50/block1/unit_3 (--/70.40k params)
#         resnet_v1_50/block1/unit_3/bottleneck_v1 (--/70.40k params)
#           resnet_v1_50/block1/unit_3/bottleneck_v1/conv1 (--/16.51k params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/weights (1x1x256x64, 16.38k/16.38k params)
#           resnet_v1_50/block1/unit_3/bottleneck_v1/conv2 (--/36.99k params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm (--/128 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/beta (64, 64/64 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (64, 64/64 params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/weights (3x3x64x64, 36.86k/36.86k params)
#           resnet_v1_50/block1/unit_3/bottleneck_v1/conv3 (--/16.90k params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm (--/512 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/weights (1x1x64x256, 16.38k/16.38k params)
#     resnet_v1_50/block2 (--/1.22m params)
#       resnet_v1_50/block2/unit_1 (--/379.39k params)
#         resnet_v1_50/block2/unit_1/bottleneck_v1 (--/379.39k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/conv1 (--/33.02k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/weights (1x1x256x128, 32.77k/32.77k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut (--/132.10k params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/weights (1x1x256x512, 131.07k/131.07k params)
#       resnet_v1_50/block2/unit_2 (--/280.06k params)
#         resnet_v1_50/block2/unit_2/bottleneck_v1 (--/280.06k params)
#           resnet_v1_50/block2/unit_2/bottleneck_v1/conv1 (--/65.79k params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/weights (1x1x512x128, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_2/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_2/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#       resnet_v1_50/block2/unit_3 (--/280.06k params)
#         resnet_v1_50/block2/unit_3/bottleneck_v1 (--/280.06k params)
#           resnet_v1_50/block2/unit_3/bottleneck_v1/conv1 (--/65.79k params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/weights (1x1x512x128, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_3/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_3/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#       resnet_v1_50/block2/unit_4 (--/280.06k params)
#         resnet_v1_50/block2/unit_4/bottleneck_v1 (--/280.06k params)
#           resnet_v1_50/block2/unit_4/bottleneck_v1/conv1 (--/65.79k params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/weights (1x1x512x128, 65.54k/65.54k params)
#           resnet_v1_50/block2/unit_4/bottleneck_v1/conv2 (--/147.71k params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm (--/256 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/beta (128, 128/128 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/gamma (128, 128/128 params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/weights (3x3x128x128, 147.46k/147.46k params)
#           resnet_v1_50/block2/unit_4/bottleneck_v1/conv3 (--/66.56k params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm (--/1.02k params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/weights (1x1x128x512, 65.54k/65.54k params)
#     resnet_v1_50/block3 (--/7.10m params)
#       resnet_v1_50/block3/unit_1 (--/1.51m params)
#         resnet_v1_50/block3/unit_1/bottleneck_v1 (--/1.51m params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/conv1 (--/131.58k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/weights (1x1x512x256, 131.07k/131.07k params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut (--/526.34k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/weights (1x1x512x1024, 524.29k/524.29k params)
#       resnet_v1_50/block3/unit_2 (--/1.12m params)
#         resnet_v1_50/block3/unit_2/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_2/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_2/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_2/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_3 (--/1.12m params)
#         resnet_v1_50/block3/unit_3/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_3/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_3/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_3/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_4 (--/1.12m params)
#         resnet_v1_50/block3/unit_4/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_4/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_4/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_4/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_5 (--/1.12m params)
#         resnet_v1_50/block3/unit_5/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_5/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_5/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_5/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#       resnet_v1_50/block3/unit_6 (--/1.12m params)
#         resnet_v1_50/block3/unit_6/bottleneck_v1 (--/1.12m params)
#           resnet_v1_50/block3/unit_6/bottleneck_v1/conv1 (--/262.66k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/weights (1x1x1024x256, 262.14k/262.14k params)
#           resnet_v1_50/block3/unit_6/bottleneck_v1/conv2 (--/590.34k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm (--/512 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/beta (256, 256/256 params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/gamma (256, 256/256 params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/weights (3x3x256x256, 589.82k/589.82k params)
#           resnet_v1_50/block3/unit_6/bottleneck_v1/conv3 (--/264.19k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm (--/2.05k params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/beta (1024, 1.02k/1.02k params)
#               resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/gamma (1024, 1.02k/1.02k params)
#             resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/weights (1x1x256x1024, 262.14k/262.14k params)
#     resnet_v1_50/block4 (--/14.96m params)
#       resnet_v1_50/block4/unit_1 (--/6.04m params)
#         resnet_v1_50/block4/unit_1/bottleneck_v1 (--/6.04m params)
#           resnet_v1_50/block4/unit_1/bottleneck_v1/conv1 (--/525.31k params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm (--/1.02k params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/weights (1x1x1024x512, 524.29k/524.29k params)
#           resnet_v1_50/block4/unit_1/bottleneck_v1/conv2 (--/2.36m params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm (--/1.02k params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/weights (3x3x512x512, 2.36m/2.36m params)
#           resnet_v1_50/block4/unit_1/bottleneck_v1/conv3 (--/1.05m params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm (--/4.10k params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/beta (2048, 2.05k/2.05k params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/gamma (2048, 2.05k/2.05k params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/weights (1x1x512x2048, 1.05m/1.05m params)
#           resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut (--/2.10m params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm (--/4.10k params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/beta (2048, 2.05k/2.05k params)
#               resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma (2048, 2.05k/2.05k params)
#             resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/weights (1x1x1024x2048, 2.10m/2.10m params)
#       resnet_v1_50/block4/unit_2 (--/4.46m params)
#         resnet_v1_50/block4/unit_2/bottleneck_v1 (--/4.46m params)
#           resnet_v1_50/block4/unit_2/bottleneck_v1/conv1 (--/1.05m params)
#             resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm (--/1.02k params)
#               resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/weights (1x1x2048x512, 1.05m/1.05m params)
#           resnet_v1_50/block4/unit_2/bottleneck_v1/conv2 (--/2.36m params)
#             resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm (--/1.02k params)
#               resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights (3x3x512x512, 2.36m/2.36m params)
#           resnet_v1_50/block4/unit_2/bottleneck_v1/conv3 (--/1.05m params)
#             resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm (--/4.10k params)
#               resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/beta (2048, 2.05k/2.05k params)
#               resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/gamma (2048, 2.05k/2.05k params)
#             resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/weights (1x1x512x2048, 1.05m/1.05m params)
#       resnet_v1_50/block4/unit_3 (--/4.46m params)
#         resnet_v1_50/block4/unit_3/bottleneck_v1 (--/4.46m params)
#           resnet_v1_50/block4/unit_3/bottleneck_v1/conv1 (--/1.05m params)
#             resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm (--/1.02k params)
#               resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/weights (1x1x2048x512, 1.05m/1.05m params)
#           resnet_v1_50/block4/unit_3/bottleneck_v1/conv2 (--/2.36m params)
#             resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm (--/1.02k params)
#               resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/beta (512, 512/512 params)
#               resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/gamma (512, 512/512 params)
#             resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/weights (3x3x512x512, 2.36m/2.36m params)
#           resnet_v1_50/block4/unit_3/bottleneck_v1/conv3 (--/1.05m params)
#             resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm (--/4.10k params)
#               resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/beta (2048, 2.05k/2.05k params)
#               resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/gamma (2048, 2.05k/2.05k params)
#             resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/weights (1x1x512x2048, 1.05m/1.05m params)
#     resnet_v1_50/conv1_1 (--/1.86k params)
#       resnet_v1_50/conv1_1/BatchNorm (--/128 params)
#         resnet_v1_50/conv1_1/BatchNorm/beta (64, 64/64 params)
#         resnet_v1_50/conv1_1/BatchNorm/gamma (64, 64/64 params)
#       resnet_v1_50/conv1_1/weights (3x3x3x64, 1.73k/1.73k params)
#     resnet_v1_50/conv1_2 (--/36.99k params)
#       resnet_v1_50/conv1_2/BatchNorm (--/128 params)
#         resnet_v1_50/conv1_2/BatchNorm/beta (64, 64/64 params)
#         resnet_v1_50/conv1_2/BatchNorm/gamma (64, 64/64 params)
#       resnet_v1_50/conv1_2/weights (3x3x64x64, 36.86k/36.86k params)
#     resnet_v1_50/conv1_3 (--/73.98k params)
#       resnet_v1_50/conv1_3/BatchNorm (--/256 params)
#         resnet_v1_50/conv1_3/BatchNorm/beta (128, 128/128 params)
#         resnet_v1_50/conv1_3/BatchNorm/gamma (128, 128/128 params)
#       resnet_v1_50/conv1_3/weights (3x3x64x128, 73.73k/73.73k params)
#
# ======================End of Report==========================
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/85.18b flops)
#   resnet_v1_50/conv1_3/Conv2D (9.74b/9.74b flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/Conv2D (5.45b/5.45b flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/Conv2D (5.45b/5.45b flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/Conv2D (5.45b/5.45b flops)
#   resnet_v1_50/conv1_2/Conv2D (4.87b/4.87b flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/Conv2D (4.57b/4.57b flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/Conv2D (2.28b/2.28b flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/Conv2D (2.28b/2.28b flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/Conv2D (2.28b/2.28b flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/Conv2D (2.28b/2.28b flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/Conv2D (2.28b/2.28b flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/Conv2D (1.28b/1.28b flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/Conv2D (1.28b/1.28b flops)
#   resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/Conv2D (1.28b/1.28b flops)
#   resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/Conv2D (1.28b/1.28b flops)
#   resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/Conv2D (1.28b/1.28b flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/Conv2D (1.28b/1.28b flops)
#   resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/Conv2D (1.25b/1.25b flops)
#   resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/Conv2D (1.25b/1.25b flops)
#   resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/Conv2D (1.25b/1.25b flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/Conv2D (1.23b/1.23b flops)
#   resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/Conv2D (1.23b/1.23b flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/Conv2D (1.14b/1.14b flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/Conv2D (1.14b/1.14b flops)
#   aspp0/Conv2D (1.14b/1.14b flops)
#   aspp1_pointwise/Conv2D (1.14b/1.14b flops)
#   aspp2_pointwise/Conv2D (1.14b/1.14b flops)
#   aspp3_pointwise/Conv2D (1.14b/1.14b flops)
#   resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/Conv2D (1.11b/1.11b flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/Conv2D (1.09b/1.09b flops)
#   concat_projection/Conv2D (713.69m/713.69m flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/Conv2D (570.95m/570.95m flops)
#   resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/Conv2D (553.78m/553.78m flops)
#   resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/Conv2D (553.78m/553.78m flops)
#   resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/Conv2D (553.78m/553.78m flops)
#   resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/Conv2D (553.78m/553.78m flops)
#   resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/Conv2D (553.78m/553.78m flops)
#   resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/Conv2D (553.78m/553.78m flops)
#   resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/Conv2D (545.29m/545.29m flops)
#   resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/Conv2D (545.29m/545.29m flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/Conv2D (545.29m/545.29m flops)
#   resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/Conv2D (545.29m/545.29m flops)
#   resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/Conv2D (321.16m/321.16m flops)
#   resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/Conv2D (311.50m/311.50m flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/Conv2D (285.47m/285.47m flops)
#   resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/Conv2D (276.89m/276.89m flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/Conv2D (272.65m/272.65m flops)
#   resnet_v1_50/conv1_1/Conv2D (228.27m/228.27m flops)
#   resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/Conv2D (142.74m/142.74m flops)
#   resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/Conv2D (138.44m/138.44m flops)
#   auc/mul_2 (52.63m/52.63m flops)
#   auc/Greater (52.63m/52.63m flops)
#   auc/mul_1 (52.63m/52.63m flops)
#   auc/mul_3 (52.63m/52.63m flops)
#   auc/mul (52.63m/52.63m flops)
#   auc/Sum_2 (52.63m/52.63m flops)
#   auc/Sum (52.63m/52.63m flops)
#   auc/Sum_1 (52.63m/52.63m flops)
#   auc/Sum_3 (52.63m/52.63m flops)
#   aspp3_depthwise/depthwise (47.78m/47.78m flops)
#   aspp2_depthwise/depthwise (47.78m/47.78m flops)
#   aspp1_depthwise/depthwise (47.78m/47.78m flops)
#   resnet_v1_50/pool1/MaxPool (19.17m/19.17m flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/7.08m flops)
#     resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (7.08m/7.08m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/7.08m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (7.08m/7.08m flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/7.08m flops)
#     resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (7.08m/7.08m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/kernel/Regularizer/l2_regularizer (1/6.29m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/kernel/Regularizer/l2_regularizer/L2Loss (6.29m/6.29m flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal (2.36m/4.72m flops)
#     resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (2.36m/2.36m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/weights/Initializer/truncated_normal (2.36m/4.72m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (2.36m/2.36m flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/weights/Initializer/truncated_normal (2.36m/4.72m flops)
#     resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (2.36m/2.36m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/weights/Initializer/truncated_normal (2.10m/4.19m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/weights/Initializer/truncated_normal/mul (2.10m/2.10m flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/3.15m flops)
#     resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (3.15m/3.15m flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/3.15m flops)
#     resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (3.15m/3.15m flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/3.15m flops)
#     resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (3.15m/3.15m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/3.15m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (3.15m/3.15m flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/3.15m flops)
#     resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (3.15m/3.15m flops)
#   Softmax (2.63m/2.63m flops)
#   AvgPool2D/AvgPool (2.23m/2.23m flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/weights/Initializer/truncated_normal (1.05m/2.10m flops)
#     resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/weights/Initializer/truncated_normal/mul (1.05m/1.05m flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/weights/Initializer/truncated_normal (1.05m/2.10m flops)
#     resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/weights/Initializer/truncated_normal/mul (1.05m/1.05m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/weights/Initializer/truncated_normal (1.05m/2.10m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/weights/Initializer/truncated_normal/mul (1.05m/1.05m flops)
#   resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/weights/Initializer/truncated_normal (1.05m/2.10m flops)
#     resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/weights/Initializer/truncated_normal/mul (1.05m/1.05m flops)
#   resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/weights/Initializer/truncated_normal (1.05m/2.10m flops)
#     resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/weights/Initializer/truncated_normal/mul (1.05m/1.05m flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/1.77m flops)
#     resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (1.77m/1.77m flops)
#   resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/1.77m flops)
#     resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (1.77m/1.77m flops)
#   resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/1.77m flops)
#     resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (1.77m/1.77m flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/1.77m flops)
#     resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (1.77m/1.77m flops)
#   resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/1.77m flops)
#     resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (1.77m/1.77m flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer (1/1.77m flops)
#     resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/kernel/Regularizer/l2_regularizer/L2Loss (1.77m/1.77m flops)
#   aspp1_pointwise/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     aspp1_pointwise/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   image_pooling/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     image_pooling/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   aspp0/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     aspp0/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   aspp2_pointwise/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     aspp2_pointwise/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   aspp3_pointwise/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     aspp3_pointwise/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/kernel/Regularizer/l2_regularizer (1/1.57m flops)
#     resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/kernel/Regularizer/l2_regularizer/L2Loss (1.57m/1.57m flops)
#   resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/weights/Initializer/truncated_normal (589.82k/1.18m flops)
#     resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (589.82k/589.82k flops)
#   resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/weights/Initializer/truncated_normal (589.82k/1.18m flops)
#     resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (589.82k/589.82k flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/weights/Initializer/truncated_normal (589.82k/1.18m flops)
#     resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (589.82k/589.82k flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal (589.82k/1.18m flops)
#     resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (589.82k/589.82k flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/weights/Initializer/truncated_normal (589.82k/1.18m flops)
#     resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (589.82k/589.82k flops)
#   resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/weights/Initializer/truncated_normal (589.82k/1.18m flops)
#     resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/weights/Initializer/truncated_normal/mul (589.82k/589.82k flops)
#   logits/semantic/Conv2D (1.12m/1.12m flops)
#   resnet_v1_50/block1/unit_3/bottleneck_v1/shortcut/MaxPool (1.08m/1.08m flops)
#   image_pooling/weights/Initializer/random_uniform (524.29k/1.05m flops)
#     image_pooling/weights/Initializer/random_uniform/mul (524.29k/524.29k flops)
#     image_pooling/weights/Initializer/random_uniform/sub (1/1 flops)
#   aspp0/weights/Initializer/random_uniform (524.29k/1.05m flops)
#     aspp0/weights/Initializer/random_uniform/mul (524.29k/524.29k flops)
#     aspp0/weights/Initializer/random_uniform/sub (1/1 flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/weights/Initializer/truncated_normal (524.29k/1.05m flops)
#     resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/weights/Initializer/truncated_normal/mul (524.29k/524.29k flops)
#   image_pooling/Conv2D (1.05m/1.05m flops)
#   resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/weights/Initializer/truncated_normal (524.29k/1.05m flops)
#     resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/weights/Initializer/truncated_normal/mul (524.29k/524.29k flops)
#   aspp1_pointwise/weights/Initializer/truncated_normal (524.29k/1.05m flops)
#     aspp1_pointwise/weights/Initializer/truncated_normal/mul (524.29k/524.29k flops)
#   aspp2_pointwise/weights/Initializer/truncated_normal (524.29k/1.05m flops)
#     aspp2_pointwise/weights/Initializer/truncated_normal/mul (524.29k/524.29k flops)
#   aspp3_pointwise/weights/Initializer/truncated_normal (524.29k/1.05m flops)
#     aspp3_pointwise/weights/Initializer/truncated_normal/mul (524.29k/524.29k flops)
#   concat_projection/kernel/Regularizer/l2_regularizer (1/983.04k flops)
#     concat_projection/kernel/Regularizer/l2_regularizer/L2Loss (983.04k/983.04k flops)
#   sub (789.51k/789.51k flops)
#   mul (789.51k/789.51k flops)
#   resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
#   resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
#   resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
#   resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
#   resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer (1/786.43k flops)
#     resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/kernel/Regularizer/l2_regularizer/L2Loss (786.43k/786.43k flops)
# ...
#   aspp2_depthwise/depthwise_weights/Initializer/truncated_normal (18.43k/36.86k flops)
#     aspp2_depthwise/depthwise_weights/Initializer/truncated_normal/mul (18.43k/18.43k flops)
#   aspp1_depthwise/depthwise_weights/Initializer/truncated_normal (18.43k/36.86k flops)
#     aspp1_depthwise/depthwise_weights/Initializer/truncated_normal/mul (18.43k/18.43k flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/weights/Initializer/truncated_normal (16.38k/32.77k flops)
#     resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/weights/Initializer/truncated_normal/mul (16.38k/16.38k flops)
#   resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/weights/Initializer/truncated_normal (16.38k/32.77k flops)
#     resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/weights/Initializer/truncated_normal/mul (16.38k/16.38k flops)
#   resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/weights/Initializer/truncated_normal (16.38k/32.77k flops)
#     resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/weights/Initializer/truncated_normal/mul (16.38k/16.38k flops)
#   resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/weights/Initializer/truncated_normal (16.38k/32.77k flops)
#     resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/weights/Initializer/truncated_normal/mul (16.38k/16.38k flops)
#   resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/weights/Initializer/truncated_normal (16.38k/32.77k flops)
#     resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/weights/Initializer/truncated_normal/mul (16.38k/16.38k flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer (1/24.58k flops)
#     resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/kernel/Regularizer/l2_regularizer/L2Loss (24.57k/24.57k flops)
#   resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights/Initializer/truncated_normal (8.19k/16.38k flops)
# W1207 16:33:55.692225 15448 module_wrapper.py:139] From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W1207 16:33:55.762221 15448 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# W1207 16:33:55.762221 15448 module_wrapper.py:139] From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# W1207 16:33:55.812218 15448 module_wrapper.py:139] From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# W1207 16:33:55.832217 15448 module_wrapper.py:139] From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# W1207 16:33:55.862215 15448 module_wrapper.py:139] From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# W1207 16:33:55.872214 15448 module_wrapper.py:139] From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# W1207 16:33:55.882213 15448 module_wrapper.py:139] From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# W1207 16:33:55.902213 15448 module_wrapper.py:139] From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:186: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# W1207 16:33:55.912212 15448 module_wrapper.py:139] From deeplab/eval.py:186: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# WARNING:tensorflow:From deeplab/eval.py:227: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1207 16:33:56.272189 15448 module_wrapper.py:139] From deeplab/eval.py:227: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From deeplab/eval.py:228: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# W1207 16:33:56.272189 15448 deprecation.py:323] From deeplab/eval.py:228: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# WARNING:tensorflow:From deeplab/eval.py:231: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W1207 16:33:56.292189 15448 module_wrapper.py:139] From deeplab/eval.py:231: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From deeplab/eval.py:244: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1207 16:33:56.292189 15448 module_wrapper.py:139] From deeplab/eval.py:244: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From deeplab/eval.py:245: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W1207 16:33:56.292189 15448 deprecation.py:323] From deeplab/eval.py:245: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W1207 16:33:56.292189 15448 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 20 ops no flops stats due to incomplete shapes.
# 20 ops no flops stats due to incomplete shapes.
# INFO:tensorflow:Waiting for new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0
# I1207 16:34:01.620244 15448 evaluation.py:189] Waiting for new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0
# INFO:tensorflow:Found new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0\model.ckpt-118108
# I1207 16:34:01.630244 15448 evaluation.py:198] Found new checkpoint at training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0\model.ckpt-118108
# INFO:tensorflow:Graph was finalized.
# I1207 16:34:02.290203 15448 monitored_session.py:240] Graph was finalized.
# 2022-12-07 16:34:02.292249: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2022-12-07 16:34:02.294780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 16:34:02.294805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 16:34:02.294811: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 16:34:02.294817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 16:34:02.294822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 16:34:02.294828: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 16:34:02.294833: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 16:34:02.294838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 16:34:02.294866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-12-07 16:34:02.702959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-07 16:34:02.702975: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-12-07 16:34:02.702980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-12-07 16:34:02.703084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6791 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1)
# INFO:tensorflow:Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0\model.ckpt-118108
# I1207 16:34:02.700177 15448 saver.py:1284] Restoring parameters from training_environment/ade_indoor/Checkpoints/Checkpoint_resnet_proper_v0\model.ckpt-118108
# INFO:tensorflow:Running local_init_op.
# I1207 16:34:03.502055 15448 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1207 16:34:03.602056 15448 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Starting evaluation at 2022-12-08-00:34:10
# I1207 16:34:10.008052 15448 evaluation.py:450] Starting evaluation at 2022-12-08-00:34:10
# 2022-12-07 16:34:10.882522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 16:34:11.417402: W tensorflow/stream_executor/cuda/redzone_allocator.cc:312] Internal: Invoking ptxas not supported on Windows
# Relying on driver to perform ptx compilation. This message will be only logged once.
# 2022-12-07 16:34:11.447372: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# false_positives[13455623]
# true_positives[27199152]
# false_negatives[180053616]
# true_negatives[16679790]
# pixel_accuracy[0.184840783]
# recall[0.131236613]
# precision[0.669027209]
# eval/miou_1.0_class_1[0.123235703]
# eval/miou_1.0_class_0[0.0793561414]
# auc[0.342365623]
# eval/miou_1.0_overall[0.101295903]
#     resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights/Initializer/truncated_normal/mul (8.19k/8.19k flops)
#   resnet_v1_50/conv1_1/kernel/Regularizer/l2_regularizer (1/5.18k flops)
#     resnet_v1_50/conv1_1/kernel/Regularizer/l2_regularizer/L2Loss (5.18k/5.18k flops)
#   resnet_v1_50/conv1_1/weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     resnet_v1_50/conv1_1/weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   logits/semantic/BiasAdd (2.18k/2.18k flops)
#   logits/semantic/kernel/Regularizer/l2_regularizer (1/1.54k flops)
#     logits/semantic/kernel/Regularizer/l2_regularizer/L2Loss (1.53k/1.53k flops)
#   logits/semantic/weights/Initializer/truncated_normal (512/1.02k flops)
#     logits/semantic/weights/Initializer/truncated_normal/mul (512/512 flops)
#   auc/AssignAdd_2 (200/200 flops)
#   auc/div_3 (200/200 flops)
#   auc/div_2 (200/200 flops)
#   auc/div_1 (200/200 flops)
#   auc/div (200/200 flops)
#   auc/AssignAdd_3 (200/200 flops)
#   auc/AssignAdd_1 (200/200 flops)
#   auc/AssignAdd (200/200 flops)
#   auc/truediv_1 (199/199 flops)
#   auc/truediv (199/199 flops)
#   auc/sub_1 (199/199 flops)
#   auc/sub (199/199 flops)
#   auc/Mul_4 (199/199 flops)
#   auc/Mul_5 (199/199 flops)
#   auc/value (198/198 flops)
#   auc/update_op (198/198 flops)
#   mean_iou/AssignAdd (4/4 flops)
#   mean_iou/Greater (2/2 flops)
#   mean_iou/sub (2/2 flops)
#   mean_iou/div (2/2 flops)
#   mean_iou/Sum_1 (2/2 flops)
#   mean_iou/Sum (2/2 flops)
#   mean_iou/NotEqual (2/2 flops)
#   recall/div_1 (1/1 flops)
#   mean_iou/Sum_2 (1/1 flops)
#   mean_iou/Greater_1 (1/1 flops)
#   false_positives_1/AssignAdd (1/1 flops)
#   false_negatives/AssignAdd (1/1 flops)
#   Greater_1 (1/1 flops)
#   accuracy/AssignAdd (1/1 flops)
#   precision/false_positives/AssignAdd (1/1 flops)
#   recall/Greater (1/1 flops)
#   false_positives_2/AssignAdd (1/1 flops)
#   true_negatives/AssignAdd (1/1 flops)
#   false_negatives_1/AssignAdd (1/1 flops)
#   recall/Greater_1 (1/1 flops)
#   precision/true_positives/AssignAdd (1/1 flops)
#   true_negatives_1/AssignAdd (1/1 flops)
#   recall/div (1/1 flops)
#   recall/false_negatives/AssignAdd (1/1 flops)
#   recall/true_positives/AssignAdd (1/1 flops)
#   true_negatives_2/AssignAdd (1/1 flops)
#   precision/div_1 (1/1 flops)
#   precision/div (1/1 flops)
#   precision/Greater_1 (1/1 flops)
#   true_positives/AssignAdd (1/1 flops)
#   precision/Greater (1/1 flops)
#   false_positives/AssignAdd (1/1 flops)
#   mean_iou/truediv (1/1 flops)
#   true_positives_1/AssignAdd (1/1 flops)
#   Greater (1/1 flops)
#   mean_iou/mean_iou (1/1 flops)
#   false_negatives_2/AssignAdd (1/1 flops)
#   true_positives_2/AssignAdd (1/1 flops)
#   accuracy/Maximum_1 (1/1 flops)
#   accuracy/Maximum (1/1 flops)
#   accuracy/AssignAdd_1 (1/1 flops)
#   truediv (1/1 flops)
#   truediv_1 (1/1 flops)
#
# ======================End of Report==========================
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAZZZZ

# %% [markdown]
# ### Mobilenetv2

# %%
# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_v2" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mn2 \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mn2 \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
# Out:
# G:\segmentation_master
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# 2022-12-07 16:38:07.191112: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/eval.py:263: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1207 16:38:10.232976  3420 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1207 16:38:10.232976  3420 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From deeplab/eval.py:108: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1207 16:38:10.232976  3420 module_wrapper.py:139] From deeplab/eval.py:108: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From deeplab/eval.py:109: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1207 16:38:10.232976  3420 module_wrapper.py:139] From deeplab/eval.py:109: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Evaluating on val set
# I1207 16:38:10.232976  3420 eval.py:109] Evaluating on val set
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1207 16:38:10.232976  3420 module_wrapper.py:139] From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1207 16:38:10.456291  3420 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1207 16:38:10.466289  3420 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# 2022-12-07 16:38:10.785586: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2022-12-07 16:38:10.801543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 16:38:10.801567: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 16:38:10.803924: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 16:38:10.806168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/2.11m params)
#   MobilenetV2 (--/1.81m params)
#     MobilenetV2/Conv (--/928 params)
#       MobilenetV2/Conv/BatchNorm (--/64 params)
#         MobilenetV2/Conv/BatchNorm/beta (32, 32/32 params)
#         MobilenetV2/Conv/BatchNorm/gamma (32, 32/32 params)
#       MobilenetV2/Conv/weights (3x3x3x32, 864/864 params)
#     MobilenetV2/expanded_conv (--/896 params)
#       MobilenetV2/expanded_conv/depthwise (--/352 params)
#         MobilenetV2/expanded_conv/depthwise/BatchNorm (--/64 params)
#           MobilenetV2/expanded_conv/depthwise/BatchNorm/beta (32, 32/32 params)
#           MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma (32, 32/32 params)
#         MobilenetV2/expanded_conv/depthwise/depthwise_weights (3x3x32x1, 288/288 params)
#       MobilenetV2/expanded_conv/project (--/544 params)
#         MobilenetV2/expanded_conv/project/BatchNorm (--/32 params)
#           MobilenetV2/expanded_conv/project/BatchNorm/beta (16, 16/16 params)
#           MobilenetV2/expanded_conv/project/BatchNorm/gamma (16, 16/16 params)
#         MobilenetV2/expanded_conv/project/weights (1x1x32x16, 512/512 params)
#     MobilenetV2/expanded_conv_1 (--/5.14k params)
#       MobilenetV2/expanded_conv_1/depthwise (--/1.06k params)
#         MobilenetV2/expanded_conv_1/depthwise/BatchNorm (--/192 params)
#           MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta (96, 96/96 params)
#           MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma (96, 96/96 params)
#         MobilenetV2/expanded_conv_1/depthwise/depthwise_weights (3x3x96x1, 864/864 params)
#       MobilenetV2/expanded_conv_1/expand (--/1.73k params)
#         MobilenetV2/expanded_conv_1/expand/BatchNorm (--/192 params)
#           MobilenetV2/expanded_conv_1/expand/BatchNorm/beta (96, 96/96 params)
#           MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma (96, 96/96 params)
#         MobilenetV2/expanded_conv_1/expand/weights (1x1x16x96, 1.54k/1.54k params)
#       MobilenetV2/expanded_conv_1/project (--/2.35k params)
#         MobilenetV2/expanded_conv_1/project/BatchNorm (--/48 params)
#           MobilenetV2/expanded_conv_1/project/BatchNorm/beta (24, 24/24 params)
#           MobilenetV2/expanded_conv_1/project/BatchNorm/gamma (24, 24/24 params)
#         MobilenetV2/expanded_conv_1/project/weights (1x1x96x24, 2.30k/2.30k params)
#     MobilenetV2/expanded_conv_10 (--/66.62k params)
#       MobilenetV2/expanded_conv_10/depthwise (--/4.22k params)
#         MobilenetV2/expanded_conv_10/depthwise/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_10/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_10/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_10/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetV2/expanded_conv_10/expand (--/25.34k params)
#         MobilenetV2/expanded_conv_10/expand/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_10/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_10/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_10/expand/weights (1x1x64x384, 24.58k/24.58k params)
#       MobilenetV2/expanded_conv_10/project (--/37.06k params)
#         MobilenetV2/expanded_conv_10/project/BatchNorm (--/192 params)
#           MobilenetV2/expanded_conv_10/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetV2/expanded_conv_10/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetV2/expanded_conv_10/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetV2/expanded_conv_11 (--/118.27k params)
#       MobilenetV2/expanded_conv_11/depthwise (--/6.34k params)
#         MobilenetV2/expanded_conv_11/depthwise/BatchNorm (--/1.15k params)
#           MobilenetV2/expanded_conv_11/depthwise/BatchNorm/beta (576, 576/576 params)
#           MobilenetV2/expanded_conv_11/depthwise/BatchNorm/gamma (576, 576/576 params)
#         MobilenetV2/expanded_conv_11/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#       MobilenetV2/expanded_conv_11/expand (--/56.45k params)
#         MobilenetV2/expanded_conv_11/expand/BatchNorm (--/1.15k params)
#           MobilenetV2/expanded_conv_11/expand/BatchNorm/beta (576, 576/576 params)
#           MobilenetV2/expanded_conv_11/expand/BatchNorm/gamma (576, 576/576 params)
#         MobilenetV2/expanded_conv_11/expand/weights (1x1x96x576, 55.30k/55.30k params)
#       MobilenetV2/expanded_conv_11/project (--/55.49k params)
#         MobilenetV2/expanded_conv_11/project/BatchNorm (--/192 params)
#           MobilenetV2/expanded_conv_11/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetV2/expanded_conv_11/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetV2/expanded_conv_11/project/weights (1x1x576x96, 55.30k/55.30k params)
#     MobilenetV2/expanded_conv_12 (--/118.27k params)
#       MobilenetV2/expanded_conv_12/depthwise (--/6.34k params)
#         MobilenetV2/expanded_conv_12/depthwise/BatchNorm (--/1.15k params)
#           MobilenetV2/expanded_conv_12/depthwise/BatchNorm/beta (576, 576/576 params)
#           MobilenetV2/expanded_conv_12/depthwise/BatchNorm/gamma (576, 576/576 params)
#         MobilenetV2/expanded_conv_12/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#       MobilenetV2/expanded_conv_12/expand (--/56.45k params)
#         MobilenetV2/expanded_conv_12/expand/BatchNorm (--/1.15k params)
#           MobilenetV2/expanded_conv_12/expand/BatchNorm/beta (576, 576/576 params)
#           MobilenetV2/expanded_conv_12/expand/BatchNorm/gamma (576, 576/576 params)
#         MobilenetV2/expanded_conv_12/expand/weights (1x1x96x576, 55.30k/55.30k params)
#       MobilenetV2/expanded_conv_12/project (--/55.49k params)
#         MobilenetV2/expanded_conv_12/project/BatchNorm (--/192 params)
#           MobilenetV2/expanded_conv_12/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetV2/expanded_conv_12/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetV2/expanded_conv_12/project/weights (1x1x576x96, 55.30k/55.30k params)
#     MobilenetV2/expanded_conv_13 (--/155.26k params)
#       MobilenetV2/expanded_conv_13/depthwise (--/6.34k params)
#         MobilenetV2/expanded_conv_13/depthwise/BatchNorm (--/1.15k params)
#           MobilenetV2/expanded_conv_13/depthwise/BatchNorm/beta (576, 576/576 params)
#           MobilenetV2/expanded_conv_13/depthwise/BatchNorm/gamma (576, 576/576 params)
#         MobilenetV2/expanded_conv_13/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#       MobilenetV2/expanded_conv_13/expand (--/56.45k params)
#         MobilenetV2/expanded_conv_13/expand/BatchNorm (--/1.15k params)
#           MobilenetV2/expanded_conv_13/expand/BatchNorm/beta (576, 576/576 params)
#           MobilenetV2/expanded_conv_13/expand/BatchNorm/gamma (576, 576/576 params)
#         MobilenetV2/expanded_conv_13/expand/weights (1x1x96x576, 55.30k/55.30k params)
#       MobilenetV2/expanded_conv_13/project (--/92.48k params)
#         MobilenetV2/expanded_conv_13/project/BatchNorm (--/320 params)
#           MobilenetV2/expanded_conv_13/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetV2/expanded_conv_13/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetV2/expanded_conv_13/project/weights (1x1x576x160, 92.16k/92.16k params)
#     MobilenetV2/expanded_conv_14 (--/320.00k params)
#       MobilenetV2/expanded_conv_14/depthwise (--/10.56k params)
#         MobilenetV2/expanded_conv_14/depthwise/BatchNorm (--/1.92k params)
#           MobilenetV2/expanded_conv_14/depthwise/BatchNorm/beta (960, 960/960 params)
#           MobilenetV2/expanded_conv_14/depthwise/BatchNorm/gamma (960, 960/960 params)
#         MobilenetV2/expanded_conv_14/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#       MobilenetV2/expanded_conv_14/expand (--/155.52k params)
#         MobilenetV2/expanded_conv_14/expand/BatchNorm (--/1.92k params)
#           MobilenetV2/expanded_conv_14/expand/BatchNorm/beta (960, 960/960 params)
#           MobilenetV2/expanded_conv_14/expand/BatchNorm/gamma (960, 960/960 params)
#         MobilenetV2/expanded_conv_14/expand/weights (1x1x160x960, 153.60k/153.60k params)
#       MobilenetV2/expanded_conv_14/project (--/153.92k params)
#         MobilenetV2/expanded_conv_14/project/BatchNorm (--/320 params)
#           MobilenetV2/expanded_conv_14/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetV2/expanded_conv_14/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetV2/expanded_conv_14/project/weights (1x1x960x160, 153.60k/153.60k params)
#     MobilenetV2/expanded_conv_15 (--/320.00k params)
#       MobilenetV2/expanded_conv_15/depthwise (--/10.56k params)
#         MobilenetV2/expanded_conv_15/depthwise/BatchNorm (--/1.92k params)
#           MobilenetV2/expanded_conv_15/depthwise/BatchNorm/beta (960, 960/960 params)
#           MobilenetV2/expanded_conv_15/depthwise/BatchNorm/gamma (960, 960/960 params)
#         MobilenetV2/expanded_conv_15/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#       MobilenetV2/expanded_conv_15/expand (--/155.52k params)
#         MobilenetV2/expanded_conv_15/expand/BatchNorm (--/1.92k params)
#           MobilenetV2/expanded_conv_15/expand/BatchNorm/beta (960, 960/960 params)
#           MobilenetV2/expanded_conv_15/expand/BatchNorm/gamma (960, 960/960 params)
#         MobilenetV2/expanded_conv_15/expand/weights (1x1x160x960, 153.60k/153.60k params)
#       MobilenetV2/expanded_conv_15/project (--/153.92k params)
#         MobilenetV2/expanded_conv_15/project/BatchNorm (--/320 params)
#           MobilenetV2/expanded_conv_15/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetV2/expanded_conv_15/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetV2/expanded_conv_15/project/weights (1x1x960x160, 153.60k/153.60k params)
#     MobilenetV2/expanded_conv_16 (--/473.92k params)
#       MobilenetV2/expanded_conv_16/depthwise (--/10.56k params)
#         MobilenetV2/expanded_conv_16/depthwise/BatchNorm (--/1.92k params)
#           MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta (960, 960/960 params)
#           MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma (960, 960/960 params)
#         MobilenetV2/expanded_conv_16/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#       MobilenetV2/expanded_conv_16/expand (--/155.52k params)
#         MobilenetV2/expanded_conv_16/expand/BatchNorm (--/1.92k params)
#           MobilenetV2/expanded_conv_16/expand/BatchNorm/beta (960, 960/960 params)
#           MobilenetV2/expanded_conv_16/expand/BatchNorm/gamma (960, 960/960 params)
#         MobilenetV2/expanded_conv_16/expand/weights (1x1x160x960, 153.60k/153.60k params)
#       MobilenetV2/expanded_conv_16/project (--/307.84k params)
#         MobilenetV2/expanded_conv_16/project/BatchNorm (--/640 params)
#           MobilenetV2/expanded_conv_16/project/BatchNorm/beta (320, 320/320 params)
#           MobilenetV2/expanded_conv_16/project/BatchNorm/gamma (320, 320/320 params)
#         MobilenetV2/expanded_conv_16/project/weights (1x1x960x320, 307.20k/307.20k params)
#     MobilenetV2/expanded_conv_2 (--/8.83k params)
#       MobilenetV2/expanded_conv_2/depthwise (--/1.58k params)
#         MobilenetV2/expanded_conv_2/depthwise/BatchNorm (--/288 params)
#           MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta (144, 144/144 params)
#           MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma (144, 144/144 params)
#         MobilenetV2/expanded_conv_2/depthwise/depthwise_weights (3x3x144x1, 1.30k/1.30k params)
#       MobilenetV2/expanded_conv_2/expand (--/3.74k params)
#         MobilenetV2/expanded_conv_2/expand/BatchNorm (--/288 params)
#           MobilenetV2/expanded_conv_2/expand/BatchNorm/beta (144, 144/144 params)
#           MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma (144, 144/144 params)
#         MobilenetV2/expanded_conv_2/expand/weights (1x1x24x144, 3.46k/3.46k params)
#       MobilenetV2/expanded_conv_2/project (--/3.50k params)
#         MobilenetV2/expanded_conv_2/project/BatchNorm (--/48 params)
#           MobilenetV2/expanded_conv_2/project/BatchNorm/beta (24, 24/24 params)
#           MobilenetV2/expanded_conv_2/project/BatchNorm/gamma (24, 24/24 params)
#         MobilenetV2/expanded_conv_2/project/weights (1x1x144x24, 3.46k/3.46k params)
#     MobilenetV2/expanded_conv_3 (--/10.00k params)
#       MobilenetV2/expanded_conv_3/depthwise (--/1.58k params)
#         MobilenetV2/expanded_conv_3/depthwise/BatchNorm (--/288 params)
#           MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta (144, 144/144 params)
#           MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma (144, 144/144 params)
#         MobilenetV2/expanded_conv_3/depthwise/depthwise_weights (3x3x144x1, 1.30k/1.30k params)
#       MobilenetV2/expanded_conv_3/expand (--/3.74k params)
#         MobilenetV2/expanded_conv_3/expand/BatchNorm (--/288 params)
#           MobilenetV2/expanded_conv_3/expand/BatchNorm/beta (144, 144/144 params)
#           MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma (144, 144/144 params)
#         MobilenetV2/expanded_conv_3/expand/weights (1x1x24x144, 3.46k/3.46k params)
#       MobilenetV2/expanded_conv_3/project (--/4.67k params)
#         MobilenetV2/expanded_conv_3/project/BatchNorm (--/64 params)
#           MobilenetV2/expanded_conv_3/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetV2/expanded_conv_3/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetV2/expanded_conv_3/project/weights (1x1x144x32, 4.61k/4.61k params)
#     MobilenetV2/expanded_conv_4 (--/14.85k params)
#       MobilenetV2/expanded_conv_4/depthwise (--/2.11k params)
#         MobilenetV2/expanded_conv_4/depthwise/BatchNorm (--/384 params)
#           MobilenetV2/expanded_conv_4/depthwise/BatchNorm/beta (192, 192/192 params)
#           MobilenetV2/expanded_conv_4/depthwise/BatchNorm/gamma (192, 192/192 params)
#         MobilenetV2/expanded_conv_4/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#       MobilenetV2/expanded_conv_4/expand (--/6.53k params)
#         MobilenetV2/expanded_conv_4/expand/BatchNorm (--/384 params)
#           MobilenetV2/expanded_conv_4/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetV2/expanded_conv_4/expand/weights (1x1x32x192, 6.14k/6.14k params)
#       MobilenetV2/expanded_conv_4/project (--/6.21k params)
#         MobilenetV2/expanded_conv_4/project/BatchNorm (--/64 params)
#           MobilenetV2/expanded_conv_4/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetV2/expanded_conv_4/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetV2/expanded_conv_4/project/weights (1x1x192x32, 6.14k/6.14k params)
#     MobilenetV2/expanded_conv_5 (--/14.85k params)
#       MobilenetV2/expanded_conv_5/depthwise (--/2.11k params)
#         MobilenetV2/expanded_conv_5/depthwise/BatchNorm (--/384 params)
#           MobilenetV2/expanded_conv_5/depthwise/BatchNorm/beta (192, 192/192 params)
#           MobilenetV2/expanded_conv_5/depthwise/BatchNorm/gamma (192, 192/192 params)
#         MobilenetV2/expanded_conv_5/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#       MobilenetV2/expanded_conv_5/expand (--/6.53k params)
#         MobilenetV2/expanded_conv_5/expand/BatchNorm (--/384 params)
#           MobilenetV2/expanded_conv_5/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetV2/expanded_conv_5/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetV2/expanded_conv_5/expand/weights (1x1x32x192, 6.14k/6.14k params)
#       MobilenetV2/expanded_conv_5/project (--/6.21k params)
#         MobilenetV2/expanded_conv_5/project/BatchNorm (--/64 params)
#           MobilenetV2/expanded_conv_5/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetV2/expanded_conv_5/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetV2/expanded_conv_5/project/weights (1x1x192x32, 6.14k/6.14k params)
#     MobilenetV2/expanded_conv_6 (--/21.06k params)
#       MobilenetV2/expanded_conv_6/depthwise (--/2.11k params)
#         MobilenetV2/expanded_conv_6/depthwise/BatchNorm (--/384 params)
#           MobilenetV2/expanded_conv_6/depthwise/BatchNorm/beta (192, 192/192 params)
#           MobilenetV2/expanded_conv_6/depthwise/BatchNorm/gamma (192, 192/192 params)
#         MobilenetV2/expanded_conv_6/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#       MobilenetV2/expanded_conv_6/expand (--/6.53k params)
#         MobilenetV2/expanded_conv_6/expand/BatchNorm (--/384 params)
#           MobilenetV2/expanded_conv_6/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetV2/expanded_conv_6/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetV2/expanded_conv_6/expand/weights (1x1x32x192, 6.14k/6.14k params)
#       MobilenetV2/expanded_conv_6/project (--/12.42k params)
#         MobilenetV2/expanded_conv_6/project/BatchNorm (--/128 params)
#           MobilenetV2/expanded_conv_6/project/BatchNorm/beta (64, 64/64 params)
#           MobilenetV2/expanded_conv_6/project/BatchNorm/gamma (64, 64/64 params)
#         MobilenetV2/expanded_conv_6/project/weights (1x1x192x64, 12.29k/12.29k params)
#     MobilenetV2/expanded_conv_7 (--/54.27k params)
#       MobilenetV2/expanded_conv_7/depthwise (--/4.22k params)
#         MobilenetV2/expanded_conv_7/depthwise/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_7/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_7/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_7/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetV2/expanded_conv_7/expand (--/25.34k params)
#         MobilenetV2/expanded_conv_7/expand/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_7/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_7/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_7/expand/weights (1x1x64x384, 24.58k/24.58k params)
#       MobilenetV2/expanded_conv_7/project (--/24.70k params)
#         MobilenetV2/expanded_conv_7/project/BatchNorm (--/128 params)
#           MobilenetV2/expanded_conv_7/project/BatchNorm/beta (64, 64/64 params)
#           MobilenetV2/expanded_conv_7/project/BatchNorm/gamma (64, 64/64 params)
#         MobilenetV2/expanded_conv_7/project/weights (1x1x384x64, 24.58k/24.58k params)
#     MobilenetV2/expanded_conv_8 (--/54.27k params)
#       MobilenetV2/expanded_conv_8/depthwise (--/4.22k params)
#         MobilenetV2/expanded_conv_8/depthwise/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_8/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_8/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_8/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetV2/expanded_conv_8/expand (--/25.34k params)
#         MobilenetV2/expanded_conv_8/expand/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_8/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_8/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_8/expand/weights (1x1x64x384, 24.58k/24.58k params)
#       MobilenetV2/expanded_conv_8/project (--/24.70k params)
#         MobilenetV2/expanded_conv_8/project/BatchNorm (--/128 params)
#           MobilenetV2/expanded_conv_8/project/BatchNorm/beta (64, 64/64 params)
#           MobilenetV2/expanded_conv_8/project/BatchNorm/gamma (64, 64/64 params)
#         MobilenetV2/expanded_conv_8/project/weights (1x1x384x64, 24.58k/24.58k params)
#     MobilenetV2/expanded_conv_9 (--/54.27k params)
#       MobilenetV2/expanded_conv_9/depthwise (--/4.22k params)
#         MobilenetV2/expanded_conv_9/depthwise/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_9/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_9/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_9/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetV2/expanded_conv_9/expand (--/25.34k params)
#         MobilenetV2/expanded_conv_9/expand/BatchNorm (--/768 params)
#           MobilenetV2/expanded_conv_9/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetV2/expanded_conv_9/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetV2/expanded_conv_9/expand/weights (1x1x64x384, 24.58k/24.58k params)
#       MobilenetV2/expanded_conv_9/project (--/24.70k params)
#         MobilenetV2/expanded_conv_9/project/BatchNorm (--/128 params)
#           MobilenetV2/expanded_conv_9/project/BatchNorm/beta (64, 64/64 params)
#           MobilenetV2/expanded_conv_9/project/BatchNorm/gamma (64, 64/64 params)
#         MobilenetV2/expanded_conv_9/project/weights (1x1x384x64, 24.58k/24.58k params)
#   aspp0 (--/82.43k params)
#     aspp0/BatchNorm (--/512 params)
#       aspp0/BatchNorm/beta (256, 256/256 params)
#       aspp0/BatchNorm/gamma (256, 256/256 params)
#     aspp0/weights (1x1x320x256, 81.92k/81.92k params)
#   concat_projection (--/131.58k params)
#     concat_projection/BatchNorm (--/512 params)
#       concat_projection/BatchNorm/beta (256, 256/256 params)
#       concat_projection/BatchNorm/gamma (256, 256/256 params)
#     concat_projection/weights (1x1x512x256, 131.07k/131.07k params)
#   image_pooling (--/82.43k params)
#     image_pooling/BatchNorm (--/512 params)
#       image_pooling/BatchNorm/beta (256, 256/256 params)
#       image_pooling/BatchNorm/gamma (256, 256/256 params)
#     image_pooling/weights (1x1x320x256, 81.92k/81.92k params)
#   logits (--/514 params)
#     logits/semantic (--/514 params)
#       logits/semantic/biases (2, 2/2 params)
#       logits/semantic/weights (1x1x256x2, 512/512 params)
#
# ======================End of Report==========================
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/5.98b flops)
#   MobilenetV2/expanded_conv_16/project/Conv2D (669.08m/669.08m flops)
#   MobilenetV2/expanded_conv_14/expand/Conv2D (334.54m/334.54m flops)
#   MobilenetV2/expanded_conv_14/project/Conv2D (334.54m/334.54m flops)
#   MobilenetV2/expanded_conv_15/expand/Conv2D (334.54m/334.54m flops)
#   MobilenetV2/expanded_conv_15/project/Conv2D (334.54m/334.54m flops)
#   MobilenetV2/expanded_conv_16/expand/Conv2D (334.54m/334.54m flops)
#   concat_projection/Conv2D (285.47m/285.47m flops)
#   MobilenetV2/expanded_conv_1/expand/Conv2D (202.90m/202.90m flops)
#   MobilenetV2/expanded_conv_13/project/Conv2D (200.72m/200.72m flops)
#   aspp0/Conv2D (178.42m/178.42m flops)
#   MobilenetV2/expanded_conv_13/expand/Conv2D (120.43m/120.43m flops)
#   MobilenetV2/expanded_conv_11/expand/Conv2D (120.43m/120.43m flops)
#   MobilenetV2/expanded_conv_12/expand/Conv2D (120.43m/120.43m flops)
#   MobilenetV2/expanded_conv_12/project/Conv2D (120.43m/120.43m flops)
#   MobilenetV2/expanded_conv_11/project/Conv2D (120.43m/120.43m flops)
#   MobilenetV2/expanded_conv_2/project/Conv2D (115.02m/115.02m flops)
#   MobilenetV2/expanded_conv_2/expand/Conv2D (115.02m/115.02m flops)
#   MobilenetV2/expanded_conv_3/expand/Conv2D (115.02m/115.02m flops)
#   MobilenetV2/Conv/Conv2D (114.13m/114.13m flops)
#   MobilenetV2/expanded_conv_10/project/Conv2D (80.29m/80.29m flops)
#   MobilenetV2/expanded_conv_1/project/Conv2D (76.68m/76.68m flops)
#   MobilenetV2/expanded_conv/project/Conv2D (67.63m/67.63m flops)
#   MobilenetV2/expanded_conv_10/expand/Conv2D (53.53m/53.53m flops)
#   MobilenetV2/expanded_conv_8/project/Conv2D (53.53m/53.53m flops)
#   MobilenetV2/expanded_conv_8/expand/Conv2D (53.53m/53.53m flops)
#   MobilenetV2/expanded_conv_7/project/Conv2D (53.53m/53.53m flops)
#   MobilenetV2/expanded_conv_7/expand/Conv2D (53.53m/53.53m flops)
#   MobilenetV2/expanded_conv_9/expand/Conv2D (53.53m/53.53m flops)
#   MobilenetV2/expanded_conv_9/project/Conv2D (53.53m/53.53m flops)
#   auc/mul_2 (52.63m/52.63m flops)
#   auc/Greater (52.63m/52.63m flops)
#   auc/mul_1 (52.63m/52.63m flops)
#   auc/mul (52.63m/52.63m flops)
#   auc/mul_3 (52.63m/52.63m flops)
#   auc/Sum (52.63m/52.63m flops)
#   auc/Sum_3 (52.63m/52.63m flops)
#   auc/Sum_1 (52.63m/52.63m flops)
#   auc/Sum_2 (52.63m/52.63m flops)
#   MobilenetV2/expanded_conv_5/expand/Conv2D (51.92m/51.92m flops)
#   MobilenetV2/expanded_conv_4/project/Conv2D (51.92m/51.92m flops)
#   MobilenetV2/expanded_conv_4/expand/Conv2D (51.92m/51.92m flops)
#   MobilenetV2/expanded_conv_6/expand/Conv2D (51.92m/51.92m flops)
#   MobilenetV2/expanded_conv_5/project/Conv2D (51.92m/51.92m flops)
#   MobilenetV2/expanded_conv_2/depthwise/depthwise (43.13m/43.13m flops)
#   MobilenetV2/expanded_conv_3/project/Conv2D (38.94m/38.94m flops)
#   MobilenetV2/expanded_conv/depthwise/depthwise (38.04m/38.04m flops)
#   MobilenetV2/expanded_conv_1/depthwise/depthwise (28.76m/28.76m flops)
#   MobilenetV2/expanded_conv_6/project/Conv2D (26.76m/26.76m flops)
#   MobilenetV2/expanded_conv_16/depthwise/depthwise (19.98m/19.98m flops)
#   MobilenetV2/expanded_conv_14/depthwise/depthwise (19.98m/19.98m flops)
#   MobilenetV2/expanded_conv_15/depthwise/depthwise (19.98m/19.98m flops)
#   MobilenetV2/expanded_conv_5/depthwise/depthwise (14.60m/14.60m flops)
#   MobilenetV2/expanded_conv_4/depthwise/depthwise (14.60m/14.60m flops)
#   MobilenetV2/expanded_conv_11/depthwise/depthwise (11.29m/11.29m flops)
#   MobilenetV2/expanded_conv_12/depthwise/depthwise (11.29m/11.29m flops)
#   MobilenetV2/expanded_conv_13/depthwise/depthwise (11.29m/11.29m flops)
#   MobilenetV2/expanded_conv_3/depthwise/depthwise (10.95m/10.95m flops)
#   MobilenetV2/expanded_conv_7/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetV2/expanded_conv_8/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetV2/expanded_conv_9/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetV2/expanded_conv_10/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetV2/expanded_conv_6/depthwise/depthwise (3.76m/3.76m flops)
#   Softmax (2.63m/2.63m flops)
#   logits/semantic/Conv2D (1.12m/1.12m flops)
#   MobilenetV2/expanded_conv_16/project/kernel/Regularizer/l2_regularizer (1/921.60k flops)
#     MobilenetV2/expanded_conv_16/project/kernel/Regularizer/l2_regularizer/L2Loss (921.60k/921.60k flops)
#   mul (789.51k/789.51k flops)
#   sub (789.51k/789.51k flops)
#   MobilenetV2/expanded_conv_16/project/weights/Initializer/truncated_normal (307.20k/614.40k flops)
#     MobilenetV2/expanded_conv_16/project/weights/Initializer/truncated_normal/mul (307.20k/307.20k flops)
#   MobilenetV2/expanded_conv_16/expand/kernel/Regularizer/l2_regularizer (1/460.80k flops)
#     MobilenetV2/expanded_conv_16/expand/kernel/Regularizer/l2_regularizer/L2Loss (460.80k/460.80k flops)
#   MobilenetV2/expanded_conv_15/project/kernel/Regularizer/l2_regularizer (1/460.80k flops)
#     MobilenetV2/expanded_conv_15/project/kernel/Regularizer/l2_regularizer/L2Loss (460.80k/460.80k flops)
#   MobilenetV2/expanded_conv_14/expand/kernel/Regularizer/l2_regularizer (1/460.80k flops)
#     MobilenetV2/expanded_conv_14/expand/kernel/Regularizer/l2_regularizer/L2Loss (460.80k/460.80k flops)
#   MobilenetV2/expanded_conv_14/project/kernel/Regularizer/l2_regularizer (1/460.80k flops)
#     MobilenetV2/expanded_conv_14/project/kernel/Regularizer/l2_regularizer/L2Loss (460.80k/460.80k flops)
#   MobilenetV2/expanded_conv_15/expand/kernel/Regularizer/l2_regularizer (1/460.80k flops)
#     MobilenetV2/expanded_conv_15/expand/kernel/Regularizer/l2_regularizer/L2Loss (460.80k/460.80k flops)
#   concat_projection/kernel/Regularizer/l2_regularizer (1/393.22k flops)
#     concat_projection/kernel/Regularizer/l2_regularizer/L2Loss (393.21k/393.21k flops)
#   AvgPool2D/AvgPool (348.48k/348.48k flops)
#   MobilenetV2/expanded_conv_15/project/weights/Initializer/truncated_normal (153.60k/307.20k flops)
#     MobilenetV2/expanded_conv_15/project/weights/Initializer/truncated_normal/mul (153.60k/153.60k flops)
#   MobilenetV2/expanded_conv_14/project/weights/Initializer/truncated_normal (153.60k/307.20k flops)
#     MobilenetV2/expanded_conv_14/project/weights/Initializer/truncated_normal/mul (153.60k/153.60k flops)
#   MobilenetV2/expanded_conv_15/expand/weights/Initializer/truncated_normal (153.60k/307.20k flops)
#     MobilenetV2/expanded_conv_15/expand/weights/Initializer/truncated_normal/mul (153.60k/153.60k flops)
#   MobilenetV2/expanded_conv_14/expand/weights/Initializer/truncated_normal (153.60k/307.20k flops)
#     MobilenetV2/expanded_conv_14/expand/weights/Initializer/truncated_normal/mul (153.60k/153.60k flops)
#   MobilenetV2/expanded_conv_16/expand/weights/Initializer/truncated_normal (153.60k/307.20k flops)
#     MobilenetV2/expanded_conv_16/expand/weights/Initializer/truncated_normal/mul (153.60k/153.60k flops)
#   MobilenetV2/expanded_conv_13/project/kernel/Regularizer/l2_regularizer (1/276.48k flops)
#     MobilenetV2/expanded_conv_13/project/kernel/Regularizer/l2_regularizer/L2Loss (276.48k/276.48k flops)
#   accuracy/broadcast_weights (263.17k/263.17k flops)
#     accuracy/broadcast_weights/assert_broadcastable/is_scalar (1/1 flops)
#     accuracy/broadcast_weights/assert_broadcastable/is_valid_shape/has_valid_nonscalar_shape/has_invalid_dims (1/1 flops)
#     accuracy/broadcast_weights/assert_broadcastable/is_valid_shape/has_valid_nonscalar_shape/is_same_rank (1/1 flops)
#   auc/broadcast_weights (263.17k/263.17k flops)
#     auc/broadcast_weights/assert_broadcastable/is_scalar (1/1 flops)
#     auc/broadcast_weights/assert_broadcastable/is_valid_shape/has_valid_nonscalar_shape/has_invalid_dims (1/1 flops)
#     auc/broadcast_weights/assert_broadcastable/is_valid_shape/has_valid_nonscalar_shape/is_same_rank (1/1 flops)
#   false_negatives_2/Mul (263.17k/263.17k flops)
#   false_negatives_2/Equal_1 (263.17k/263.17k flops)
#   false_negatives_1/Mul (263.17k/263.17k flops)
#   false_negatives_1/Equal_1 (263.17k/263.17k flops)
#   false_negatives/Mul (263.17k/263.17k flops)
#   false_negatives/Equal_1 (263.17k/263.17k flops)
#   ArgMax (263.17k/263.17k flops)
#   auc/assert_less_equal/LessEqual (263.17k/263.17k flops)
#   auc/assert_greater_equal/GreaterEqual (263.17k/263.17k flops)
#   recall/false_negatives/Mul (263.17k/263.17k flops)
#   accuracy/Mul (263.17k/263.17k flops)
#   false_positives/Equal_1 (263.17k/263.17k flops)
#   false_positives/Mul (263.17k/263.17k flops)
#   false_positives_1/Equal_1 (263.17k/263.17k flops)
#   false_positives_1/Mul (263.17k/263.17k flops)
#   false_positives_2/Equal_1 (263.17k/263.17k flops)
#   false_positives_2/Mul (263.17k/263.17k flops)
#   mean_iou/confusion_matrix/assert_less_1/Less (263.17k/263.17k flops)
#   mean_iou/confusion_matrix/assert_non_negative_1/assert_less_equal/LessEqual (263.17k/263.17k flops)
#   precision/false_positives/Equal_1 (263.17k/263.17k flops)
#   precision/false_positives/Mul (263.17k/263.17k flops)
#   precision/true_positives/Equal_1 (263.17k/263.17k flops)
#   precision/true_positives/Mul (263.17k/263.17k flops)
#   recall/false_negatives/Equal_1 (263.17k/263.17k flops)
#   recall/true_positives/Equal_1 (263.17k/263.17k flops)
#   recall/true_positives/Mul (263.17k/263.17k flops)
#   Equal_1 (263.17k/263.17k flops)
#   true_negatives/Equal_1 (263.17k/263.17k flops)
#   true_negatives/Mul (263.17k/263.17k flops)
#   true_negatives_1/Equal_1 (263.17k/263.17k flops)
#   true_negatives_1/Mul (263.17k/263.17k flops)
#   true_negatives_2/Equal_1 (263.17k/263.17k flops)
#   true_negatives_2/Mul (263.17k/263.17k flops)
#   true_positives/Equal_1 (263.17k/263.17k flops)
#   true_positives/Mul (263.17k/263.17k flops)
#   true_positives_1/Equal_1 (263.17k/263.17k flops)
#   true_positives_1/Mul (263.17k/263.17k flops)
#   true_positives_2/Equal_1 (263.17k/263.17k flops)
#   true_positives_2/Mul (263.17k/263.17k flops)
#   false_negatives_2/Sum (263.17k/263.17k flops)
#   true_positives_1/Sum (263.17k/263.17k flops)
#   accuracy/Sum (263.17k/263.17k flops)
#   true_positives/Sum (263.17k/263.17k flops)
#   true_negatives_2/Sum (263.17k/263.17k flops)
#   false_negatives_1/Sum (263.17k/263.17k flops)
#   true_negatives_1/Sum (263.17k/263.17k flops)
#   true_positives_2/Sum (263.17k/263.17k flops)
#   true_negatives/Sum (263.17k/263.17k flops)
#   accuracy/Sum_1 (263.17k/263.17k flops)
#   false_positives/Sum (263.17k/263.17k flops)
#   recall/true_positives/Sum (263.17k/263.17k flops)
#   recall/false_negatives/Sum (263.17k/263.17k flops)
#   false_positives_1/Sum (263.17k/263.17k flops)
#   false_positives_2/Sum (263.17k/263.17k flops)
#   false_negatives/Sum (263.17k/263.17k flops)
#   precision/true_positives/Sum (263.17k/263.17k flops)
#   precision/false_positives/Sum (263.17k/263.17k flops)
#   concat_projection/weights/Initializer/random_uniform (131.07k/262.14k flops)
#     concat_projection/weights/Initializer/random_uniform/mul (131.07k/131.07k flops)
# 2022-12-07 16:38:10.807160: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 16:38:10.810020: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 16:38:10.811995: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 16:38:10.818911: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 16:38:10.818984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W1207 16:38:11.154209  3420 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W1207 16:38:13.562139  3420 deprecation.py:323] From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Performing single-scale test.
# I1207 16:38:13.592138  3420 eval.py:127] Performing single-scale test.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1207 16:38:13.592138  3420 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1207 16:38:13.592138  3420 deprecation.py:323] From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1207 16:38:13.592138  3420 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W1207 16:38:15.032048  3420 module_wrapper.py:139] From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1207 16:38:15.092045  3420 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From deeplab/eval.py:150: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1207 16:38:15.122043  3420 deprecation.py:323] From deeplab/eval.py:150: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# W1207 16:38:15.122043  3420 module_wrapper.py:139] From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W1207 16:38:15.182039  3420 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# W1207 16:38:15.182039  3420 module_wrapper.py:139] From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# W1207 16:38:15.232035  3420 module_wrapper.py:139] From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# W1207 16:38:15.262034  3420 module_wrapper.py:139] From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# W1207 16:38:15.292032  3420 module_wrapper.py:139] From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# W1207 16:38:15.302031  3420 module_wrapper.py:139] From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# W1207 16:38:15.312030  3420 module_wrapper.py:139] From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# W1207 16:38:15.322030  3420 module_wrapper.py:139] From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:186: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# W1207 16:38:15.332030  3420 module_wrapper.py:139] From deeplab/eval.py:186: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# WARNING:tensorflow:From deeplab/eval.py:227: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1207 16:38:15.592014  3420 module_wrapper.py:139] From deeplab/eval.py:227: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From deeplab/eval.py:228: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# W1207 16:38:15.592014  3420 deprecation.py:323] From deeplab/eval.py:228: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# ...
#     aspp0/weights/Initializer/random_uniform/sub (1/1 flops)
#   image_pooling/weights/Initializer/random_uniform (81.92k/163.84k flops)
#     image_pooling/weights/Initializer/random_uniform/mul (81.92k/81.92k flops)
#     image_pooling/weights/Initializer/random_uniform/sub (1/1 flops)
#   image_pooling/Conv2D (163.84k/163.84k flops)
#   MobilenetV2/expanded_conv_10/project/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetV2/expanded_conv_10/project/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetV2/expanded_conv_11/expand/weights/Initializer/truncated_normal (55.30k/110.59k flops)
#     MobilenetV2/expanded_conv_11/expand/weights/Initializer/truncated_normal/mul (55.30k/55.30k flops)
#   MobilenetV2/expanded_conv_13/expand/weights/Initializer/truncated_normal (55.30k/110.59k flops)
#     MobilenetV2/expanded_conv_13/expand/weights/Initializer/truncated_normal/mul (55.30k/55.30k flops)
#   MobilenetV2/expanded_conv_12/project/weights/Initializer/truncated_normal (55.30k/110.59k flops)
#     MobilenetV2/expanded_conv_12/project/weights/Initializer/truncated_normal/mul (55.30k/55.30k flops)
#   MobilenetV2/expanded_conv_12/expand/weights/Initializer/truncated_normal (55.30k/110.59k flops)
#     MobilenetV2/expanded_conv_12/expand/weights/Initializer/truncated_normal/mul (55.30k/55.30k flops)
#   MobilenetV2/expanded_conv_11/project/weights/Initializer/truncated_normal (55.30k/110.59k flops)
#     MobilenetV2/expanded_conv_11/project/weights/Initializer/truncated_normal/mul (55.30k/55.30k flops)
#   MobilenetV2/expanded_conv_9/expand/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_9/expand/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_10/expand/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_10/expand/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_9/project/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_9/project/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_8/project/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_8/project/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_8/expand/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_8/expand/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_10/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetV2/expanded_conv_10/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetV2/expanded_conv_7/project/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_7/project/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_7/expand/kernel/Regularizer/l2_regularizer (1/73.73k flops)
#     MobilenetV2/expanded_conv_7/expand/kernel/Regularizer/l2_regularizer/L2Loss (73.73k/73.73k flops)
#   MobilenetV2/expanded_conv_9/expand/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_9/expand/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_8/expand/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_8/expand/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_10/expand/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_10/expand/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_8/project/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_8/project/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_9/project/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_9/project/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_7/project/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_7/project/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_7/expand/weights/Initializer/truncated_normal (24.58k/49.15k flops)
#     MobilenetV2/expanded_conv_7/expand/weights/Initializer/truncated_normal/mul (24.58k/24.58k flops)
#   MobilenetV2/expanded_conv_6/project/kernel/Regularizer/l2_regularizer (1/36.86k flops)
#     MobilenetV2/expanded_conv_6/project/kernel/Regularizer/l2_regularizer/L2Loss (36.86k/36.86k flops)
#   MobilenetV2/expanded_conv_6/project/weights/Initializer/truncated_normal (12.29k/24.58k flops)
#     MobilenetV2/expanded_conv_6/project/weights/Initializer/truncated_normal/mul (12.29k/12.29k flops)
#   MobilenetV2/expanded_conv_4/project/kernel/Regularizer/l2_regularizer (1/18.43k flops)
#     MobilenetV2/expanded_conv_4/project/kernel/Regularizer/l2_regularizer/L2Loss (18.43k/18.43k flops)
#   MobilenetV2/expanded_conv_5/project/kernel/Regularizer/l2_regularizer (1/18.43k flops)
#     MobilenetV2/expanded_conv_5/project/kernel/Regularizer/l2_regularizer/L2Loss (18.43k/18.43k flops)
#   MobilenetV2/expanded_conv_4/expand/kernel/Regularizer/l2_regularizer (1/18.43k flops)
#     MobilenetV2/expanded_conv_4/expand/kernel/Regularizer/l2_regularizer/L2Loss (18.43k/18.43k flops)
#   MobilenetV2/expanded_conv_5/expand/kernel/Regularizer/l2_regularizer (1/18.43k flops)
#     MobilenetV2/expanded_conv_5/expand/kernel/Regularizer/l2_regularizer/L2Loss (18.43k/18.43k flops)
#   MobilenetV2/expanded_conv_6/expand/kernel/Regularizer/l2_regularizer (1/18.43k flops)
#     MobilenetV2/expanded_conv_6/expand/kernel/Regularizer/l2_regularizer/L2Loss (18.43k/18.43k flops)
#   MobilenetV2/expanded_conv_15/depthwise/depthwise_weights/Initializer/truncated_normal (8.64k/17.28k flops)
#     MobilenetV2/expanded_conv_15/depthwise/depthwise_weights/Initializer/truncated_normal/mul (8.64k/8.64k flops)
#   MobilenetV2/expanded_conv_14/depthwise/depthwise_weights/Initializer/truncated_normal (8.64k/17.28k flops)
#     MobilenetV2/expanded_conv_14/depthwise/depthwise_weights/Initializer/truncated_normal/mul (8.64k/8.64k flops)
#   MobilenetV2/expanded_conv_16/depthwise/depthwise_weights/Initializer/truncated_normal (8.64k/17.28k flops)
#     MobilenetV2/expanded_conv_16/depthwise/depthwise_weights/Initializer/truncated_normal/mul (8.64k/8.64k flops)
#   MobilenetV2/expanded_conv_3/project/kernel/Regularizer/l2_regularizer (1/13.82k flops)
#     MobilenetV2/expanded_conv_3/project/kernel/Regularizer/l2_regularizer/L2Loss (13.82k/13.82k flops)
#   MobilenetV2/expanded_conv_6/expand/weights/Initializer/truncated_normal (6.14k/12.29k flops)
#     MobilenetV2/expanded_conv_6/expand/weights/Initializer/truncated_normal/mul (6.14k/6.14k flops)
#   MobilenetV2/expanded_conv_5/expand/weights/Initializer/truncated_normal (6.14k/12.29k flops)
#     MobilenetV2/expanded_conv_5/expand/weights/Initializer/truncated_normal/mul (6.14k/6.14k flops)
#   MobilenetV2/expanded_conv_4/expand/weights/Initializer/truncated_normal (6.14k/12.29k flops)
#     MobilenetV2/expanded_conv_4/expand/weights/Initializer/truncated_normal/mul (6.14k/6.14k flops)
#   MobilenetV2/expanded_conv_4/project/weights/Initializer/truncated_normal (6.14k/12.29k flops)
#     MobilenetV2/expanded_conv_4/project/weights/Initializer/truncated_normal/mul (6.14k/6.14k flops)
#   MobilenetV2/expanded_conv_5/project/weights/Initializer/truncated_normal (6.14k/12.29k flops)
#     MobilenetV2/expanded_conv_5/project/weights/Initializer/truncated_normal/mul (6.14k/6.14k flops)
#   MobilenetV2/expanded_conv_11/depthwise/depthwise_weights/Initializer/truncated_normal (5.18k/10.37k flops)
#     MobilenetV2/expanded_conv_11/depthwise/depthwise_weights/Initializer/truncated_normal/mul (5.18k/5.18k flops)
#   MobilenetV2/expanded_conv_12/depthwise/depthwise_weights/Initializer/truncated_normal (5.18k/10.37k flops)
#     MobilenetV2/expanded_conv_12/depthwise/depthwise_weights/Initializer/truncated_normal/mul (5.18k/5.18k flops)
#   MobilenetV2/expanded_conv_13/depthwise/depthwise_weights/Initializer/truncated_normal (5.18k/10.37k flops)
#     MobilenetV2/expanded_conv_13/depthwise/depthwise_weights/Initializer/truncated_normal/mul (5.18k/5.18k flops)
#   MobilenetV2/expanded_conv_3/expand/kernel/Regularizer/l2_regularizer (1/10.37k flops)
#     MobilenetV2/expanded_conv_3/expand/kernel/Regularizer/l2_regularizer/L2Loss (10.37k/10.37k flops)
#   MobilenetV2/expanded_conv_2/expand/kernel/Regularizer/l2_regularizer (1/10.37k flops)
#     MobilenetV2/expanded_conv_2/expand/kernel/Regularizer/l2_regularizer/L2Loss (10.37k/10.37k flops)
#   MobilenetV2/expanded_conv_2/project/kernel/Regularizer/l2_regularizer (1/10.37k flops)
#     MobilenetV2/expanded_conv_2/project/kernel/Regularizer/l2_regularizer/L2Loss (10.37k/10.37k flops)
#   MobilenetV2/expanded_conv_3/project/weights/Initializer/truncated_normal (4.61k/9.22k flops)
#     MobilenetV2/expanded_conv_3/project/weights/Initializer/truncated_normal/mul (4.61k/4.61k flops)
#   MobilenetV2/expanded_conv_9/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_9/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_10/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_10/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_1/project/kernel/Regularizer/l2_regularizer (1/6.91k flops)
#     MobilenetV2/expanded_conv_1/project/kernel/Regularizer/l2_regularizer/L2Loss (6.91k/6.91k flops)
#   MobilenetV2/expanded_conv_8/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_8/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_7/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_7/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_3/expand/weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_3/expand/weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_2/expand/weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_2/expand/weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_2/project/weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetV2/expanded_conv_2/project/weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetV2/expanded_conv_1/expand/kernel/Regularizer/l2_regularizer (1/4.61k flops)
#     MobilenetV2/expanded_conv_1/expand/kernel/Regularizer/l2_regularizer/L2Loss (4.61k/4.61k flops)
#   MobilenetV2/expanded_conv_1/project/weights/Initializer/truncated_normal (2.30k/4.61k flops)
#     MobilenetV2/expanded_conv_1/project/weights/Initializer/truncated_normal/mul (2.30k/2.30k flops)
#   MobilenetV2/expanded_conv_6/depthwise/depthwise_weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV2/expanded_conv_6/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV2/expanded_conv_5/depthwise/depthwise_weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV2/expanded_conv_5/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV2/expanded_conv_4/depthwise/depthwise_weights/Initializer/truncated_normal (1.73k/3.46k flops)
#     MobilenetV2/expanded_conv_4/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.73k/1.73k flops)
#   MobilenetV2/expanded_conv_1/expand/weights/Initializer/truncated_normal (1.54k/3.07k flops)
#     MobilenetV2/expanded_conv_1/expand/weights/Initializer/truncated_normal/mul (1.54k/1.54k flops)
#   MobilenetV2/Conv/kernel/Regularizer/l2_regularizer (1/2.59k flops)
#     MobilenetV2/Conv/kernel/Regularizer/l2_regularizer/L2Loss (2.59k/2.59k flops)
#   MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/Initializer/truncated_normal (1.30k/2.59k flops)
#     MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.30k/1.30k flops)
#   MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/Initializer/truncated_normal (1.30k/2.59k flops)
#     MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/Initializer/truncated_normal/mul (1.30k/1.30k flops)
#   logits/semantic/BiasAdd (2.18k/2.18k flops)
#   MobilenetV2/Conv/weights/Initializer/truncated_normal (864/1.73k flops)
#     MobilenetV2/Conv/weights/Initializer/truncated_normal/mul (864/864 flops)
#   MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/Initializer/truncated_normal (864/1.73k flops)
#     MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/Initializer/truncated_normal/mul (864/864 flops)
#   logits/semantic/kernel/Regularizer/l2_regularizer (1/1.54k flops)
#     logits/semantic/kernel/Regularizer/l2_regularizer/L2Loss (1.53k/1.53k flops)
#   MobilenetV2/expanded_conv/project/kernel/Regularizer/l2_regularizer (1/1.54k flops)
#     MobilenetV2/expanded_conv/project/kernel/Regularizer/l2_regularizer/L2Loss (1.53k/1.53k flops)
#   logits/semantic/weights/Initializer/truncated_normal (512/1.02k flops)
#     logits/semantic/weights/Initializer/truncated_normal/mul (512/512 flops)
#   MobilenetV2/expanded_conv/project/weights/Initializer/truncated_normal (512/1.02k flops)
#     MobilenetV2/expanded_conv/project/weights/Initializer/truncated_normal/mul (512/512 flops)
#   MobilenetV2/expanded_conv/depthwise/depthwise_weights/Initializer/truncated_normal (288/576 flops)
#     MobilenetV2/expanded_conv/depthwise/depthwise_weights/Initializer/truncated_normal/mul (288/288 flops)
#   auc/div (200/200 flops)
#   auc/AssignAdd (200/200 flops)
#   auc/AssignAdd_1 (200/200 flops)
#   auc/AssignAdd_3 (200/200 flops)
#   auc/div_1 (200/200 flops)
#   auc/div_2 (200/200 flops)
#   auc/div_3 (200/200 flops)
#   auc/AssignAdd_2 (200/200 flops)
#   auc/Mul_5 (199/199 flops)
#   auc/sub (199/199 flops)
#   auc/sub_1 (199/199 flops)
#   auc/truediv (199/199 flops)
#   auc/truediv_1 (199/199 flops)
#   auc/Mul_4 (199/199 flops)
#   auc/update_op (198/198 flops)
#   auc/value (198/198 flops)
#   mean_iou/AssignAdd (4/4 flops)
#   mean_iou/sub (2/2 flops)
#   mean_iou/Greater (2/2 flops)
#   mean_iou/div (2/2 flops)
#   mean_iou/Sum_1 (2/2 flops)
#   mean_iou/Sum (2/2 flops)
#   mean_iou/NotEqual (2/2 flops)
#   recall/Greater_1 (1/1 flops)
#   recall/div_1 (1/1 flops)
#   recall/false_negatives/AssignAdd (1/1 flops)
#   precision/Greater (1/1 flops)
#   mean_iou/truediv (1/1 flops)
#   recall/true_positives/AssignAdd (1/1 flops)
#   false_negatives_2/AssignAdd (1/1 flops)
#   Greater_1 (1/1 flops)
#   Greater (1/1 flops)
#   false_positives/AssignAdd (1/1 flops)
#   true_negatives/AssignAdd (1/1 flops)
#   mean_iou/mean_iou (1/1 flops)
#   accuracy/AssignAdd (1/1 flops)
#   recall/div (1/1 flops)
#   true_negatives_1/AssignAdd (1/1 flops)
#   accuracy/AssignAdd_1 (1/1 flops)
#   accuracy/Maximum (1/1 flops)
#   false_positives_2/AssignAdd (1/1 flops)
#   true_negatives_2/AssignAdd (1/1 flops)
#   false_positives_1/AssignAdd (1/1 flops)
#   accuracy/Maximum_1 (1/1 flops)
#   precision/false_positives/AssignAdd (1/1 flops)
#   true_positives/AssignAdd (1/1 flops)
#   precision/true_positives/AssignAdd (1/1 flops)
#   precision/div_1 (1/1 flops)
#   mean_iou/Sum_2 (1/1 flops)
#   true_positives_1/AssignAdd (1/1 flops)
#   precision/div (1/1 flops)
#   false_negatives/AssignAdd (1/1 flops)
#   precision/Greater_1 (1/1 flops)
#   true_positives_2/AssignAdd (1/1 flops)
#   recall/Greater (1/1 flops)
#   mean_iou/Greater_1 (1/1 flops)
#   false_negatives_1/AssignAdd (1/1 flops)
#   truediv (1/1 flops)
#   truediv_1 (1/1 flops)
#
# ======================End of Report==========================
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAZZZZ

# %% [markdown]
# ### MobilenetEdgeTPU

# %%
# Proper MobilenetEdgeTPU Evaluation
# tensorboard --port=6007 --logdir="G:\segmentation_master\training_environment\ade_indoor\Evaluations/Evaluation_mnetpu"
# tensorboard --logdir="G:\segmentation_master\training_environment\ade_indoor\Checkpoints\Checkpoint"

# Though the eval_split says val, we are actually testing on the test set. We temporarilty rename the test shards for this script to run

# %cd G:\segmentation_master

# !python deeplab/eval.py \
  --logtostderr \
  --eval_split="val" \
  --model_variant="mobilenet_edgetpu" \
  --eval_crop_size=513,513 \
  --min_resize_value=513 \
  --max_resize_value=513 \
  --dataset="pascal_voc_seg" \
  --checkpoint_dir=training_environment/ade_indoor/Checkpoints/Checkpoint_mnetpu \
  --eval_logdir=training_environment/ade_indoor/Evaluations/Evaluation_mnetpu \
  --dataset_dir=training_environment/ade_indoor/TFRecord \
  --max_number_of_evaluations=1
# Out:
# G:\segmentation_master
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# 2022-12-07 16:40:51.237675: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:From deeplab/eval.py:263: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1207 16:40:54.413468  3808 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1207 16:40:54.413468  3808 module_wrapper.py:139] From deeplab/eval.py:91: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From deeplab/eval.py:108: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W1207 16:40:54.413468  3808 module_wrapper.py:139] From deeplab/eval.py:108: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# WARNING:tensorflow:From deeplab/eval.py:109: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# W1207 16:40:54.413468  3808 module_wrapper.py:139] From deeplab/eval.py:109: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Evaluating on val set
# I1207 16:40:54.413468  3808 eval.py:109] Evaluating on val set
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1207 16:40:54.413468  3808 module_wrapper.py:139] From G:\segmentation_master\deeplab\datasets\data_generator.py:355: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# W1207 16:40:54.623467  3808 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# W1207 16:40:54.623467  3808 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
#
# 2022-12-07 16:40:54.954913: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2022-12-07 16:40:54.969648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce GTX 1070 major: 6 minor: 1 memoryClockRate(GHz): 1.797
# pciBusID: 0000:01:00.0
# 2022-12-07 16:40:54.969680: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_100.dll
# 2022-12-07 16:40:54.971859: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_100.dll
# 2022-12-07 16:40:54.973981: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_100.dll
# 2022-12-07 16:40:54.974816: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_100.dll
# 2022-12-07 16:40:54.977586: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_100.dll
# 2022-12-07 16:40:54.979679: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_100.dll
# 2022-12-07 16:40:54.986222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2022-12-07 16:40:54.986292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# W1207 16:40:55.313424  3808 module_wrapper.py:139] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\autograph\converters\directives.py:119: The name tf.logging.warning is deprecated. Please use tf.compat.v1.logging.warning instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W1207 16:40:57.659565  3808 deprecation.py:323] From G:\segmentation_master\deeplab\datasets\data_generator.py:344: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Performing single-scale test.
# I1207 16:40:57.689563  3808 eval.py:127] Performing single-scale test.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# W1207 16:40:57.689563  3808 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:323: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1207 16:40:57.689563  3808 deprecation.py:323] From G:\segmentation_master\deeplab\core\feature_extractor.py:493: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1207 16:40:57.689563  3808 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\contrib\layers\python\layers\layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W1207 16:40:59.379601  3808 module_wrapper.py:139] From G:\segmentation_master\deeplab\core\utils.py:41: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1207 16:40:59.439598  3808 module_wrapper.py:139] From G:\segmentation_master\deeplab\model.py:897: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From deeplab/eval.py:150: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1207 16:40:59.469597  3808 deprecation.py:323] From deeplab/eval.py:150: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# W1207 16:40:59.469597  3808 module_wrapper.py:139] From deeplab/eval.py:161: The name tf.metrics.mean_iou is deprecated. Please use tf.compat.v1.metrics.mean_iou instead.
#
# WARNING:tensorflow:From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W1207 16:40:59.539592  3808 deprecation.py:323] From G:\anaconda_environments\cpsc483_tf1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:1178: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# W1207 16:40:59.539592  3808 module_wrapper.py:139] From deeplab/eval.py:165: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# W1207 16:40:59.593230  3808 module_wrapper.py:139] From deeplab/eval.py:168: The name tf.metrics.precision is deprecated. Please use tf.compat.v1.metrics.precision instead.
#
# WARNING:tensorflow:From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# W1207 16:40:59.620356  3808 module_wrapper.py:139] From deeplab/eval.py:171: The name tf.metrics.recall is deprecated. Please use tf.compat.v1.metrics.recall instead.
#
# WARNING:tensorflow:From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# W1207 16:40:59.650356  3808 module_wrapper.py:139] From deeplab/eval.py:174: The name tf.metrics.true_positives is deprecated. Please use tf.compat.v1.metrics.true_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# W1207 16:40:59.660355  3808 module_wrapper.py:139] From deeplab/eval.py:177: The name tf.metrics.true_negatives is deprecated. Please use tf.compat.v1.metrics.true_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# W1207 16:40:59.680354  3808 module_wrapper.py:139] From deeplab/eval.py:180: The name tf.metrics.false_positives is deprecated. Please use tf.compat.v1.metrics.false_positives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# W1207 16:40:59.690353  3808 module_wrapper.py:139] From deeplab/eval.py:183: The name tf.metrics.false_negatives is deprecated. Please use tf.compat.v1.metrics.false_negatives instead.
#
# WARNING:tensorflow:From deeplab/eval.py:186: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# W1207 16:40:59.700353  3808 module_wrapper.py:139] From deeplab/eval.py:186: The name tf.metrics.auc is deprecated. Please use tf.compat.v1.metrics.auc instead.
#
# WARNING:tensorflow:From deeplab/eval.py:227: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W1207 16:40:59.970347  3808 module_wrapper.py:139] From deeplab/eval.py:227: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From deeplab/eval.py:228: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
#
# W1207 16:40:59.970347  3808 deprecation.py:323] From deeplab/eval.py:228: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/3.60m params)
#   MobilenetEdgeTPU (--/2.81m params)
#     MobilenetEdgeTPU/Conv (--/928 params)
#       MobilenetEdgeTPU/Conv/BatchNorm (--/64 params)
#         MobilenetEdgeTPU/Conv/BatchNorm/beta (32, 32/32 params)
#         MobilenetEdgeTPU/Conv/BatchNorm/gamma (32, 32/32 params)
#       MobilenetEdgeTPU/Conv/weights (3x3x3x32, 864/864 params)
#     MobilenetEdgeTPU/Conv_1 (--/248.32k params)
#       MobilenetEdgeTPU/Conv_1/BatchNorm (--/2.56k params)
#         MobilenetEdgeTPU/Conv_1/BatchNorm/beta (1280, 1.28k/1.28k params)
#         MobilenetEdgeTPU/Conv_1/BatchNorm/gamma (1280, 1.28k/1.28k params)
#       MobilenetEdgeTPU/Conv_1/weights (1x1x192x1280, 245.76k/245.76k params)
#     MobilenetEdgeTPU/expanded_conv (--/544 params)
#       MobilenetEdgeTPU/expanded_conv/project (--/544 params)
#         MobilenetEdgeTPU/expanded_conv/project/BatchNorm (--/32 params)
#           MobilenetEdgeTPU/expanded_conv/project/BatchNorm/beta (16, 16/16 params)
#           MobilenetEdgeTPU/expanded_conv/project/BatchNorm/gamma (16, 16/16 params)
#         MobilenetEdgeTPU/expanded_conv/project/weights (1x1x32x16, 512/512 params)
#     MobilenetEdgeTPU/expanded_conv_1 (--/22.85k params)
#       MobilenetEdgeTPU/expanded_conv_1/expand (--/18.69k params)
#         MobilenetEdgeTPU/expanded_conv_1/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_1/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_1/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_1/expand/weights (3x3x16x128, 18.43k/18.43k params)
#       MobilenetEdgeTPU/expanded_conv_1/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_1/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_1/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_1/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_1/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_10 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_10/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_10/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_10/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_10/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_10/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_10/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_10/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_10/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_10/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_10/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_10/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_10/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_10/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_10/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_10/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_11 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_11/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_11/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_11/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_11/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_11/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_11/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_11/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_11/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_11/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_11/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_11/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_11/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_11/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_11/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_11/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_12 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_12/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_12/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_12/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_12/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_12/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_12/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_12/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_12/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_12/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_12/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_12/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_12/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_12/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_12/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_12/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_13 (--/157.63k params)
#       MobilenetEdgeTPU/expanded_conv_13/depthwise (--/8.45k params)
#         MobilenetEdgeTPU/expanded_conv_13/depthwise/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_13/depthwise/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_13/depthwise/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_13/depthwise/depthwise_weights (3x3x768x1, 6.91k/6.91k params)
#       MobilenetEdgeTPU/expanded_conv_13/expand (--/75.26k params)
#         MobilenetEdgeTPU/expanded_conv_13/expand/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_13/expand/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_13/expand/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_13/expand/weights (1x1x96x768, 73.73k/73.73k params)
#       MobilenetEdgeTPU/expanded_conv_13/project (--/73.92k params)
#         MobilenetEdgeTPU/expanded_conv_13/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_13/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_13/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_13/project/weights (1x1x768x96, 73.73k/73.73k params)
#     MobilenetEdgeTPU/expanded_conv_14 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_14/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_14/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_14/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_14/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_14/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_14/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_14/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_14/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_14/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_14/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_14/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_14/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_14/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_14/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_14/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_15 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_15/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_15/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_15/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_15/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_15/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_15/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_15/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_15/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_15/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_15/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_15/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_15/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_15/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_15/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_15/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_16 (--/78.91k params)
#       MobilenetEdgeTPU/expanded_conv_16/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_16/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_16/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_16/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_16/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_16/expand (--/37.63k params)
#         MobilenetEdgeTPU/expanded_conv_16/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_16/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_16/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_16/expand/weights (1x1x96x384, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_16/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_16/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_16/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_16/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_16/project/weights (1x1x384x96, 36.86k/36.86k params)
#     MobilenetEdgeTPU/expanded_conv_17 (--/219.20k params)
#       MobilenetEdgeTPU/expanded_conv_17/depthwise (--/20.74k params)
#         MobilenetEdgeTPU/expanded_conv_17/depthwise/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_17/depthwise/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_17/depthwise/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_17/depthwise/depthwise_weights (5x5x768x1, 19.20k/19.20k params)
#       MobilenetEdgeTPU/expanded_conv_17/expand (--/75.26k params)
#         MobilenetEdgeTPU/expanded_conv_17/expand/BatchNorm (--/1.54k params)
#           MobilenetEdgeTPU/expanded_conv_17/expand/BatchNorm/beta (768, 768/768 params)
#           MobilenetEdgeTPU/expanded_conv_17/expand/BatchNorm/gamma (768, 768/768 params)
#         MobilenetEdgeTPU/expanded_conv_17/expand/weights (1x1x96x768, 73.73k/73.73k params)
#       MobilenetEdgeTPU/expanded_conv_17/project (--/123.20k params)
#         MobilenetEdgeTPU/expanded_conv_17/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_17/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_17/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_17/project/weights (1x1x768x160, 122.88k/122.88k params)
#     MobilenetEdgeTPU/expanded_conv_18 (--/223.68k params)
#       MobilenetEdgeTPU/expanded_conv_18/depthwise (--/17.28k params)
#         MobilenetEdgeTPU/expanded_conv_18/depthwise/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_18/depthwise/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_18/depthwise/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_18/depthwise/depthwise_weights (5x5x640x1, 16.00k/16.00k params)
#       MobilenetEdgeTPU/expanded_conv_18/expand (--/103.68k params)
#         MobilenetEdgeTPU/expanded_conv_18/expand/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_18/expand/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_18/expand/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_18/expand/weights (1x1x160x640, 102.40k/102.40k params)
#       MobilenetEdgeTPU/expanded_conv_18/project (--/102.72k params)
#         MobilenetEdgeTPU/expanded_conv_18/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_18/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_18/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_18/project/weights (1x1x640x160, 102.40k/102.40k params)
#     MobilenetEdgeTPU/expanded_conv_19 (--/223.68k params)
#       MobilenetEdgeTPU/expanded_conv_19/depthwise (--/17.28k params)
#         MobilenetEdgeTPU/expanded_conv_19/depthwise/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_19/depthwise/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_19/depthwise/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_19/depthwise/depthwise_weights (5x5x640x1, 16.00k/16.00k params)
#       MobilenetEdgeTPU/expanded_conv_19/expand (--/103.68k params)
#         MobilenetEdgeTPU/expanded_conv_19/expand/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_19/expand/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_19/expand/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_19/expand/weights (1x1x160x640, 102.40k/102.40k params)
#       MobilenetEdgeTPU/expanded_conv_19/project (--/102.72k params)
#         MobilenetEdgeTPU/expanded_conv_19/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_19/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_19/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_19/project/weights (1x1x640x160, 102.40k/102.40k params)
#     MobilenetEdgeTPU/expanded_conv_2 (--/41.28k params)
#       MobilenetEdgeTPU/expanded_conv_2/expand (--/37.12k params)
#         MobilenetEdgeTPU/expanded_conv_2/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_2/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_2/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_2/expand/weights (3x3x32x128, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_2/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_2/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_2/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_2/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_2/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_20 (--/223.68k params)
#       MobilenetEdgeTPU/expanded_conv_20/depthwise (--/17.28k params)
#         MobilenetEdgeTPU/expanded_conv_20/depthwise/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_20/depthwise/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_20/depthwise/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_20/depthwise/depthwise_weights (5x5x640x1, 16.00k/16.00k params)
#       MobilenetEdgeTPU/expanded_conv_20/expand (--/103.68k params)
#         MobilenetEdgeTPU/expanded_conv_20/expand/BatchNorm (--/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_20/expand/BatchNorm/beta (640, 640/640 params)
#           MobilenetEdgeTPU/expanded_conv_20/expand/BatchNorm/gamma (640, 640/640 params)
#         MobilenetEdgeTPU/expanded_conv_20/expand/weights (1x1x160x640, 102.40k/102.40k params)
#       MobilenetEdgeTPU/expanded_conv_20/project (--/102.72k params)
#         MobilenetEdgeTPU/expanded_conv_20/project/BatchNorm (--/320 params)
#           MobilenetEdgeTPU/expanded_conv_20/project/BatchNorm/beta (160, 160/160 params)
#           MobilenetEdgeTPU/expanded_conv_20/project/BatchNorm/gamma (160, 160/160 params)
#         MobilenetEdgeTPU/expanded_conv_20/project/weights (1x1x640x160, 102.40k/102.40k params)
#     MobilenetEdgeTPU/expanded_conv_21 (--/467.58k params)
#       MobilenetEdgeTPU/expanded_conv_21/depthwise (--/14.08k params)
#         MobilenetEdgeTPU/expanded_conv_21/depthwise/BatchNorm (--/2.56k params)
#           MobilenetEdgeTPU/expanded_conv_21/depthwise/BatchNorm/beta (1280, 1.28k/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_21/depthwise/BatchNorm/gamma (1280, 1.28k/1.28k params)
#         MobilenetEdgeTPU/expanded_conv_21/depthwise/depthwise_weights (3x3x1280x1, 11.52k/11.52k params)
#       MobilenetEdgeTPU/expanded_conv_21/expand (--/207.36k params)
#         MobilenetEdgeTPU/expanded_conv_21/expand/BatchNorm (--/2.56k params)
#           MobilenetEdgeTPU/expanded_conv_21/expand/BatchNorm/beta (1280, 1.28k/1.28k params)
#           MobilenetEdgeTPU/expanded_conv_21/expand/BatchNorm/gamma (1280, 1.28k/1.28k params)
#         MobilenetEdgeTPU/expanded_conv_21/expand/weights (1x1x160x1280, 204.80k/204.80k params)
#       MobilenetEdgeTPU/expanded_conv_21/project (--/246.14k params)
#         MobilenetEdgeTPU/expanded_conv_21/project/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_21/project/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_21/project/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_21/project/weights (1x1x1280x192, 245.76k/245.76k params)
#     MobilenetEdgeTPU/expanded_conv_3 (--/41.28k params)
#       MobilenetEdgeTPU/expanded_conv_3/expand (--/37.12k params)
#         MobilenetEdgeTPU/expanded_conv_3/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_3/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_3/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_3/expand/weights (3x3x32x128, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_3/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_3/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_3/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_3/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_3/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_4 (--/41.28k params)
#       MobilenetEdgeTPU/expanded_conv_4/expand (--/37.12k params)
#         MobilenetEdgeTPU/expanded_conv_4/expand/BatchNorm (--/256 params)
#           MobilenetEdgeTPU/expanded_conv_4/expand/BatchNorm/beta (128, 128/128 params)
#           MobilenetEdgeTPU/expanded_conv_4/expand/BatchNorm/gamma (128, 128/128 params)
#         MobilenetEdgeTPU/expanded_conv_4/expand/weights (3x3x32x128, 36.86k/36.86k params)
#       MobilenetEdgeTPU/expanded_conv_4/project (--/4.16k params)
#         MobilenetEdgeTPU/expanded_conv_4/project/BatchNorm (--/64 params)
#           MobilenetEdgeTPU/expanded_conv_4/project/BatchNorm/beta (32, 32/32 params)
#           MobilenetEdgeTPU/expanded_conv_4/project/BatchNorm/gamma (32, 32/32 params)
#         MobilenetEdgeTPU/expanded_conv_4/project/weights (1x1x128x32, 4.10k/4.10k params)
#     MobilenetEdgeTPU/expanded_conv_5 (--/86.62k params)
#       MobilenetEdgeTPU/expanded_conv_5/expand (--/74.24k params)
#         MobilenetEdgeTPU/expanded_conv_5/expand/BatchNorm (--/512 params)
#           MobilenetEdgeTPU/expanded_conv_5/expand/BatchNorm/beta (256, 256/256 params)
#           MobilenetEdgeTPU/expanded_conv_5/expand/BatchNorm/gamma (256, 256/256 params)
#         MobilenetEdgeTPU/expanded_conv_5/expand/weights (3x3x32x256, 73.73k/73.73k params)
#       MobilenetEdgeTPU/expanded_conv_5/project (--/12.38k params)
#         MobilenetEdgeTPU/expanded_conv_5/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_5/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_5/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_5/project/weights (1x1x256x48, 12.29k/12.29k params)
#     MobilenetEdgeTPU/expanded_conv_6 (--/92.64k params)
#       MobilenetEdgeTPU/expanded_conv_6/expand (--/83.33k params)
#         MobilenetEdgeTPU/expanded_conv_6/expand/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_6/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_6/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_6/expand/weights (3x3x48x192, 82.94k/82.94k params)
#       MobilenetEdgeTPU/expanded_conv_6/project (--/9.31k params)
#         MobilenetEdgeTPU/expanded_conv_6/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_6/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_6/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_6/project/weights (1x1x192x48, 9.22k/9.22k params)
#     MobilenetEdgeTPU/expanded_conv_7 (--/92.64k params)
#       MobilenetEdgeTPU/expanded_conv_7/expand (--/83.33k params)
#         MobilenetEdgeTPU/expanded_conv_7/expand/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_7/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_7/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_7/expand/weights (3x3x48x192, 82.94k/82.94k params)
#       MobilenetEdgeTPU/expanded_conv_7/project (--/9.31k params)
#         MobilenetEdgeTPU/expanded_conv_7/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_7/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_7/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_7/project/weights (1x1x192x48, 9.22k/9.22k params)
#     MobilenetEdgeTPU/expanded_conv_8 (--/92.64k params)
#       MobilenetEdgeTPU/expanded_conv_8/expand (--/83.33k params)
#         MobilenetEdgeTPU/expanded_conv_8/expand/BatchNorm (--/384 params)
#           MobilenetEdgeTPU/expanded_conv_8/expand/BatchNorm/beta (192, 192/192 params)
#           MobilenetEdgeTPU/expanded_conv_8/expand/BatchNorm/gamma (192, 192/192 params)
#         MobilenetEdgeTPU/expanded_conv_8/expand/weights (3x3x48x192, 82.94k/82.94k params)
#       MobilenetEdgeTPU/expanded_conv_8/project (--/9.31k params)
#         MobilenetEdgeTPU/expanded_conv_8/project/BatchNorm (--/96 params)
#           MobilenetEdgeTPU/expanded_conv_8/project/BatchNorm/beta (48, 48/48 params)
#           MobilenetEdgeTPU/expanded_conv_8/project/BatchNorm/gamma (48, 48/48 params)
#         MobilenetEdgeTPU/expanded_conv_8/project/weights (1x1x192x48, 9.22k/9.22k params)
#     MobilenetEdgeTPU/expanded_conv_9 (--/60.48k params)
#       MobilenetEdgeTPU/expanded_conv_9/depthwise (--/4.22k params)
#         MobilenetEdgeTPU/expanded_conv_9/depthwise/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_9/depthwise/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_9/depthwise/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_9/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#       MobilenetEdgeTPU/expanded_conv_9/expand (--/19.20k params)
#         MobilenetEdgeTPU/expanded_conv_9/expand/BatchNorm (--/768 params)
#           MobilenetEdgeTPU/expanded_conv_9/expand/BatchNorm/beta (384, 384/384 params)
#           MobilenetEdgeTPU/expanded_conv_9/expand/BatchNorm/gamma (384, 384/384 params)
#         MobilenetEdgeTPU/expanded_conv_9/expand/weights (1x1x48x384, 18.43k/18.43k params)
#       MobilenetEdgeTPU/expanded_conv_9/project (--/37.06k params)
#         MobilenetEdgeTPU/expanded_conv_9/project/BatchNorm (--/192 params)
#           MobilenetEdgeTPU/expanded_conv_9/project/BatchNorm/beta (96, 96/96 params)
#           MobilenetEdgeTPU/expanded_conv_9/project/BatchNorm/gamma (96, 96/96 params)
#         MobilenetEdgeTPU/expanded_conv_9/project/weights (1x1x384x96, 36.86k/36.86k params)
#   aspp0 (--/328.19k params)
#     aspp0/BatchNorm (--/512 params)
#       aspp0/BatchNorm/beta (256, 256/256 params)
#       aspp0/BatchNorm/gamma (256, 256/256 params)
#     aspp0/weights (1x1x1280x256, 327.68k/327.68k params)
#   concat_projection (--/131.58k params)
#     concat_projection/BatchNorm (--/512 params)
#       concat_projection/BatchNorm/beta (256, 256/256 params)
#       concat_projection/BatchNorm/gamma (256, 256/256 params)
#     concat_projection/weights (1x1x512x256, 131.07k/131.07k params)
#   image_pooling (--/328.19k params)
#     image_pooling/BatchNorm (--/512 params)
#       image_pooling/BatchNorm/beta (256, 256/256 params)
#       image_pooling/BatchNorm/gamma (256, 256/256 params)
#     image_pooling/weights (1x1x1280x256, 327.68k/327.68k params)
#   logits (--/514 params)
#     logits/semantic (--/514 params)
#       logits/semantic/biases (2, 2/2 params)
#       logits/semantic/weights (1x1x256x2, 512/512 params)
#
# ======================End of Report==========================
# Parsing Inputs...
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/14.65b flops)
#   MobilenetEdgeTPU/expanded_conv_4/expand/Conv2D (1.23b/1.23b flops)
#   MobilenetEdgeTPU/expanded_conv_3/expand/Conv2D (1.23b/1.23b flops)
#   MobilenetEdgeTPU/expanded_conv_2/expand/Conv2D (1.23b/1.23b flops)
#   aspp0/Conv2D (713.69m/713.69m flops)
#   MobilenetEdgeTPU/expanded_conv_6/expand/Conv2D (700.88m/700.88m flops)
#   MobilenetEdgeTPU/expanded_conv_8/expand/Conv2D (700.88m/700.88m flops)
#   MobilenetEdgeTPU/expanded_conv_7/expand/Conv2D (700.88m/700.88m flops)
#   MobilenetEdgeTPU/expanded_conv_5/expand/Conv2D (623.00m/623.00m flops)
#   MobilenetEdgeTPU/expanded_conv_1/expand/Conv2D (613.45m/613.45m flops)
#   MobilenetEdgeTPU/Conv_1/Conv2D (535.27m/535.27m flops)
#   MobilenetEdgeTPU/expanded_conv_21/project/Conv2D (535.27m/535.27m flops)
#   MobilenetEdgeTPU/expanded_conv_21/expand/Conv2D (446.05m/446.05m flops)
#   concat_projection/Conv2D (285.47m/285.47m flops)
#   MobilenetEdgeTPU/expanded_conv_17/project/Conv2D (267.63m/267.63m flops)
#   MobilenetEdgeTPU/expanded_conv_18/expand/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_19/expand/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_20/expand/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_20/project/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_18/project/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_19/project/Conv2D (223.03m/223.03m flops)
#   MobilenetEdgeTPU/expanded_conv_13/expand/Conv2D (160.58m/160.58m flops)
#   MobilenetEdgeTPU/expanded_conv_17/expand/Conv2D (160.58m/160.58m flops)
#   MobilenetEdgeTPU/expanded_conv_13/project/Conv2D (160.58m/160.58m flops)
#   MobilenetEdgeTPU/expanded_conv_9/expand/Conv2D (155.75m/155.75m flops)
#   MobilenetEdgeTPU/expanded_conv_2/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/expanded_conv_3/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/expanded_conv_1/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/expanded_conv_4/project/Conv2D (136.32m/136.32m flops)
#   MobilenetEdgeTPU/Conv/Conv2D (114.13m/114.13m flops)
#   MobilenetEdgeTPU/expanded_conv_5/project/Conv2D (103.83m/103.83m flops)
#   MobilenetEdgeTPU/expanded_conv_12/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_11/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_11/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_12/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_9/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_15/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_15/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_16/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_16/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_14/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_10/expand/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_10/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_14/project/Conv2D (80.29m/80.29m flops)
#   MobilenetEdgeTPU/expanded_conv_6/project/Conv2D (77.88m/77.88m flops)
#   MobilenetEdgeTPU/expanded_conv_7/project/Conv2D (77.88m/77.88m flops)
#   MobilenetEdgeTPU/expanded_conv_8/project/Conv2D (77.88m/77.88m flops)
#   MobilenetEdgeTPU/expanded_conv/project/Conv2D (67.63m/67.63m flops)
#   auc/mul_1 (52.63m/52.63m flops)
#   auc/mul_2 (52.63m/52.63m flops)
#   auc/Greater (52.63m/52.63m flops)
#   auc/mul (52.63m/52.63m flops)
#   auc/mul_3 (52.63m/52.63m flops)
#   auc/Sum_1 (52.63m/52.63m flops)
#   auc/Sum_2 (52.63m/52.63m flops)
#   auc/Sum_3 (52.63m/52.63m flops)
#   auc/Sum (52.63m/52.63m flops)
#   MobilenetEdgeTPU/expanded_conv_17/depthwise/depthwise (41.82m/41.82m flops)
#   MobilenetEdgeTPU/expanded_conv_18/depthwise/depthwise (36.99m/36.99m flops)
#   MobilenetEdgeTPU/expanded_conv_19/depthwise/depthwise (36.99m/36.99m flops)
#   MobilenetEdgeTPU/expanded_conv_20/depthwise/depthwise (36.99m/36.99m flops)
#   MobilenetEdgeTPU/expanded_conv_21/depthwise/depthwise (26.63m/26.63m flops)
#   MobilenetEdgeTPU/expanded_conv_13/depthwise/depthwise (15.05m/15.05m flops)
#   MobilenetEdgeTPU/expanded_conv_10/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_9/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_14/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_11/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_15/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_12/depthwise/depthwise (7.53m/7.53m flops)
#   MobilenetEdgeTPU/expanded_conv_16/depthwise/depthwise (7.53m/7.53m flops)
#   Softmax (2.63m/2.63m flops)
#   AvgPool2D/AvgPool (1.39m/1.39m flops)
#   logits/semantic/Conv2D (1.12m/1.12m flops)
#   image_pooling/kernel/Regularizer/l2_regularizer (1/983.04k flops)
#     image_pooling/kernel/Regularizer/l2_regularizer/L2Loss (983.04k/983.04k flops)
#   aspp0/kernel/Regularizer/l2_regularizer (1/983.04k flops)
#     aspp0/kernel/Regularizer/l2_regularizer/L2Loss (983.04k/983.04k flops)
#   sub (789.51k/789.51k flops)
#   mul (789.51k/789.51k flops)
#   MobilenetEdgeTPU/Conv_1/kernel/Regularizer/l2_regularizer (1/737.28k flops)
#     MobilenetEdgeTPU/Conv_1/kernel/Regularizer/l2_regularizer/L2Loss (737.28k/737.28k flops)
#   MobilenetEdgeTPU/expanded_conv_21/project/kernel/Regularizer/l2_regularizer (1/737.28k flops)
#     MobilenetEdgeTPU/expanded_conv_21/project/kernel/Regularizer/l2_regularizer/L2Loss (737.28k/737.28k flops)
#   image_pooling/weights/Initializer/random_uniform (327.68k/655.36k flops)
#     image_pooling/weights/Initializer/random_uniform/mul (327.68k/327.68k flops)
#     image_pooling/weights/Initializer/random_uniform/sub (1/1 flops)
#   aspp0/weights/Initializer/random_uniform (327.68k/655.36k flops)
#     aspp0/weights/Initializer/random_uniform/mul (327.68k/327.68k flops)
# ...
#     MobilenetEdgeTPU/expanded_conv_12/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_14/expand/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_14/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_14/project/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_14/project/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_15/expand/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_15/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_15/project/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_15/project/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_16/expand/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_16/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_16/project/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_16/project/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_12/project/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_12/project/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_2/expand/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_2/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_3/expand/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_3/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_4/expand/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_4/expand/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_11/project/kernel/Regularizer/l2_regularizer (1/110.59k flops)
#     MobilenetEdgeTPU/expanded_conv_11/project/kernel/Regularizer/l2_regularizer/L2Loss (110.59k/110.59k flops)
#   MobilenetEdgeTPU/expanded_conv_16/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_16/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_11/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_11/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_3/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_3/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_16/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_16/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_10/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_10/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_15/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_15/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_15/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_15/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_10/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_10/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_14/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_14/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_14/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_14/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_4/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_4/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_9/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_9/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_12/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_12/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_12/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_12/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_2/expand/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_2/expand/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_11/project/weights/Initializer/truncated_normal (36.86k/73.73k flops)
#     MobilenetEdgeTPU/expanded_conv_11/project/weights/Initializer/truncated_normal/mul (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_1/expand/kernel/Regularizer/l2_regularizer (1/55.30k flops)
#     MobilenetEdgeTPU/expanded_conv_1/expand/kernel/Regularizer/l2_regularizer/L2Loss (55.30k/55.30k flops)
#   MobilenetEdgeTPU/expanded_conv_9/expand/kernel/Regularizer/l2_regularizer (1/55.30k flops)
#     MobilenetEdgeTPU/expanded_conv_9/expand/kernel/Regularizer/l2_regularizer/L2Loss (55.30k/55.30k flops)
#   MobilenetEdgeTPU/expanded_conv_17/depthwise/depthwise_weights/Initializer/truncated_normal (19.20k/38.40k flops)
#     MobilenetEdgeTPU/expanded_conv_17/depthwise/depthwise_weights/Initializer/truncated_normal/mul (19.20k/19.20k flops)
#   MobilenetEdgeTPU/expanded_conv_9/expand/weights/Initializer/truncated_normal (18.43k/36.86k flops)
#     MobilenetEdgeTPU/expanded_conv_9/expand/weights/Initializer/truncated_normal/mul (18.43k/18.43k flops)
#   MobilenetEdgeTPU/expanded_conv_5/project/kernel/Regularizer/l2_regularizer (1/36.86k flops)
#     MobilenetEdgeTPU/expanded_conv_5/project/kernel/Regularizer/l2_regularizer/L2Loss (36.86k/36.86k flops)
#   MobilenetEdgeTPU/expanded_conv_1/expand/weights/Initializer/truncated_normal (18.43k/36.86k flops)
#     MobilenetEdgeTPU/expanded_conv_1/expand/weights/Initializer/truncated_normal/mul (18.43k/18.43k flops)
#   MobilenetEdgeTPU/expanded_conv_18/depthwise/depthwise_weights/Initializer/truncated_normal (16.00k/32.00k flops)
#     MobilenetEdgeTPU/expanded_conv_18/depthwise/depthwise_weights/Initializer/truncated_normal/mul (16.00k/16.00k flops)
#   MobilenetEdgeTPU/expanded_conv_20/depthwise/depthwise_weights/Initializer/truncated_normal (16.00k/32.00k flops)
#     MobilenetEdgeTPU/expanded_conv_20/depthwise/depthwise_weights/Initializer/truncated_normal/mul (16.00k/16.00k flops)
#   MobilenetEdgeTPU/expanded_conv_19/depthwise/depthwise_weights/Initializer/truncated_normal (16.00k/32.00k flops)
#     MobilenetEdgeTPU/expanded_conv_19/depthwise/depthwise_weights/Initializer/truncated_normal/mul (16.00k/16.00k flops)
#   MobilenetEdgeTPU/expanded_conv_7/project/kernel/Regularizer/l2_regularizer (1/27.65k flops)
#     MobilenetEdgeTPU/expanded_conv_7/project/kernel/Regularizer/l2_regularizer/L2Loss (27.65k/27.65k flops)
#   MobilenetEdgeTPU/expanded_conv_8/project/kernel/Regularizer/l2_regularizer (1/27.65k flops)
#     MobilenetEdgeTPU/expanded_conv_8/project/kernel/Regularizer/l2_regularizer/L2Loss (27.65k/27.65k flops)
#   MobilenetEdgeTPU/expanded_conv_6/project/kernel/Regularizer/l2_regularizer (1/27.65k flops)
#     MobilenetEdgeTPU/expanded_conv_6/project/kernel/Regularizer/l2_regularizer/L2Loss (27.65k/27.65k flops)
#   MobilenetEdgeTPU/expanded_conv_5/project/weights/Initializer/truncated_normal (12.29k/24.58k flops)
#     MobilenetEdgeTPU/expanded_conv_5/project/weights/Initializer/truncated_normal/mul (12.29k/12.29k flops)
#   MobilenetEdgeTPU/expanded_conv_21/depthwise/depthwise_weights/Initializer/truncated_normal (11.52k/23.04k flops)
#     MobilenetEdgeTPU/expanded_conv_21/depthwise/depthwise_weights/Initializer/truncated_normal/mul (11.52k/11.52k flops)
#   MobilenetEdgeTPU/expanded_conv_7/project/weights/Initializer/truncated_normal (9.22k/18.43k flops)
#     MobilenetEdgeTPU/expanded_conv_7/project/weights/Initializer/truncated_normal/mul (9.22k/9.22k flops)
#   MobilenetEdgeTPU/expanded_conv_8/project/weights/Initializer/truncated_normal (9.22k/18.43k flops)
#     MobilenetEdgeTPU/expanded_conv_8/project/weights/Initializer/truncated_normal/mul (9.22k/9.22k flops)
#   MobilenetEdgeTPU/expanded_conv_6/project/weights/Initializer/truncated_normal (9.22k/18.43k flops)
#     MobilenetEdgeTPU/expanded_conv_6/project/weights/Initializer/truncated_normal/mul (9.22k/9.22k flops)
#   MobilenetEdgeTPU/expanded_conv_13/depthwise/depthwise_weights/Initializer/truncated_normal (6.91k/13.82k flops)
#     MobilenetEdgeTPU/expanded_conv_13/depthwise/depthwise_weights/Initializer/truncated_normal/mul (6.91k/6.91k flops)
#   MobilenetEdgeTPU/expanded_conv_4/project/kernel/Regularizer/l2_regularizer (1/12.29k flops)
#     MobilenetEdgeTPU/expanded_conv_4/project/kernel/Regularizer/l2_regularizer/L2Loss (12.29k/12.29k flops)
#   MobilenetEdgeTPU/expanded_conv_1/project/kernel/Regularizer/l2_regularizer (1/12.29k flops)
#     MobilenetEdgeTPU/expanded_conv_1/project/kernel/Regularizer/l2_regularizer/L2Loss (12.29k/12.29k flops)
#   MobilenetEdgeTPU/expanded_conv_3/project/kernel/Regularizer/l2_regularizer (1/12.29k flops)
#     MobilenetEdgeTPU/expanded_conv_3/project/kernel/Regularizer/l2_regularizer/L2Loss (12.29k/12.29k flops)
#   MobilenetEdgeTPU/expanded_conv_2/project/kernel/Regularizer/l2_regularizer (1/12.29k flops)
#     MobilenetEdgeTPU/expanded_conv_2/project/kernel/Regularizer/l2_regularizer/L2Loss (12.29k/12.29k flops)
#   MobilenetEdgeTPU/expanded_conv_2/project/weights/Initializer/truncated_normal (4.10k/8.19k flops)
#     MobilenetEdgeTPU/expanded_conv_2/project/weights/Initializer/truncated_normal/mul (4.10k/4.10k flops)
#   MobilenetEdgeTPU/expanded_conv_3/project/weights/Initializer/truncated_normal (4.10k/8.19k flops)
#     MobilenetEdgeTPU/expanded_conv_3/project/weights/Initializer/truncated_normal/mul (4.10k/4.10k flops)
#   MobilenetEdgeTPU/expanded_conv_4/project/weights/Initializer/truncated_normal (4.10k/8.19k flops)
#     MobilenetEdgeTPU/expanded_conv_4/project/weights/Initializer/truncated_normal/mul (4.10k/4.10k flops)
#   MobilenetEdgeTPU/expanded_conv_1/project/weights/Initializer/truncated_normal (4.10k/8.19k flops)
#     MobilenetEdgeTPU/expanded_conv_1/project/weights/Initializer/truncated_normal/mul (4.10k/4.10k flops)
#   MobilenetEdgeTPU/expanded_conv_16/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_16/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/expanded_conv_15/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_15/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/expanded_conv_14/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_14/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/expanded_conv_12/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_12/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/expanded_conv_11/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_11/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/expanded_conv_10/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_10/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/expanded_conv_9/depthwise/depthwise_weights/Initializer/truncated_normal (3.46k/6.91k flops)
#     MobilenetEdgeTPU/expanded_conv_9/depthwise/depthwise_weights/Initializer/truncated_normal/mul (3.46k/3.46k flops)
#   MobilenetEdgeTPU/Conv/kernel/Regularizer/l2_regularizer (1/2.59k flops)
#     MobilenetEdgeTPU/Conv/kernel/Regularizer/l2_regularizer/L2Loss (2.59k/2.59k flops)
#   logits/semantic/BiasAdd (2.18k/2.18k flops)
#   MobilenetEdgeTPU/Conv/weights/Initializer/truncated_normal (864/1.73k flops)
#     MobilenetEdgeTPU/Conv/weights/Initializer/truncated_normal/mul (864/864 flops)
#   logits/semantic/kernel/Regularizer/l2_regularizer (1/1.54k flops)
#     logits/semantic/kernel/Regularizer/l2_regularizer/L2Loss (1.53k/1.53k flops)
#   MobilenetEdgeTPU/expanded_conv/project/kernel/Regularizer/l2_regularizer (1/1.54k flops)
#     MobilenetEdgeTPU/expanded_conv/project/kernel/Regularizer/l2_regularizer/L2Loss (1.53k/1.53k flops)
#   logits/semantic/weights/Initializer/truncated_normal (512/1.02k flops)
#     logits/semantic/weights/Initializer/truncated_normal/mul (512/512 flops)
#   MobilenetEdgeTPU/expanded_conv/project/weights/Initializer/truncated_normal (512/1.02k flops)
#     MobilenetEdgeTPU/expanded_conv/project/weights/Initializer/truncated_normal/mul (512/512 flops)
#   auc/AssignAdd (200/200 flops)
#   auc/AssignAdd_1 (200/200 flops)
#   auc/AssignAdd_2 (200/200 flops)
#   auc/div (200/200 flops)
#   auc/div_1 (200/200 flops)
#   auc/div_2 (200/200 flops)
#   auc/div_3 (200/200 flops)
#   auc/AssignAdd_3 (200/200 flops)
#   auc/sub (199/199 flops)
#   auc/sub_1 (199/199 flops)
#   auc/truediv (199/199 flops)
#   auc/truediv_1 (199/199 flops)
#   auc/Mul_5 (199/199 flops)
#   auc/Mul_4 (199/199 flops)
#   auc/update_op (198/198 flops)
#   auc/value (198/198 flops)
#   mean_iou/AssignAdd (4/4 flops)
#   mean_iou/Sum (2/2 flops)
#   mean_iou/Greater (2/2 flops)
#   mean_iou/NotEqual (2/2 flops)
#   mean_iou/Sum_1 (2/2 flops)
#   mean_iou/div (2/2 flops)
#   mean_iou/sub (2/2 flops)
#   recall/Greater (1/1 flops)
#   recall/Greater_1 (1/1 flops)
#   recall/div (1/1 flops)
#   recall/div_1 (1/1 flops)
#   recall/false_negatives/AssignAdd (1/1 flops)
#   false_positives/AssignAdd (1/1 flops)
#   Greater_1 (1/1 flops)
#   Greater (1/1 flops)
#   recall/true_positives/AssignAdd (1/1 flops)
#   accuracy/Maximum_1 (1/1 flops)
#   false_positives_1/AssignAdd (1/1 flops)
#   true_negatives/AssignAdd (1/1 flops)
#   mean_iou/Greater_1 (1/1 flops)
#   false_negatives/AssignAdd (1/1 flops)
#   true_negatives_1/AssignAdd (1/1 flops)
#   accuracy/Maximum (1/1 flops)
#   mean_iou/Sum_2 (1/1 flops)
#   false_negatives_1/AssignAdd (1/1 flops)
#   true_negatives_2/AssignAdd (1/1 flops)
#   false_negatives_2/AssignAdd (1/1 flops)
#   precision/true_positives/AssignAdd (1/1 flops)
#   mean_iou/mean_iou (1/1 flops)
#   true_positives/AssignAdd (1/1 flops)
#   accuracy/AssignAdd_1 (1/1 flops)
#   mean_iou/truediv (1/1 flops)
#   accuracy/AssignAdd (1/1 flops)
#   true_positives_1/AssignAdd (1/1 flops)
#   precision/Greater (1/1 flops)
#   precision/Greater_1 (1/1 flops)
#   precision/div (1/1 flops)
#   true_positives_2/AssignAdd (1/1 flops)
#   precision/div_1 (1/1 flops)
#   precision/false_positives/AssignAdd (1/1 flops)
#   false_positives_2/AssignAdd (1/1 flops)
#   truediv (1/1 flops)
#   truediv_1 (1/1 flops)
#
# ======================End of Report==========================
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAZZZZ

# %% [markdown]
# ## Summarize Metrics

# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
def display_confusion_matrix(name,
                    true_positives,
                    true_negatives,
                    false_positives,
                    false_negatives,
                    pixel_accuracy,
                    recall,
                    precision,
                    jaccard,
                    roc_auc):
    
    print("{} Pixel Accuracy on the test image = {}".format(name, pixel_accuracy))
    print("{} Recall on the test image = {}".format(name, recall))
    print("{} Precision on the test image = {}".format(name, precision))
    print("{} Jaccard Score on the test image = {}".format(name, jaccard))
    print("{} ROC AUC on the test image = {}".format(name, roc_auc))
    
    cm_mobilenet_etpu = np.array([
        [true_negatives, false_positives],
        [false_negatives, true_positives]])
    ls = [0, 1] # your y labels
    disp = ConfusionMatrixDisplay(confusion_matrix=np.array(cm_mobilenet_etpu), display_labels=ls)
    fig, ax = plt.subplots(figsize=(2,2))
    ax.set_title(name)
    disp.plot(ax=ax)
    
def display_auc_roc(name,
                    true_positives,
                    true_negatives,
                    false_positives,
                    false_negatives):
    fpr_instance = 1.0 - (true_negatives/(true_negatives+false_positives))
    tpr_instance = true_positives/(true_positives+false_negatives)
    
    fpr = [0.0, fpr_instance, 1.0]
    tpr = [0.0, tpr_instance, 1.0]
    
    fig, ax = plt.subplots()
    ax.plot(fpr, tpr, linewidth=2.0)
    plt.show()

# %% [markdown]
# ### ResNetV1

# %%
'''
Values calculated from running eval.py:
false_negatives[30495388]
true_positives[176757184]
true_negatives[17023848]
false_positives[13111568]
pixel_accuracy[0.816307485]
recall[0.852858782]
precision[0.930944]
eval/miou_1.0_class_0[0.280778855]
eval/miou_1.0_class_1[0.802114069]
auc[0.708885193]
eval/miou_1.0_overall[0.541446567]
'''
        
display_confusion_matrix(name="ResNetV1",
                true_positives=176757184,
                true_negatives=17023848,
                false_positives=13111568,
                false_negatives=30495388,
                pixel_accuracy=0.816307485,
                recall=0.852858782,
                precision=0.930944,
                jaccard=0.541446567,
                roc_auc=0.708885193)

display_auc_roc(name="ResNetV1",
                true_positives=176757184,
                true_negatives=17023848,
                false_positives=13111568,
                false_negatives=30495388)
# Out:
# ResNetV1 Pixel Accuracy on the test image = 0.816307485
# ResNetV1 Recall on the test image = 0.852858782
# ResNetV1 Precision on the test image = 0.930944
# ResNetV1 Jaccard Score on the test image = 0.541446567
# ResNetV1 ROC AUC on the test image = 0.708885193

# %% [markdown]
# ### MobilenetV2

# %%
    '''
Values calculated from running eval.py:
true_positives[204620400]
false_positives[5292444]
true_negatives[24842974]
false_negatives[2632436]
pixel_accuracy[0.966617703]
recall[0.987298429]
precision[0.974787414]
eval/miou_1.0_class_0[0.758150756]
eval/miou_1.0_class_1[0.962714374]
auc[0.905838192]
eval/miou_1.0_overall[0.860432506]
'''
display_confusion_matrix(name="MobilenetV2",
                true_positives=204620400,
                true_negatives=24842974,
                false_positives=5292444,
                false_negatives=2632436,
                pixel_accuracy=0.966617703,
                recall=0.987298429,
                precision=0.974787414,
                jaccard=0.860432506,
                roc_auc=0.905838192)
# Out:
# MobilenetV2 Pixel Accuracy on the test image = 0.966617703
# MobilenetV2 Recall on the test image = 0.987298429
# MobilenetV2 Precision on the test image = 0.974787414
# MobilenetV2 Jaccard Score on the test image = 0.860432506
# MobilenetV2 ROC AUC on the test image = 0.905838192

# %% [markdown]
# ### MobileNetEdgeTPU

# %%
'''
Values calculated from running eval.py:
true_negatives[22977736]
true_positives[204014224]
false_positives[7.15767e+06]
false_negatives[3238608]
pixel_accuracy[0.956207633]
recall[0.984373629]
precision[0.966105044]
eval/miou_1.0_class_1[0.951512277]
eval/miou_1.0_class_0[0.688491821]
roc_auc[0.873428345]
eval/miou_1.0_overall[0.820002079]
'''
display_confusion_matrix(name="MobilenetEdgeTPU",
                true_positives=204014224,
                true_negatives=22977736,
                false_positives=7.15767e+06,
                false_negatives=3238608,
                pixel_accuracy=0.956207633,
                recall=0.984373629,
                precision=0.966105044,
                jaccard=0.820002079,
                roc_auc=0.873428345)
# Out:
# MobilenetEdgeTPU Pixel Accuracy on the test image = 0.956207633
# MobilenetEdgeTPU Recall on the test image = 0.984373629
# MobilenetEdgeTPU Precision on the test image = 0.966105044
# MobilenetEdgeTPU Jaccard Score on the test image = 0.820002079
# MobilenetEdgeTPU ROC AUC on the test image = 0.873428345

# %%
def calculate_fpr_instance(tn, fp):
    return 1.0 - (tn/(tn+fp))

def calculate_tpr_instance(tp, fn):
    return tp/(tp+fn)
    
def plot_roc_curves(
    logistic_regression_tp_tn_fp_fn, 
    svm_tp_tn_fp_fn,
    random_forest_tp_tn_fp_fn,
    resnet_tp_tn_fp_fn,
    mobilenet_v2_tp_tn_fp_fn,
    mobilenet_etpu_tp_tn_fp_fn
):
    logistic_regression_fpr = [0.0, calculate_fpr_instance(logistic_regression_tp_tn_fp_fn[1], logistic_regression_tp_tn_fp_fn[2]), 1.0]
    logistic_regression_tpr = [0.0, calculate_tpr_instance(logistic_regression_tp_tn_fp_fn[0], logistic_regression_tp_tn_fp_fn[3]), 1.0]
    
    svm_fpr = [0.0, calculate_fpr_instance(svm_tp_tn_fp_fn[1], svm_tp_tn_fp_fn[2]), 1.0]
    svm_tpr = [0.0, calculate_tpr_instance(svm_tp_tn_fp_fn[0], svm_tp_tn_fp_fn[3]), 1.0]
    
    random_forest_fpr = [0.0, calculate_fpr_instance(random_forest_tp_tn_fp_fn[1], random_forest_tp_tn_fp_fn[2]), 1.0]
    random_forest_tpr = [0.0, calculate_tpr_instance(random_forest_tp_tn_fp_fn[0], random_forest_tp_tn_fp_fn[3]), 1.0]
    
    resnet_fpr = [0.0, calculate_fpr_instance(resnet_tp_tn_fp_fn[1], resnet_tp_tn_fp_fn[2]), 1.0]
    resnet_tpr = [0.0, calculate_tpr_instance(resnet_tp_tn_fp_fn[0], resnet_tp_tn_fp_fn[3]), 1.0]
    
    mobilenet_v2_fpr = [0.0, calculate_fpr_instance(mobilenet_v2_tp_tn_fp_fn[1], mobilenet_v2_tp_tn_fp_fn[2]), 1.0]
    mobilenet_v2_tpr = [0.0, calculate_tpr_instance(mobilenet_v2_tp_tn_fp_fn[0], mobilenet_v2_tp_tn_fp_fn[3]), 1.0]
    
    
    mobilenet_etpu_fpr = [0.0, calculate_fpr_instance(mobilenet_etpu_tp_tn_fp_fn[1], mobilenet_etpu_tp_tn_fp_fn[2]), 1.0]
    mobilenet_etpu_tpr = [0.0, calculate_tpr_instance(mobilenet_etpu_tp_tn_fp_fn[0], mobilenet_etpu_tp_tn_fp_fn[3]), 1.0]
    
    
    fig, ax = plt.subplots()
    plt.title("ROCs")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    ax.plot([0.0, 1.0], [0.0, 1.0], '--', color='gray')
    ax.plot(logistic_regression_fpr, logistic_regression_tpr, linewidth=2.0, label='Logistic Regression')
    ax.plot(svm_fpr, svm_tpr, linewidth=2.0, label='Support Vector Machine')
    ax.plot(random_forest_fpr, random_forest_tpr, linewidth=2.0, label='Random Forest')
    ax.plot(resnet_fpr, resnet_tpr, linewidth=2.0, label='ResNetV1')
    ax.plot(mobilenet_v2_fpr, mobilenet_v2_tpr, linewidth=2.0, label='MobileNetV2')
    ax.plot(mobilenet_etpu_fpr, mobilenet_etpu_tpr, linewidth=2.0, label='MobileNetEdgeTPU')
    ax.legend(loc="lower right")
    plt.show()

    
plot_roc_curves(
    logistic_regression_tp_tn_fp_fn=[1927608, 77791, 129525, 44693], 
    svm_tp_tn_fp_fn=[1702877, 171137, 36179, 269424],
    random_forest_tp_tn_fp_fn=[1903290, 74524, 132792, 69011],
    resnet_tp_tn_fp_fn=[176757184, 17023848, 13111568, 30495388],
    mobilenet_v2_tp_tn_fp_fn=[204620400, 24842974, 5292444, 2632436],
    mobilenet_etpu_tp_tn_fp_fn=[204014224, 22977736, 7157670, 3238608]
)
